# %% [markdown]
# ARN = arn:aws:s3:::coleneemr
# AWS_REGION = Europa (Frankfurt) eu-central-1

# %% [markdown]
# # First Time Test

# %%
# !pip install bs4
# Out:
# Requirement already satisfied: bs4 in /root/venv/lib/python3.12/site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /root/venv/lib/python3.12/site-packages (from bs4) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /root/venv/lib/python3.12/site-packages (from beautifulsoup4->bs4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /root/venv/lib/python3.12/site-packages (from beautifulsoup4->bs4) (4.14.1)
#
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# INFO

# %% [markdown]
# #9 feature muss noch weiter gemacht werden.

# %%
script_dir = os.getcwd()
#file_path = os.path.join(script_dir, "..", "JSONS", "all_matches.json")
file_path = "/work/all_matches.json"
all_rows = []

# %%
import json
import pandas as pd

all_rows = []

with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

for team_name, matches in data.items():
    for match in matches:
        try:
            info = match.get("info", {})
            game_id = info.get('gameId')
            game_mode = info.get("gameMode")
            game_type = info.get("gameType")
            timestamp = info.get("gameCreation")
            participants = info.get("participants", [])   # <- richtige Stelle!

            challenges = [participant.get("challenges", {}) for participant in participants]

            for player, challenge in zip(participants, challenges):
                row = {
                    "timestamp": timestamp,
                    "gameId": game_id,
                    "gameMode": game_mode,
                    "gameType": game_type,
                    "tier": player.get("tier"),
                    "rank": player.get("rank"),
                    "LP": player.get("leaguePoints"),
                    "wins": player.get("wins"),
                    "losses": player.get("losses"),
                }
                row.update(player)
                row.update(challenge)
                all_rows.append(row)

        except KeyError as e:
            print(f"Error {e} in {file_path}")
        except Exception as e:
            print(f"Error {e}")

df = pd.DataFrame(all_rows)
df["timestamp"] = pd.to_datetime(df["timestamp"], unit='ms')

# Normiere challenges (falls vorhanden)
if 'challenges' in df.columns:
    ch_df = pd.json_normalize(df['challenges']).add_prefix('challenge_')
    df = pd.concat([df.drop(columns=['challenges']), ch_df], axis=1)

# Normiere missions (falls vorhanden)
if 'missions' in df.columns:
    missions_df = pd.json_normalize(df['missions']).add_prefix('mission_')
    df = pd.concat([df.drop(columns=['missions']), missions_df], axis=1)

# Normiere perks (falls vorhanden)
if 'perks' in df.columns:
    perks_df = pd.json_normalize(df['perks']).add_prefix('perks_')
    df = pd.concat([df.drop(columns=['perks']), perks_df], axis=1)

df = df[df['gameMode'] == 'CLASSIC']
df = df[df['tier'].isin(['IRON', 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'EMERALD', 'DIAMOND'])]

print(df.tail())
# Out:
# Empty DataFrame
# Columns: [timestamp, gameId, gameMode, gameType, tier, rank, LP, wins, losses, PlayerScore0, PlayerScore1, PlayerScore10, PlayerScore11, PlayerScore2, PlayerScore3, PlayerScore4, PlayerScore5, PlayerScore6, PlayerScore7, PlayerScore8, PlayerScore9, allInPings, assistMePings, assists, baronKills, basicPings, champExperience, champLevel, championId, championName, championTransform, commandPings, consumablesPurchased, damageDealtToBuildings, damageDealtToObjectives, damageDealtToTurrets, damageSelfMitigated, dangerPings, deaths, detectorWardsPlaced, doubleKills, dragonKills, eligibleForProgression, enemyMissingPings, enemyVisionPings, firstBloodAssist, firstBloodKill, firstTowerAssist, firstTowerKill, gameEndedInEarlySurrender, gameEndedInSurrender, getBackPings, goldEarned, goldSpent, holdPings, individualPosition, inhibitorKills, inhibitorTakedowns, inhibitorsLost, item0, item1, item2, item3, item4, item5, item6, itemsPurchased, killingSprees, kills, lane, largestCriticalStrike, largestKillingSpree, largestMultiKill, longestTimeSpentLiving, magicDamageDealt, magicDamageDealtToChampions, magicDamageTaken, needVisionPings, neutralMinionsKilled, nexusKills, nexusLost, nexusTakedowns, objectivesStolen, objectivesStolenAssists, onMyWayPings, participantId, pentaKills, physicalDamageDealt, physicalDamageDealtToChampions, physicalDamageTaken, placement, playerAugment1, playerAugment2, playerAugment3, playerAugment4, playerAugment5, playerAugment6, playerSubteamId, profileIcon, pushPings, ...]
# Index: []
#
# [0 rows x 450 columns]

# %%
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

for team_name, matches in data.items():
    for match in matches:
        try:
            info = match.get("info", {})
            game_id = info.get('gameId')
            game_mode = info.get("gameMode")
            game_type = info.get("gameType")
            timestamp = info.get("gameCreation")
            participants = info.get("participants", [])
            challenges = [participant.get("challenges", {}) for participant in participants]

            for player, challenge in zip(participants, challenges):
                row = {
                    "timestamp": timestamp,
                    "gameId": game_id,
                    "gameMode": game_mode,
                    "gameType": game_type,
                    "tier": player.get("tier"),
                    "rank": player.get("rank"),
                    "LP": player.get("leaguePoints"),
                    "wins": player.get("wins"),
                    "losses": player.get("losses"),
                }
                row.update(player)
                row.update(challenge)
                all_rows.append(row)

        except KeyError as e:
            print(f"Error {e} in {file_path}")
        except Exception as e:
            print(f"Error {e}")

df = pd.DataFrame(all_rows)

df["timestamp"] = pd.to_datetime(df["timestamp"], unit='ms')

#Open up dictionarys in the list and create columns:

ch_df = pd.json_normalize(df['challenges']).add_prefix('challenge_')

df = pd.concat([
    df.drop(columns=['challenges']), 
    ch_df
], axis=1)

missions_df = pd.json_normalize(df['missions']).add_prefix('mission_')

df = pd.concat(
    [df.drop(columns=['missions']), missions_df],
    axis=1
)

perks_df = pd.json_normalize(df['perks']).add_prefix('perks_')

df = pd.concat(
    [df.drop(columns=['perks']), perks_df],
    axis=1
)

df = df[df['gameMode'] == 'CLASSIC']
df = df[df['tier'].isin(['IRON', 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'EMERALD', 'DIAMOND'])]

df.tail()
# Out:
# Empty DataFrame
# Columns: [timestamp, gameId, gameMode, gameType, tier, rank, LP, wins, losses, PlayerScore0, PlayerScore1, PlayerScore10, PlayerScore11, PlayerScore2, PlayerScore3, PlayerScore4, PlayerScore5, PlayerScore6, PlayerScore7, PlayerScore8, PlayerScore9, allInPings, assistMePings, assists, baronKills, basicPings, champExperience, champLevel, championId, championName, championTransform, commandPings, consumablesPurchased, damageDealtToBuildings, damageDealtToObjectives, damageDealtToTurrets, damageSelfMitigated, dangerPings, deaths, detectorWardsPlaced, doubleKills, dragonKills, eligibleForProgression, enemyMissingPings, enemyVisionPings, firstBloodAssist, firstBloodKill, firstTowerAssist, firstTowerKill, gameEndedInEarlySurrender, gameEndedInSurrender, getBackPings, goldEarned, goldSpent, holdPings, individualPosition, inhibitorKills, inhibitorTakedowns, inhibitorsLost, item0, item1, item2, item3, item4, item5, item6, itemsPurchased, killingSprees, kills, lane, largestCriticalStrike, largestKillingSpree, largestMultiKill, longestTimeSpentLiving, magicDamageDealt, magicDamageDealtToChampions, magicDamageTaken, needVisionPings, neutralMinionsKilled, nexusKills, nexusLost, nexusTakedowns, objectivesStolen, objectivesStolenAssists, onMyWayPings, participantId, pentaKills, physicalDamageDealt, physicalDamageDealtToChampions, physicalDamageTaken, placement, playerAugment1, playerAugment2, playerAugment3, playerAugment4, playerAugment5, playerAugment6, playerSubteamId, profileIcon, pushPings, ...]
# Index: []
#
# [0 rows x 450 columns]

# %%
df['tier'].unique()
df['gameType'].unique()
# Out:
# array(['MATCHED_GAME'], dtype=object)

# %%
with open('/work/features_columns.json', 'w', encoding='utf-8') as f:
    json.dump(list(df.columns), f, ensure_ascii=False, indent=2)

# %%
print(df.isna().sum().sum())
#print(df.info)
# Out:
# 2018

# %%
# Dropping non-numeric columns to compute the correlation matrix
numeric_df = df.select_dtypes(include=['number'])

# Compute the correlation matrix for numerical columns
correlation_matrix = numeric_df.corr()

plt.figure(figsize=(15, 12))
sns.heatmap(correlation_matrix,
            annot=False,
            cmap="coolwarm",
            vmin=0,
            vmax=1,
            fmt=".3f",
            cbar=True
            )
plt.title("Korrelationsmatrix (Champion Stats)")
plt.tight_layout()
plt.show()

# %%
c_matrix = correlation_matrix.abs()
intervals = np.arange(0, 1.1, 0.1)
result = {round(i,1):[] for i in intervals}
result[1.1] = [] # NaN-Werte

cols = c_matrix.columns
n = len(cols)

for i in range(n):
    for j in range(i+1, n):
        v = c_matrix.iloc[i, j]
        if np.isnan(v):
            result[1.1].append((cols[i], cols[j]))
        else:
            bucket = round(np.floor(v * 10) / 10, 1)
            if v == 1.0:
                bucket = 1.0
            result[bucket].append((cols[i], cols[j]))

list_result = {k: v for k, v in result.items()}

with open('/work/features_wertung.json', 'w', encoding='utf-8') as f:
    json.dump(list_result, f, ensure_ascii=False, indent=2)

# %%
# somtin somthin
'''
Features
DamageShare = teamDamagePercentage
role = lane
visionPerMinute = visionScorePerMinute
kda
totaltimespentdead
firstbloodkill
turretplatestaken
takedownsfirstxminutes
firstblood
kill-share
dodgeSkillShotsSmallWindow
outnumberedkills
veteran / freshBlood
hotStreak
perfectgame = deathless

longestTimeSpentLiving
quickCleanse
skillshotdogded
skillshotsHit
wardTakedownsBefore20M
gameEndedInEarlySurrender
maxlevelleadlaneopponent
summonerlevel
maxcsadvantageonlaneopponent
visionscoreadvantageonlaneopponent


'''


'''
heuristische Features
+1 Game Length vs. Winrate --> viele Games mit kurzer Zeit (normale Low Elo sind 30-40 Min)
+2 Account Level --> niedriges Level mit stark guten Stats ++
+3 Rank Progression (von Iron zu Gold in unter <50 Spielen)
-4 Durchschnittliches Gold vor 10 Minutes (vllt goldPerMinute anschauen und hohe Zahlen als Threshold verwenden)
-5 Anteil der Spiele mit S-Rank (kann OTP sein) Annäherungsversuch mittels Heuristik möglich --> S-Rank Potenzial Funktion
+6 Wie viele Perfekte Games (keine Tode)
+7 durchschnittlicher CS-Lead zum Lane Opponent (maxCsAdvantageOnLaneOpponent) ++
+8 hohe Vision Control ++
+9 durchschnittliches Gold pro Minute bei Champ und Rolle
+10 Zeit bis first full Item
-11 Erster Level 6 bei 10+ Games im Durchschnitt
+12 Winrate mit Off-Meta Champions (https://lolalytics.com/lol/tierlist/) --> All tierlist websites are dynamic (difficult to scrape)
+13 Anteil der Spiele mit über 20 Kills
-14 Ragequits/AFK-Quote (Smurf AFKt nicht)
-15 Keine frühen Aufgaben (earlysurrender gibt es nicht)
-16 Durchschnittliche Tower Damage im Verhältnis zum Team -->nur damageDealtToBuildings
+17 Durchschnittliche Anzahl an "Skillshots landed" ++
+18 Durchschnittliche Objective Steals pro Spiel
-19 Elo-Boosting (Drastische Veränderung der Account-Performance)
-20 Champion Experience (Viele S-Ranks ohne Championmastery oder wenige Punkte) - champion-mastery-v4-api
+21 Erst Prüfen ob "eligibleForProgression" ist auf "True" !!!

Info
--> mind 10+ Games für Aussagekraft
--> immer Top 5% der Elo-Rangliste
--> Alle Thresholds müssen aktualisiert werden mit einem Machine Learning Algorithmus

'''
# Out:
# '\nheuristische Features\n+1 Game Length vs. Winrate --> viele Games mit kurzer Zeit (normale Low Elo sind 30-40 Min)\n+2 Account Level --> niedriges Level mit stark guten Stats ++\n+3 Rank Progression (von Iron zu Gold in unter <50 Spielen)\n-4 Durchschnittliches Gold vor 10 Minutes (vllt goldPerMinute anschauen und hohe Zahlen als Threshold verwenden)\n-5 Anteil der Spiele mit S-Rank (kann OTP sein) Annäherungsversuch mittels Heuristik möglich --> S-Rank Potenzial Funktion\n+6 Wie viele Perfekte Games (keine Tode)\n+7 durchschnittlicher CS-Lead zum Lane Opponent (maxCsAdvantageOnLaneOpponent) ++\n+8 hohe Vision Control ++\n+9 durchschnittliches Gold pro Minute bei Champ und Rolle\n+10 Zeit bis first full Item\n-11 Erster Level 6 bei 10+ Games im Durchschnitt\n+12 Winrate mit Off-Meta Champions (https://lolalytics.com/lol/tierlist/) --> All tierlist websites are dynamic (difficult to scrape)\n+13 Anteil der Spiele mit über 20 Kills\n-14 Ragequits/AFK-Quote (Smurf AFKt nicht)\n-15 Keine frühen Aufgaben (earlysurrender gibt es nicht)\n-16 Durchschnittliche Tower Damage im Verhältnis zum Team -->nur damageDealtToBuildings\n+17 Durchschnittliche Anzahl an "Skillshots landed" ++\n+18 Durchschnittliche Objective Steals pro Spiel\n-19 Elo-Boosting (Drastische Veränderung der Account-Performance)\n-20 Champion Experience (Viele S-Ranks ohne Championmastery oder wenige Punkte) - champion-mastery-v4-api\n+21 Erst Prüfen ob "eligibleForProgression" ist auf "True" !!!\n\nInfo\n--> mind 10+ Games für Aussagekraft\n--> immer Top 5% der Elo-Rangliste\n--> Alle Thresholds müssen aktualisiert werden mit einem Machine Learning Algorithmus\n\n'

# %%
#New Features
df["damagePerGold"] = df["totalDamageDealtToChampions"] / df["goldEarned"]
df["carryScore"] =  (df["kda"] * df["totalDamageDealtToChampions"] * df["goldEarned"]) /  (df["timePlayed"]/60)
df["efficiencyScore"] = df["kda"] * df["damagePerGold"] * df["visionScorePerMinute"]

tier_map = {
    "IRON": 1,
    "BRONZE": 2,
    "SILVER": 3,
    "GOLD": 4,
    "PLATINUM": 5,
    "EMERALD": 6,
    "DIAMOND": 7,
    "MASTER": 8,
    "GRANDMASTER": 9,
    "CHALLENGER": 10,
    "UNRANKED": 0
}

rank_map = {"IV": 1, "III": 2, "II": 3, "I": 4}

df["tier_num"] = df["tier"].map(tier_map)
df["rank_num"] = df["rank"].map(rank_map).fillna(0).astype(int)

df["tier_score"] = df["tier_num"] + df["rank_num"] + df["LP"]/100

df_ranked = df[df["tier_score"] > 0].copy() #Filter non ranked players

df_ranked["kda_tier"] = df_ranked["kda"] / df_ranked["tier_score"]

df_ranked["winrate"] = (df_ranked["wins"] / (df_ranked["losses"]+df_ranked["wins"])) *100

df_ranked = df_ranked[df_ranked["eligibleForProgression"] == True].copy()

print(df_ranked["winrate"])

# Definiert wurde: Winrate, KDA/rank, damagePerGold, carryScore, efficiencyScore
# Out:
# 26     44.444444
# 27     52.941176
# 28     53.164557
# 31     37.500000
# 33     52.208835
#          ...
# 193    44.444444
# 194    50.340136
# 195    57.383966
# 196    50.596659
# 197    58.888889
# Name: winrate, Length: 70, dtype: float64

# %% [markdown]
# # Heuristische Features implementieren

# %%
#1. Game Length vs. Winrate
# timePlayed und gameLength ist das Gleiche nur gameLength ist float (genauer?)

def compute_fast_winrate(df):
    shortgame_threshold = 25 * 60 # Für Sekunden!

    won_games = df[df['win'] == True]
    short_wins = won_games[won_games['gameLength'] < shortgame_threshold]

    all_fast_games = df[df['gameLength'] < shortgame_threshold]

    total_games = len(df)
    fast_winrate = len(short_wins) / len(won_games) if len(won_games) > 0 else 0
    fast_game_rate = len(all_fast_games) / total_games if total_games > 0 else 0

    return pd.Series({'winrate': fast_winrate, 'fast_game_rate': fast_game_rate})

df_fast_stats = df.groupby('puuid').apply(compute_fast_winrate).reset_index()

df_ranked = df_ranked.merge(df_fast_stats[['puuid', 'fast_game_rate']], on='puuid', how='left')


'''
if len(won_games) > 0:
    winrate = len(short_wins) / len(won_games)
else:
    winrate = None

print(f"Anteil schneller Siege (<{shortgame_threshold} min): {winrate:.2%}")
print(f"Anteil aller kurzen Spiele (<{shortgame_threshold} min): {len(all_fast_games) / len(df):.2%}")
'''
# Out:
# /tmp/ipykernel_113/1696528781.py:18: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_fast_stats = df.groupby('puuid').apply(compute_fast_winrate).reset_index()
# '\nif len(won_games) > 0:\n    winrate = len(short_wins) / len(won_games)\nelse:\n    winrate = None\n\nprint(f"Anteil schneller Siege (<{shortgame_threshold} min): {winrate:.2%}")\nprint(f"Anteil aller kurzen Spiele (<{shortgame_threshold} min): {len(all_fast_games) / len(df):.2%}")\n'

# %%
#2. Account Level au smurf und score überprüfen
low_level_threshold = 70
high_kda_threshold = 4
high_winrate_threshold = 65
gold_earned_threshold = 400
totalDamageDealt_threshold = 300

account_stats = df_ranked.groupby('puuid').agg({
    'summonerLevel': 'first',
    'kda': 'mean',
    'kills': 'mean',
    'assists': 'mean',
    'deaths': 'mean',
    'goldPerMinute': 'mean',
    'totalDamageDealtToChampions': 'mean',
    'tier_num': 'first',
    'winrate' : 'mean'
}).reset_index()

account_stats['smurf_flag'] = (
    (account_stats['summonerLevel'] < low_level_threshold) &
    (
        #(account_stats['kda'] >= high_kda_threshold) &
        #(account_stats['kills'] >= 8) &
        #(account_stats['goldPerMinute'] >= gold_earned_threshold) &
        #(account_stats['totalDamageDealtToChampions'] >= totalDamageDealt_threshold) &
        (account_stats['winrate'] >= high_winrate_threshold) 
    )
)

account_stats['smurf_score'] = (
    (account_stats['summonerLevel'] < low_level_threshold).astype(int) +
    #(account_stats['kda'] >= high_kda_threshold).astype(int) +
    #(account_stats['kills'] >= 8).astype(int) +
    #(account_stats['goldPerMinute'] >= gold_earned_threshold).astype(int) +
    #(account_stats['totalDamageDealtToChampions'] >= totalDamageDealt_threshold).astype(int) +
    (account_stats['winrate'] >= high_winrate_threshold).astype(int)
)

account_stats['smurf_ratio'] = account_stats['smurf_score'] / account_stats['tier_num']
account_stats['smurf_ratio'] = account_stats['smurf_ratio'].fillna(0)

df_ranked = df_ranked.merge(account_stats[['puuid', 'smurf_flag', 'smurf_score', 'smurf_ratio']], on='puuid', how='left')

#print(df_ranked[['puuid', 'summonerLevel', 'kda', 'win', 'kills', 'goldPerMinute', 'totalDamageDealtToChampions', 'smurf_flag', 'smurf_score', 'smurf_ratio']].head())

print(df_ranked[['puuid', 'summonerLevel', 'kda', 'winrate', 'kills', 'goldPerMinute', 'totalDamageDealtToChampions', 'smurf_flag', 'smurf_score', 'smurf_ratio']].head())
# Out:
#                                                puuid  summonerLevel       kda  \
# 0  VecACGBYGaYN4rYoAdHr3nox4uAZERedMRHLuR8lqj9Z0P...             39  1.125000
# 1  -WbLudFHyoIYrQJ6XV-5MtWisSVjjweLp8S19KcZXWh3uy...            229  1.444444
# 2  vYQLI-rTA_2HuEUjwW3CzaD3J6ozUP-hXU0ogVPeruCNmh...            172  1.333333
# 3  LKEJUSbX118NCvq71N5d2Lt2VIowd9fc0JKSEC_jSJkwA_...            295  1.714286
# 4  D0eNXuIl7MQsskZFlosVNWJqV1jZ3zyR5nLk3sCEgIUcAT...            130  2.000000
#
#      winrate  kills  goldPerMinute  totalDamageDealtToChampions  smurf_flag  \
# 0  44.444444      7     399.918123                        33764       False
# 1  52.941176      6     408.514799                        17458       False
# 2  53.164557      4     396.184424                        18811       False
# 3  37.500000      4     371.105784                        17465       False
# 4  52.208835      9     483.211636                        24205       False
#
#    smurf_score  smurf_ratio
# 0            1     0.333333
# 1            0     0.000000
# 2            0     0.000000
# 3            0     0.000000
# 4            0     0.000000

# %%
sns.boxplot(data=account_stats, x='smurf_flag', y='smurf_ratio')
plt.title('Smurf Rating nach Smurf Flag')
# Out:
# /root/venv/lib/python3.12/site-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Text(0.5, 1.0, 'Smurf Rating nach Smurf Flag')

# %%
for t in [0.8, 1.0, 1.2, 1.5]:
    temp_flag = account_stats['smurf_ratio'] > t
    print(f"Threshold {t:.1f}:\n", pd.crosstab(account_stats['smurf_flag'], temp_flag, normalize='index'), "\n")

def label_smurf(row):
    if row['smurf_ratio'] >= 1.5:
        return 'definite_smurf'
    elif row['smurf_ratio'] >= 1.0:
        return 'likely_smurf'
    elif row['smurf_ratio'] >= 0.8:
        return 'possible_smurf'
    else:
        return 'normal'

account_stats['smurf_category'] = account_stats.apply(label_smurf, axis=1)
df_ranked = df_ranked.merge(account_stats[['puuid', 'smurf_category']], on='puuid', how='left')
# Out:
# Threshold 0.8:
#  smurf_ratio     False     True
# smurf_flag
# False        0.971429  0.028571
#
# Threshold 1.0:
#  smurf_ratio  False
# smurf_flag
# False          1.0
#
# Threshold 1.2:
#  smurf_ratio  False
# smurf_flag
# False          1.0
#
# Threshold 1.5:
#  smurf_ratio  False
# smurf_flag
# False          1.0

# %%
#3. Rank Progression (von Iron zu Gold in unter <50 Spielen)
df_sorted = df_ranked.sort_values(['puuid', 'timestamp'])

def check_schneller_rank_aufstieg(gruppe):
    if len(gruppe) < 2:
        return False
    lowest_tier = gruppe['tier_num'].min()
    highest_tier = gruppe['tier_num'].max()
    num_games = len(gruppe)
    is_schnell_aufgestiegen = (lowest_tier == 1) and (highest_tier >= 4) and (num_games <= 50)
    return is_schnell_aufgestiegen

rankprog_df = df_sorted.groupby('puuid').apply(lambda x: check_schneller_rank_aufstieg(x)).reset_index()
rankprog_df.columns = ['puuid', 'fast_rank_progression']

df_ranked = df_ranked.merge(rankprog_df, on='puuid', how='left')

print(df_ranked[df_ranked['fast_rank_progression']])
# Out:
# Empty DataFrame
# Columns: [timestamp, gameId, gameMode, gameType, tier, rank, LP, wins, losses, PlayerScore0, PlayerScore1, PlayerScore10, PlayerScore11, PlayerScore2, PlayerScore3, PlayerScore4, PlayerScore5, PlayerScore6, PlayerScore7, PlayerScore8, PlayerScore9, allInPings, assistMePings, assists, baronKills, basicPings, champExperience, champLevel, championId, championName, championTransform, commandPings, consumablesPurchased, damageDealtToBuildings, damageDealtToObjectives, damageDealtToTurrets, damageSelfMitigated, dangerPings, deaths, detectorWardsPlaced, doubleKills, dragonKills, eligibleForProgression, enemyMissingPings, enemyVisionPings, firstBloodAssist, firstBloodKill, firstTowerAssist, firstTowerKill, gameEndedInEarlySurrender, gameEndedInSurrender, getBackPings, goldEarned, goldSpent, holdPings, individualPosition, inhibitorKills, inhibitorTakedowns, inhibitorsLost, item0, item1, item2, item3, item4, item5, item6, itemsPurchased, killingSprees, kills, lane, largestCriticalStrike, largestKillingSpree, largestMultiKill, longestTimeSpentLiving, magicDamageDealt, magicDamageDealtToChampions, magicDamageTaken, needVisionPings, neutralMinionsKilled, nexusKills, nexusLost, nexusTakedowns, objectivesStolen, objectivesStolenAssists, onMyWayPings, participantId, pentaKills, physicalDamageDealt, physicalDamageDealtToChampions, physicalDamageTaken, placement, playerAugment1, playerAugment2, playerAugment3, playerAugment4, playerAugment5, playerAugment6, playerSubteamId, profileIcon, pushPings, ...]
# Index: []
#
# [0 rows x 467 columns]
# /tmp/ipykernel_113/115411444.py:13: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   rankprog_df = df_sorted.groupby('puuid').apply(lambda x: check_schneller_rank_aufstieg(x)).reset_index()

# %%
#6 Wie viele Perfekte Games (keine Tode)

perfect_games = df[df['deaths'] == 0]
perfect_games_won = perfect_games[perfect_games['win'] == True]

print(f"Anzahl Perfekte Games (keine Tode): {len(perfect_games)}")
print(f"… davon gewonnen: {len(perfect_games_won)}")

print(df_ranked[['puuid', 'perfectGame']])

#  Nicht notwendig ist schon im ranked_df
# Out:
# Anzahl Perfekte Games (keine Tode): 0
# … davon gewonnen: 0
#                                                 puuid  perfectGame
# 0   VecACGBYGaYN4rYoAdHr3nox4uAZERedMRHLuR8lqj9Z0P...            0
# 1   -WbLudFHyoIYrQJ6XV-5MtWisSVjjweLp8S19KcZXWh3uy...            0
# 2   vYQLI-rTA_2HuEUjwW3CzaD3J6ozUP-hXU0ogVPeruCNmh...            0
# 3   LKEJUSbX118NCvq71N5d2Lt2VIowd9fc0JKSEC_jSJkwA_...            0
# 4   D0eNXuIl7MQsskZFlosVNWJqV1jZ3zyR5nLk3sCEgIUcAT...            0
# ..                                                ...          ...
# 65  dSZRDHIK7sETNR2q_uodXNnJHMdu1uOvc3Lua4yqO-9P6B...            0
# 66  9KJqaSylw0NdkCxIBGyVSa2Nz9fAm1jUAP-vzadxoRg64x...            0
# 67  n4Ez80e-i6GgYeUeYkwDu32uJBPjhY6VwiB1WeY2X7SQrB...            0
# 68  3SfUU280VeZwGsmCJhmU7wFYdA6A6m38IvKPPebWD96GSY...            0
# 69  2rgIXCcnaYUzP-86OXVh0LQg0moZpWzlAzfCJUrk36_Krf...            0
#
# [70 rows x 2 columns]

# %%
#7 durchschnittlicher CS-Lead zum Lane Opponent --> Keine negativen Werte --> Nur Advantage

cs_lead_per_account = df.groupby('puuid')['maxCsAdvantageOnLaneOpponent'].mean().reset_index()
cs_lead_per_account.rename(columns={'maxCsAdvantageOnLaneOpponent': 'avg_cs_lead_lane'}, inplace=True)

df_ranked = df_ranked.merge(cs_lead_per_account, on='puuid', how='left')

print(df_ranked[['puuid', 'avg_cs_lead_lane']].head())
# Out:
#                                                puuid  avg_cs_lead_lane
# 0  VecACGBYGaYN4rYoAdHr3nox4uAZERedMRHLuR8lqj9Z0P...              67.0
# 1  -WbLudFHyoIYrQJ6XV-5MtWisSVjjweLp8S19KcZXWh3uy...               3.0
# 2  vYQLI-rTA_2HuEUjwW3CzaD3J6ozUP-hXU0ogVPeruCNmh...               4.0
# 3  LKEJUSbX118NCvq71N5d2Lt2VIowd9fc0JKSEC_jSJkwA_...               0.0
# 4  D0eNXuIl7MQsskZFlosVNWJqV1jZ3zyR5nLk3sCEgIUcAT...              36.0

# %%
#8 hohe Vision Control Score

vision_score_thresholds = df.groupby('tier')['visionScore'].quantile(0.75).reset_index()
vision_score_thresholds.rename(columns={'visionScore': 'visionScore_threshold'}, inplace=True)

df_ranked = df_ranked.merge(vision_score_thresholds, on='tier', how='left')

df_ranked['high_vision_control'] = (
    (df_ranked['visionScore'] > df_ranked['visionScore_threshold']) &
    (df_ranked['visionScoreAdvantageLaneOpponent'] > 0.5)
)

print(df_ranked[['puuid', 'championName', 'tier', 'visionScore', 'visionScore_threshold', 'visionScoreAdvantageLaneOpponent', 'high_vision_control']].head())
# Out:
#                                                puuid championName    tier  \
# 0  VecACGBYGaYN4rYoAdHr3nox4uAZERedMRHLuR8lqj9Z0P...         Yone  SILVER
# 1  -WbLudFHyoIYrQJ6XV-5MtWisSVjjweLp8S19KcZXWh3uy...      Nidalee  BRONZE
# 2  vYQLI-rTA_2HuEUjwW3CzaD3J6ozUP-hXU0ogVPeruCNmh...     Malzahar  BRONZE
# 3  LKEJUSbX118NCvq71N5d2Lt2VIowd9fc0JKSEC_jSJkwA_...       Darius  BRONZE
# 4  D0eNXuIl7MQsskZFlosVNWJqV1jZ3zyR5nLk3sCEgIUcAT...         Azir  BRONZE
#
#    visionScore  visionScore_threshold  visionScoreAdvantageLaneOpponent  \
# 0           14                   40.0                         -0.093380
# 1           13                   16.5                          0.246933
# 2           18                   16.5                          1.226014
# 3           15                   16.5                          0.102998
# 4            8                   16.5                         -0.550766
#
#    high_vision_control
# 0                False
# 1                False
# 2                 True
# 3                False
# 4                False

# %%
#9 durchschnittliches Gold pro Minute bei Champ und Rolle
#--> Webseite scrapen für Rundendauer durchschnitt und mit durchschnitt von Gold/XP vergleichen
#--> https://op.gg/de/lol/statistics/champions und https://www.leagueofgraphs.com/stats/game-durations

with open("champ-stats.html", encoding="utf-8") as f:
    html = f.read()

soup = BeautifulSoup(html, "html.parser")

champ_data = []

rows = soup.find_all('tr')

for row in rows:
    cols = row.find_all('td')
    if len(cols) < 9:
        continue
    name = cols[1].text.strip()
    cs = cols[7].text.strip().replace(',', '.')
    gold = cols[8].text.strip().replace(',', '.')
    champ_data.append({'championName': name, 'goldAvgInternet': gold, 'csAvgInternet': cs})

for c in champ_data:
    print(c)
# Out:
# {'championName': 'Lux', 'goldAvgInternet': '10.702', 'csAvgInternet': '101.69'}
# {'championName': 'Jhin', 'goldAvgInternet': '12.856', 'csAvgInternet': '187.62'}
# {'championName': 'Caitlyn', 'goldAvgInternet': '12.863', 'csAvgInternet': '193.76'}
# {'championName': 'Senna', 'goldAvgInternet': '11.423', 'csAvgInternet': '131.56'}
# {'championName': 'Miss Fortune', 'goldAvgInternet': '12.945', 'csAvgInternet': '185.37'}
# {'championName': 'Jinx', 'goldAvgInternet': '12.557', 'csAvgInternet': '196.68'}
# {'championName': 'Yasuo', 'goldAvgInternet': '12.499', 'csAvgInternet': '201.57'}
# {'championName': 'Ezreal', 'goldAvgInternet': '12.130', 'csAvgInternet': '187.82'}
# {'championName': "Kai'Sa", 'goldAvgInternet': '13.038', 'csAvgInternet': '199.57'}
# {'championName': 'Lucian', 'goldAvgInternet': '12.735', 'csAvgInternet': '200.26'}
# {'championName': 'Yone', 'goldAvgInternet': '12.165', 'csAvgInternet': '197.42'}
# {'championName': 'Pantheon', 'goldAvgInternet': '11.652', 'csAvgInternet': '126.64'}
# {'championName': 'Smolder', 'goldAvgInternet': '12.893', 'csAvgInternet': '215.01'}
# {'championName': 'Zed', 'goldAvgInternet': '12.724', 'csAvgInternet': '182.82'}
# {'championName': 'Mel', 'goldAvgInternet': '12.123', 'csAvgInternet': '145.85'}
# {'championName': 'Viego', 'goldAvgInternet': '12.815', 'csAvgInternet': '178.79'}
# {'championName': 'Sylas', 'goldAvgInternet': '11.162', 'csAvgInternet': '143.43'}
# {'championName': 'Sett', 'goldAvgInternet': '12.382', 'csAvgInternet': '174.53'}
# {'championName': 'Kayn', 'goldAvgInternet': '12.854', 'csAvgInternet': '181.53'}
# {'championName': 'Ashe', 'goldAvgInternet': '11.599', 'csAvgInternet': '167.56'}
# {'championName': 'Diana', 'goldAvgInternet': '12.880', 'csAvgInternet': '186.93'}
# {'championName': 'Ahri', 'goldAvgInternet': '11.581', 'csAvgInternet': '181.16'}
# {'championName': 'Lee Sin', 'goldAvgInternet': '12.067', 'csAvgInternet': '160.53'}
# {'championName': 'Warwick', 'goldAvgInternet': '12.537', 'csAvgInternet': '166.07'}
# {'championName': 'Ekko', 'goldAvgInternet': '12.785', 'csAvgInternet': '178.75'}
# {'championName': 'Thresh', 'goldAvgInternet': '8.633', 'csAvgInternet': '34.46'}
# {'championName': 'Shaco', 'goldAvgInternet': '12.177', 'csAvgInternet': '138.14'}
# {'championName': 'Nautilus', 'goldAvgInternet': '8.614', 'csAvgInternet': '35.15'}
# {'championName': 'Dr. Mundo', 'goldAvgInternet': '12.184', 'csAvgInternet': '193.62'}
# {'championName': 'Tristana', 'goldAvgInternet': '13.040', 'csAvgInternet': '185.24'}
# {'championName': 'Nami', 'goldAvgInternet': '8.413', 'csAvgInternet': '25.58'}
# {'championName': 'Nocturne', 'goldAvgInternet': '12.779', 'csAvgInternet': '186.02'}
# {'championName': 'Volibear', 'goldAvgInternet': '12.175', 'csAvgInternet': '178.26'}
# {'championName': 'Morgana', 'goldAvgInternet': '9.963', 'csAvgInternet': '66.77'}
# {'championName': 'Teemo', 'goldAvgInternet': '12.097', 'csAvgInternet': '167.42'}
# {'championName': 'Akali', 'goldAvgInternet': '11.938', 'csAvgInternet': '164.4'}
# {'championName': 'Shen', 'goldAvgInternet': '10.673', 'csAvgInternet': '141.02'}
# {'championName': 'Malphite', 'goldAvgInternet': '11.223', 'csAvgInternet': '150.12'}
# {'championName': 'Darius', 'goldAvgInternet': '12.374', 'csAvgInternet': '183.29'}
# {'championName': 'Vayne', 'goldAvgInternet': '12.571', 'csAvgInternet': '178'}
# {'championName': 'Xerath', 'goldAvgInternet': '11.175', 'csAvgInternet': '122.29'}
# {'championName': 'Lulu', 'goldAvgInternet': '8.246', 'csAvgInternet': '30.3'}
# {'championName': 'Master Yi', 'goldAvgInternet': '13.017', 'csAvgInternet': '179.28'}
# {'championName': 'Mordekaiser', 'goldAvgInternet': '12.051', 'csAvgInternet': '173.63'}
# {'championName': 'Malzahar', 'goldAvgInternet': '12.828', 'csAvgInternet': '218.34'}
# {'championName': 'Yorick', 'goldAvgInternet': '12.678', 'csAvgInternet': '202.62'}
# {'championName': 'Varus', 'goldAvgInternet': '12.352', 'csAvgInternet': '186.47'}
# {'championName': 'Leona', 'goldAvgInternet': '8.631', 'csAvgInternet': '31.85'}
# {'championName': 'Aatrox', 'goldAvgInternet': '11.505', 'csAvgInternet': '175.82'}
# {'championName': 'Veigar', 'goldAvgInternet': '12.548', 'csAvgInternet': '177.18'}
# {'championName': 'Jax', 'goldAvgInternet': '12.154', 'csAvgInternet': '176.12'}
# {'championName': 'Xin Zhao', 'goldAvgInternet': '11.866', 'csAvgInternet': '167.26'}
# {'championName': "Kha'Zix", 'goldAvgInternet': '13.162', 'csAvgInternet': '177.16'}
# {'championName': 'Garen', 'goldAvgInternet': '12.915', 'csAvgInternet': '199.18'}
# {'championName': 'Irelia', 'goldAvgInternet': '13.203', 'csAvgInternet': '216.41'}
# {'championName': 'Vladimir', 'goldAvgInternet': '12.093', 'csAvgInternet': '193.76'}
# {'championName': 'Karma', 'goldAvgInternet': '8.904', 'csAvgInternet': '51.2'}
# {'championName': 'Viktor', 'goldAvgInternet': '11.803', 'csAvgInternet': '195.47'}
# {'championName': 'Pyke', 'goldAvgInternet': '10.265', 'csAvgInternet': '36.5'}
# {'championName': 'Renekton', 'goldAvgInternet': '12.303', 'csAvgInternet': '194.9'}
# {'championName': 'Naafiri', 'goldAvgInternet': '12.676', 'csAvgInternet': '178.53'}
# {'championName': 'Braum', 'goldAvgInternet': '8.297', 'csAvgInternet': '27.57'}
# {'championName': 'Katarina', 'goldAvgInternet': '12.698', 'csAvgInternet': '164.24'}
# {'championName': 'Galio', 'goldAvgInternet': '10.592', 'csAvgInternet': '150.49'}
# {'championName': 'Sion', 'goldAvgInternet': '12.508', 'csAvgInternet': '196.22'}
# {'championName': 'Swain', 'goldAvgInternet': '10.464', 'csAvgInternet': '94.58'}
# {'championName': 'Trundle', 'goldAvgInternet': '12.710', 'csAvgInternet': '187.6'}
# {'championName': 'Samira', 'goldAvgInternet': '13.465', 'csAvgInternet': '183.14'}
# {'championName': "Cho'Gath", 'goldAvgInternet': '12.014', 'csAvgInternet': '172.98'}
# {'championName': 'Yuumi', 'goldAvgInternet': '7.995', 'csAvgInternet': '14.77'}
# {'championName': 'Nasus', 'goldAvgInternet': '12.187', 'csAvgInternet': '183.7'}
# {'championName': 'Vi', 'goldAvgInternet': '11.921', 'csAvgInternet': '168.63'}
# {'championName': 'Jarvan IV.', 'goldAvgInternet': '12.165', 'csAvgInternet': '162.33'}
# {'championName': 'LeBlanc', 'goldAvgInternet': '11.499', 'csAvgInternet': '147.18'}
# {'championName': 'Blitzcrank', 'goldAvgInternet': '8.453', 'csAvgInternet': '30.02'}
# {'championName': 'Kayle', 'goldAvgInternet': '12.923', 'csAvgInternet': '213.95'}
# {'championName': 'Seraphine', 'goldAvgInternet': '9.379', 'csAvgInternet': '57.46'}
# {'championName': 'Graves', 'goldAvgInternet': '13.799', 'csAvgInternet': '203.33'}
# {'championName': 'Talon', 'goldAvgInternet': '12.891', 'csAvgInternet': '190.23'}
# {'championName': 'Milio', 'goldAvgInternet': '8.167', 'csAvgInternet': '28.77'}
# {'championName': 'Twitch', 'goldAvgInternet': '13.031', 'csAvgInternet': '163.16'}
# {'championName': 'Brand', 'goldAvgInternet': '10.842', 'csAvgInternet': '97.63'}
# {'championName': 'Zyra', 'goldAvgInternet': '10.153', 'csAvgInternet': '81.16'}
# {'championName': 'Amumu', 'goldAvgInternet': '11.483', 'csAvgInternet': '156.6'}
# {'championName': 'Gwen', 'goldAvgInternet': '12.509', 'csAvgInternet': '191.01'}
# {'championName': 'Briar', 'goldAvgInternet': '13.038', 'csAvgInternet': '171.65'}
# {'championName': 'Tahm Kench', 'goldAvgInternet': '9.934', 'csAvgInternet': '72.31'}
# {'championName': "Vel'Koz", 'goldAvgInternet': '10.806', 'csAvgInternet': '97.36'}
# {'championName': 'Hwei', 'goldAvgInternet': '11.592', 'csAvgInternet': '174.76'}
# {'championName': 'Jayce', 'goldAvgInternet': '12.267', 'csAvgInternet': '197.96'}
# {'championName': 'Fizz', 'goldAvgInternet': '12.871', 'csAvgInternet': '163.67'}
# {'championName': 'Soraka', 'goldAvgInternet': '8.025', 'csAvgInternet': '27.69'}
# {'championName': 'Xayah', 'goldAvgInternet': '12.657', 'csAvgInternet': '204.62'}
# {'championName': 'Twisted Fate', 'goldAvgInternet': '12.383', 'csAvgInternet': '175.89'}
# {'championName': 'Lillia', 'goldAvgInternet': '12.516', 'csAvgInternet': '186.51'}
# {'championName': 'Alistar', 'goldAvgInternet': '8.265', 'csAvgInternet': '31.18'}
# {'championName': 'Vex', 'goldAvgInternet': '11.825', 'csAvgInternet': '172.88'}
# {'championName': 'Wukong', 'goldAvgInternet': '12.266', 'csAvgInternet': '169.87'}
# {'championName': 'Sivir', 'goldAvgInternet': '12.949', 'csAvgInternet': '224.41'}
# {'championName': 'Aphelios', 'goldAvgInternet': '12.664', 'csAvgInternet': '191.83'}
# {'championName': 'Annie', 'goldAvgInternet': '11.448', 'csAvgInternet': '153.42'}
# {'championName': 'Neeko', 'goldAvgInternet': '10.069', 'csAvgInternet': '84.54'}
# {'championName': 'Fiddlesticks', 'goldAvgInternet': '11.146', 'csAvgInternet': '126.23'}
# {'championName': 'Poppy', 'goldAvgInternet': '10.245', 'csAvgInternet': '99.06'}
# {'championName': 'Gragas', 'goldAvgInternet': '11.198', 'csAvgInternet': '159.84'}
# {'championName': 'Orianna', 'goldAvgInternet': '11.617', 'csAvgInternet': '190.85'}
# {'championName': 'Syndra', 'goldAvgInternet': '12.635', 'csAvgInternet': '193.63'}
# {'championName': 'Zac', 'goldAvgInternet': '11.210', 'csAvgInternet': '150.15'}
# {'championName': 'Zoe', 'goldAvgInternet': '11.277', 'csAvgInternet': '146.8'}
# {'championName': 'Riven', 'goldAvgInternet': '12.233', 'csAvgInternet': '183.95'}
# {'championName': 'Elise', 'goldAvgInternet': '11.474', 'csAvgInternet': '118.76'}
# {'championName': 'Rell', 'goldAvgInternet': '8.655', 'csAvgInternet': '29.27'}
# {'championName': 'Tryndamere', 'goldAvgInternet': '13.218', 'csAvgInternet': '211.94'}
# {'championName': 'Fiora', 'goldAvgInternet': '12.490', 'csAvgInternet': '194.29'}
# {'championName': 'Draven', 'goldAvgInternet': '13.508', 'csAvgInternet': '189.63'}
# {'championName': 'Ryze', 'goldAvgInternet': '12.285', 'csAvgInternet': '209.43'}
# {'championName': 'Ambessa', 'goldAvgInternet': '11.593', 'csAvgInternet': '178.97'}
# {'championName': 'Gangplank', 'goldAvgInternet': '13.797', 'csAvgInternet': '205.65'}
# {'championName': 'Urgot', 'goldAvgInternet': '12.930', 'csAvgInternet': '191.77'}
# {'championName': 'Rakan', 'goldAvgInternet': '8.277', 'csAvgInternet': '31.98'}
# {'championName': 'Azir', 'goldAvgInternet': '12.056', 'csAvgInternet': '202.31'}
# {'championName': 'Ornn', 'goldAvgInternet': '11.059', 'csAvgInternet': '171.31'}
# {'championName': 'Illaoi', 'goldAvgInternet': '12.160', 'csAvgInternet': '189.8'}
# {'championName': 'Hecarim', 'goldAvgInternet': '12.591', 'csAvgInternet': '194.12'}
# {'championName': 'Heimerdinger', 'goldAvgInternet': '11.838', 'csAvgInternet': '173.43'}
# {'championName': 'Kindred', 'goldAvgInternet': '12.855', 'csAvgInternet': '177.35'}
# {'championName': 'Nunu & Willump', 'goldAvgInternet': '11.396', 'csAvgInternet': '153.6'}
# {'championName': 'Aurora', 'goldAvgInternet': '11.763', 'csAvgInternet': '179.44'}
# {'championName': 'Sejuani', 'goldAvgInternet': '11.347', 'csAvgInternet': '160.67'}
# {'championName': 'Evelynn', 'goldAvgInternet': '12.515', 'csAvgInternet': '159.71'}
# {'championName': 'Udyr', 'goldAvgInternet': '12.177', 'csAvgInternet': '186.51'}
# {'championName': 'Nidalee', 'goldAvgInternet': '11.586', 'csAvgInternet': '154.01'}
# {'championName': 'Kennen', 'goldAvgInternet': '11.761', 'csAvgInternet': '171.15'}
# {'championName': 'Gnar', 'goldAvgInternet': '11.854', 'csAvgInternet': '182.08'}
# {'championName': 'Quinn', 'goldAvgInternet': '13.003', 'csAvgInternet': '172.63'}
# {'championName': 'Aurelion Sol', 'goldAvgInternet': '12.811', 'csAvgInternet': '194.38'}
# {'championName': 'Maokai', 'goldAvgInternet': '9.363', 'csAvgInternet': '70.65'}
# {'championName': 'Lissandra', 'goldAvgInternet': '11.687', 'csAvgInternet': '180.51'}
# {'championName': 'Sona', 'goldAvgInternet': '8.672', 'csAvgInternet': '30.23'}
# {'championName': 'Bard', 'goldAvgInternet': '9.199', 'csAvgInternet': '33.92'}
# {'championName': "K'Sante", 'goldAvgInternet': '11.013', 'csAvgInternet': '176'}
# {'championName': 'Rengar', 'goldAvgInternet': '12.867', 'csAvgInternet': '182.61'}
# {'championName': 'Zeri', 'goldAvgInternet': '13.231', 'csAvgInternet': '215.73'}
# {'championName': 'Camille', 'goldAvgInternet': '11.832', 'csAvgInternet': '163.22'}
# {'championName': 'Qiyana', 'goldAvgInternet': '12.357', 'csAvgInternet': '169.66'}
# {'championName': 'Rammus', 'goldAvgInternet': '11.193', 'csAvgInternet': '150.19'}
# {'championName': 'Zilean', 'goldAvgInternet': '9.103', 'csAvgInternet': '62.9'}
# {'championName': 'Akshan', 'goldAvgInternet': '13.244', 'csAvgInternet': '177.5'}
# {'championName': 'Janna', 'goldAvgInternet': '8.336', 'csAvgInternet': '28.54'}
# {'championName': 'Ziggs', 'goldAvgInternet': '12.120', 'csAvgInternet': '178.82'}
# {'championName': 'Taliyah', 'goldAvgInternet': '11.930', 'csAvgInternet': '188.53'}
# {'championName': 'Rumble', 'goldAvgInternet': '11.621', 'csAvgInternet': '177.65'}
# {'championName': 'Anivia', 'goldAvgInternet': '11.457', 'csAvgInternet': '170.89'}
# {'championName': 'Nilah', 'goldAvgInternet': '13.388', 'csAvgInternet': '189.84'}
# {'championName': 'Singed', 'goldAvgInternet': '12.507', 'csAvgInternet': '216.31'}
# {'championName': 'Shyvana', 'goldAvgInternet': '12.801', 'csAvgInternet': '209.29'}
# {'championName': 'Olaf', 'goldAvgInternet': '12.615', 'csAvgInternet': '186.62'}
# {'championName': 'Karthus', 'goldAvgInternet': '13.619', 'csAvgInternet': '205.09'}
# {'championName': "Kog'Maw", 'goldAvgInternet': '12.932', 'csAvgInternet': '184.04'}
# {'championName': 'Corki', 'goldAvgInternet': '12.594', 'csAvgInternet': '204.01'}
# {'championName': 'Kassadin', 'goldAvgInternet': '12.357', 'csAvgInternet': '179.22'}
# {'championName': 'Cassiopeia', 'goldAvgInternet': '11.869', 'csAvgInternet': '185.77'}
# {'championName': "Bel'Veth", 'goldAvgInternet': '12.441', 'csAvgInternet': '182.23'}
# {'championName': 'Kalista', 'goldAvgInternet': '12.665', 'csAvgInternet': '182.25'}
# {'championName': 'Ivern', 'goldAvgInternet': '10.534', 'csAvgInternet': '135.46'}
# {'championName': 'Taric', 'goldAvgInternet': '8.607', 'csAvgInternet': '41.88'}
# {'championName': 'Kled', 'goldAvgInternet': '12.512', 'csAvgInternet': '169.69'}
# {'championName': 'Renata Glasc', 'goldAvgInternet': '8.570', 'csAvgInternet': '34.23'}
# {'championName': 'Skarner', 'goldAvgInternet': '10.601', 'csAvgInternet': '144.94'}
# {'championName': "Rek'Sai", 'goldAvgInternet': '11.960', 'csAvgInternet': '157.05'}

# %%
#9 durchschnittliches Gold pro Minute bei Champ und Rolle -- Continuation
def clean_name(name):
    if pd.isna(name):
        return ""
    return re.sub(r'[^A-Za-z0-9]', '', name).upper()

champion_gold_df = pd.DataFrame(champ_data)

#Unify championName
champion_gold_df['championName'] = champion_gold_df['championName'].apply(clean_name)
df_ranked['championName']      = df_ranked['championName'].apply(clean_name)
df_ranked['tier']              = df_ranked['tier'].str.strip().str.upper()

champion_gold_df['goldAvgInternet'] = (
    champion_gold_df['goldAvgInternet']
    .str.replace('.', '', regex=False)
    .str.replace(',', '.', regex=False)
    .astype(float)
)

#Average gametime per rank
def compute_time(x: float) -> float:
    m = int(x)
    s = int((x - m) * 100)
    return (m*60 + s) / 60.0

Ranked_Solo_Duo = {
    tier: compute_time(val)
    for tier, val in {
        'IRON':   30.36, 'BRONZE': 30.44, 'SILVER': 30.33,
        'GOLD':   30.05, 'PLATINUM':29.32, 'EMERALD':28.54,
        'DIAMOND':28.02, 'MASTER':26.58, 'GRANDMASTER':26.36,
        'CHALLENGER':26.11
    }.items()
}

df_ranked = df_ranked.merge(
    champion_gold_df[['championName','goldAvgInternet']],
    on='championName',
    how='left'
)

df_ranked['avgGameTime'] = df_ranked['tier'].map(Ranked_Solo_Duo)

df_ranked['internetGoldPerMinute'] = (
    df_ranked['goldAvgInternet'] / df_ranked['avgGameTime']
)

df_ranked['gpmDelta'] = df_ranked['goldPerMinute'] - df_ranked['internetGoldPerMinute']

display(df_ranked[['puuid','championName','tier',
                   'goldAvgInternet','avgGameTime',
                   'internetGoldPerMinute','goldPerMinute','gpmDelta']].head(10))
# Out:
#                                                puuid championName    tier  \
# 0  VecACGBYGaYN4rYoAdHr3nox4uAZERedMRHLuR8lqj9Z0P...         YONE  SILVER
# 1  -WbLudFHyoIYrQJ6XV-5MtWisSVjjweLp8S19KcZXWh3uy...      NIDALEE  BRONZE
# 2  vYQLI-rTA_2HuEUjwW3CzaD3J6ozUP-hXU0ogVPeruCNmh...     MALZAHAR  BRONZE
# 3  LKEJUSbX118NCvq71N5d2Lt2VIowd9fc0JKSEC_jSJkwA_...       DARIUS  BRONZE
# 4  D0eNXuIl7MQsskZFlosVNWJqV1jZ3zyR5nLk3sCEgIUcAT...         AZIR  BRONZE
# 5  BOIe8vqhUfX27L0ES02Lp9xTRAUmQ8Xo-ng8xI0Dud0WB1...        VARUS  BRONZE
# 6  fgUmO3_kqZR3_nqvigkrL520DlCQZE5sG3TU2Df6bCL77G...      MORGANA  BRONZE
# 7  YRvGMWX4Eco8OmxrRvY6i3t2CSJUU_A_YVK-Y7KSN4RPP1...        SHACO    GOLD
# 8  c7R5Mgnp9my-gtl4UueChgdJOMtrWpTBE2_o3ZQhA-qcOY...      NAAFIRI  BRONZE
# 9  tpghW4K0wr4o8ukEV6O7pOrU4-kfVzgdJPIl7fBk5iQb74...  MISSFORTUNE  BRONZE
#
#    goldAvgInternet  avgGameTime  internetGoldPerMinute  goldPerMinute  \
# 0          12165.0    30.533333             398.417031     399.918123
# 1          11586.0    30.733333             376.984816     408.514799
# 2          12828.0    30.733333             417.396963     396.184424
# 3          12374.0    30.733333             402.624729     371.105784
# 4          12056.0    30.733333             392.277657     483.211636
# 5          12352.0    30.733333             401.908894     558.272506
# 6           9963.0    30.733333             324.175705     415.054236
# 7          12177.0    30.083333             404.775623     348.969501
# 8          12676.0    30.733333             412.451193     354.018632
# 9          12945.0    30.733333             421.203905     308.880852
#
#      gpmDelta
# 0    1.501092
# 1   31.529984
# 2  -21.212539
# 3  -31.518945
# 4   90.933978
# 5  156.363612
# 6   90.878531
# 7  -55.806123
# 8  -58.432561
# 9 -112.323053

# %%
#10. Zeit bis first full Item

#There is no possible metric for first full Item
#However we could estimate the first item time by applying the goldPerMinute feature on the first bought item cost

url = 'https://wiki.leagueoflegends.com/en-us/List_of_items'
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")

#Search for legendary items and their URLs

item_names = []
item_links = []
legendary_items = []

for dt in soup.find_all('dt'):
    if "Legendary items" in dt.text:
        legendary_div = dt.find_next('div', class_='tlist')
        if legendary_div:
            for item in legendary_div.find_all('li'):
                icon_div = item.find('div', class_='item-icon')
                if icon_div:
                    name = icon_div.get('data-item', '')
                    a_tag = item.find('a', href=True)
                    link = 'https://wiki.leagueoflegends.com' + a_tag['href'] if a_tag else ''
                    item_names.append(name)
                    item_links.append(link)
        break

#Visit every URL and find out what the item cost and ID is

for i in range(len(item_links)):
    url = item_links[i]
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")

    infobox = soup.find('div', class_='infobox-section-cell')

    cost = ''
    item_id = ''
    if infobox:
        rows = infobox.find_all('div', class_='infobox-data-row')
        for row in rows:
            label = row.find('div', class_='infobox-data-label')
            value = row.find('div', class_='infobox-data-value')
            if not label or not value:
                continue
            # Extract item costs
            if 'Cost' in label.text:
                gold_span = value.find('span', style=lambda x: x and 'color:#E2BA3D' in x)
                if gold_span:
                    cost_text = gold_span.find_all('span')[-1].text.strip()
                    cost = cost_text
            # Extract item ID
            if label.text.strip() == 'ID':
                item_id = value.text.strip()
    legendary_items.append({'name': item_names[i], 'cost': cost, 'id': item_id})

print(legendary_items)
# Out:
# [{'name': 'Abyssal Mask', 'cost': '2650', 'id': '8020'}, {'name': "Archangel's Staff", 'cost': '2900', 'id': '3003'}, {'name': 'Ardent Censer', 'cost': '2200', 'id': '3504'}, {'name': 'Axiom Arc', 'cost': '3000', 'id': '6696'}, {'name': "Banshee's Veil", 'cost': '3000', 'id': '3102'}, {'name': 'Black Cleaver', 'cost': '3000', 'id': '3071'}, {'name': 'Blackfire Torch', 'cost': '2800', 'id': '2503'}, {'name': 'Blade of the Ruined King', 'cost': '3200', 'id': '3153'}, {'name': "Bloodletter's Curse", 'cost': '2900', 'id': '8010'}, {'name': 'Bloodsong', 'cost': '400', 'id': '3877'}, {'name': 'Bloodthirster', 'cost': '3400', 'id': '3072'}, {'name': 'Bounty of Worlds', 'cost': '400', 'id': '3867'}, {'name': 'Celestial Opposition', 'cost': '400', 'id': '3869'}, {'name': 'Chempunk Chainsword', 'cost': '3100', 'id': '6609'}, {'name': 'Cosmic Drive', 'cost': '3000', 'id': '4629'}, {'name': 'Cryptbloom', 'cost': '3000', 'id': '3137'}, {'name': 'Dawncore', 'cost': '2500', 'id': '6621'}, {'name': "Dead Man's Plate", 'cost': '2900', 'id': '3742'}, {'name': "Death's Dance", 'cost': '3300', 'id': '6333'}, {'name': 'Dream Maker', 'cost': '400', 'id': '3870'}, {'name': 'Echoes of Helia', 'cost': '2200', 'id': '6620'}, {'name': 'Eclipse', 'cost': '2900', 'id': '6692'}, {'name': 'Edge of Night', 'cost': '3000', 'id': '3814'}, {'name': 'Essence Reaver', 'cost': '2900', 'id': '3508'}, {'name': 'Experimental Hexplate', 'cost': '3000', 'id': '3073'}, {'name': 'Fimbulwinter', 'cost': '2400', 'id': '3121'}, {'name': 'Force of Nature', 'cost': '2800', 'id': '4401'}, {'name': 'Frozen Heart', 'cost': '2500', 'id': '3110'}, {'name': 'Guardian Angel', 'cost': '3200', 'id': '3026'}, {'name': "Guinsoo's Rageblade", 'cost': '3000', 'id': '3124'}, {'name': 'Heartsteel', 'cost': '3000', 'id': '3084'}, {'name': 'Hextech Rocketbelt', 'cost': '2650', 'id': '3152'}, {'name': 'Hollow Radiance', 'cost': '2800', 'id': '6664'}, {'name': 'Horizon Focus', 'cost': '2800', 'id': '4628'}, {'name': 'Hubris', 'cost': '3000', 'id': '6697'}, {'name': 'Hullbreaker', 'cost': '3000', 'id': '3181'}, {'name': 'Iceborn Gauntlet', 'cost': '2900', 'id': '6662'}, {'name': 'Immortal Shieldbow', 'cost': '3000', 'id': '6673'}, {'name': 'Imperial Mandate', 'cost': '2250', 'id': '4005'}, {'name': 'Infinity Edge', 'cost': '3450', 'id': '3031'}, {'name': "Jak'Sho, The Protean", 'cost': '3200', 'id': '6665'}, {'name': 'Kaenic Rookern', 'cost': '2900', 'id': '2504'}, {'name': "Knight's Vow", 'cost': '2300', 'id': '3109'}, {'name': 'Kraken Slayer', 'cost': '3000', 'id': '6672'}, {'name': "Liandry's Torment", 'cost': '3000', 'id': '6653'}, {'name': 'Lich Bane', 'cost': '2900', 'id': '3100'}, {'name': 'Locket of the Iron Solari', 'cost': '2200', 'id': '3190'}, {'name': "Lord Dominik's Regards", 'cost': '3100', 'id': '3036'}, {'name': "Luden's Companion", 'cost': '2750', 'id': '6655'}, {'name': 'Malignance', 'cost': '2700', 'id': '3118'}, {'name': 'Manamune', 'cost': '2900', 'id': '3004'}, {'name': 'Maw of Malmortius', 'cost': '3100', 'id': '3156'}, {'name': "Mejai's Soulstealer", 'cost': '1500', 'id': '3041'}, {'name': 'Mercurial Scimitar', 'cost': '3200', 'id': '3139'}, {'name': "Mikael's Blessing", 'cost': '2300', 'id': '3222'}, {'name': 'Moonstone Renewer', 'cost': '2200', 'id': '6617'}, {'name': 'Morellonomicon', 'cost': '2850', 'id': '3165'}, {'name': 'Mortal Reminder', 'cost': '3300', 'id': '3033'}, {'name': 'Muramana', 'cost': '2900', 'id': '3042'}, {'name': "Nashor's Tooth", 'cost': '2900', 'id': '3115'}, {'name': 'Navori Flickerblade', 'cost': '2650', 'id': '6675'}, {'name': 'Opportunity', 'cost': '2700', 'id': '6701'}, {'name': "Overlord's Bloodmail", 'cost': '3300', 'id': '2501'}, {'name': 'Phantom Dancer', 'cost': '2650', 'id': '3046'}, {'name': 'Profane Hydra', 'cost': '3200', 'id': '6698'}, {'name': "Rabadon's Deathcap", 'cost': '3500', 'id': '3089'}, {'name': "Randuin's Omen", 'cost': '2700', 'id': '3143'}, {'name': 'Rapid Firecannon', 'cost': '2650', 'id': '3094'}, {'name': 'Ravenous  ...

# %%
#10. Zeit bis first full Item - Continuation

#if item_id in items, then we take the first entry and take the costs and look how much gold per minute he has 

id_to_cost = {str(item['id']): int(item['cost']) for item in legendary_items if 'id' in item and 'cost' in item}
print(id_to_cost)

legendary_ids = set(id_to_cost.keys())

def first_legendary_stats(row):
    items = [str(row[f'item{i}']) for i in range(7) if f'item{i}' in row]
    for item in items:
        if item in legendary_ids:
            cost = id_to_cost[item]
            if cost >= 500:  # Filter out evolved support items, because they cost 400G and count as legendary
                gpm = row['goldPerMinute']
                minutes_needed = round(cost / gpm, 2) if gpm > 0 else None
                return pd.Series({
                    'first_legendary_id': item,
                    'first_legendary_cost': cost,
                    'first_legendary_minutes': minutes_needed
                })
    return pd.Series({'first_legendary_id': None, 'first_legendary_cost': None, 'first_legendary_minutes': None})

# Apply auf DataFrame:
df_ranked = df_ranked.join(df_ranked.apply(first_legendary_stats, axis=1))
df_ranked['first_legendary_id'] = df_ranked['first_legendary_id'].fillna(0)

print(df_ranked[['puuid','first_legendary_id', 'first_legendary_cost', 'first_legendary_minutes']].head(20))
# Out:
# {'8020': 2650, '3003': 2900, '3504': 2200, '6696': 3000, '3102': 3000, '3071': 3000, '2503': 2800, '3153': 3200, '8010': 2900, '3877': 400, '3072': 3400, '3867': 400, '3869': 400, '6609': 3100, '4629': 3000, '3137': 3000, '6621': 2500, '3742': 2900, '6333': 3300, '3870': 400, '6620': 2200, '6692': 2900, '3814': 3000, '3508': 2900, '3073': 3000, '3121': 2400, '4401': 2800, '3110': 2500, '3026': 3200, '3124': 3000, '3084': 3000, '3152': 2650, '6664': 2800, '4628': 2800, '6697': 3000, '3181': 3000, '6662': 2900, '6673': 3000, '4005': 2250, '3031': 3450, '6665': 3200, '2504': 2900, '3109': 2300, '6672': 3000, '6653': 3000, '3100': 2900, '3190': 2200, '3036': 3100, '6655': 2750, '3118': 2700, '3004': 2900, '3156': 3100, '3041': 1500, '3139': 3200, '3222': 2300, '6617': 2200, '3165': 2850, '3033': 3300, '3042': 2900, '3115': 2900, '6675': 2650, '6701': 2700, '2501': 3300, '3046': 2650, '6698': 3200, '3089': 3500, '3143': 2700, '3094': 2650, '3074': 3300, '3107': 2300, '4633': 3100, '6657': 2600, '3085': 2650, '3116': 2600, '3040': 2900, '6695': 2500, '6694': 3000, '4645': 3200, '2065': 2200, '3876': 400, '3161': 3100, '224004': 2800, '3065': 2700, '6616': 2250, '3087': 2700, '3053': 3200, '4646': 2800, '6631': 3300, '6610': 3100, '3068': 2700, '3302': 3000, '6676': 3000, '3075': 2450, '3748': 3300, '3002': 2400, '3078': 3333, '3179': 2500, '2502': 2800, '4643': 2300, '3135': 3000, '6699': 3000, '3083': 3100, '3119': 2400, '3091': 2800, '3142': 2800, '3032': 3000, '3871': 400, '3050': 2200, '3157': 3250}
#                                                 puuid first_legendary_id  \
# 0   VecACGBYGaYN4rYoAdHr3nox4uAZERedMRHLuR8lqj9Z0P...               6673
# 1   -WbLudFHyoIYrQJ6XV-5MtWisSVjjweLp8S19KcZXWh3uy...               3100
# 2   vYQLI-rTA_2HuEUjwW3CzaD3J6ozUP-hXU0ogVPeruCNmh...               2503
# 3   LKEJUSbX118NCvq71N5d2Lt2VIowd9fc0JKSEC_jSJkwA_...               3078
# 4   D0eNXuIl7MQsskZFlosVNWJqV1jZ3zyR5nLk3sCEgIUcAT...               3115
# 5   BOIe8vqhUfX27L0ES02Lp9xTRAUmQ8Xo-ng8xI0Dud0WB1...               3089
# 6   fgUmO3_kqZR3_nqvigkrL520DlCQZE5sG3TU2Df6bCL77G...               3157
# 7   YRvGMWX4Eco8OmxrRvY6i3t2CSJUU_A_YVK-Y7KSN4RPP1...               2503
# 8   c7R5Mgnp9my-gtl4UueChgdJOMtrWpTBE2_o3ZQhA-qcOY...               3071
# 9   tpghW4K0wr4o8ukEV6O7pOrU4-kfVzgdJPIl7fBk5iQb74...               6676
# 10  eXHFUFQ5CzboQ2iL0EKCzuvpcdMUNYcdlC7JYqfH9KPqli...               6610
# 11  MF9K9eKn81kgzVa0jz5_Tcs8rJuKBIe6jgoIXHQK05vwhz...               3078
# 12  lHamDyBYjAFje2EdLGYmdMrsl-6hAmzgX8-vqzBoTdt2O6...               6699
# 13  AwybzOVONeUyZOJFbMRCcA6K_1SA_wfaINcCBnCMLJHRYl...               4645
# 14  k-reKRJBMvs7X1cF5AUustJz0J0VK9xpquDjlixRMI1NXH...               3190
# 15  z1fRSZ14usYpyy7GOOKDEzWUi8Rrglj_ETJ_vwbRa6grP6...               3143
# 16  NjwmEH6MxK5oQc2aQQ7iO8vReUf7aWmD1OZGuCxWLAGf8Q...               6610
# 17  hJPtX6ka-ctW08BAyyHUEGLTHiPuPD2z_9yG2doCBRd8AV...               3089
# 18  2QtWBz1krghaAIiuRnpHhr-KnZjdU8f9n2VDufvSS7hU81...               6676
# 19  ifldNLBHimXJCniepyPQPkPNKOWXD73ShCXSW7PHR1gFZo...               3222
#
#     first_legendary_cost  first_legendary_minutes
# 0                   3000                     7.50
# 1                   2900                     7.10
# 2                   2800                     7.07
# 3                   3333                     8.98
# 4                   2900                     6.00
# 5                   3500                     6.27
# 6                   3250                     7.83
# 7                   2800                     8.02
# 8                   3000                     8.47
# 9                   3000                     9.71
# 10                  3100                    13.01
# 11                  3333                     7.88
# 12                  3000                     5.08
# 13                  3200                     9.78
# 14                  2200                     8.08
# 15                  2700                     7.74
# 16                  3100                     7.99
# 17                  3500                     7.63
# 18                  3000                     7.65
# 19                  2300                     8.81

# %%
#12. Off-Meta Champs 

with open("champtier.html", encoding="utf-8") as f:
    html = f.read()

soup = BeautifulSoup(html, "html.parser")

color_to_tier = {
    "#0093ff": "1",
    "#00bba3": "2",
    "#ffb900": "3",
    "#9aa4af": "4",
    "#a88a67": "5"
}

champ_data_tier = []

rows = soup.find_all('tr')

for row in rows:
    cols = row.find_all('td')
    if len(cols) < 8:
        continue
    tier = None
    svg_tag_tier = cols[2].find('svg')
    if svg_tag_tier:
        path_tag_tier = svg_tag_tier.find('path')
        if path_tag_tier and path_tag_tier.has_attr('fill'):
            color = path_tag_tier['fill'].lower()
            tier = color_to_tier.get(color)

    role = None
    svg_tag_role = cols[3].find('svg')
    if svg_tag_role:
        for path_tag_role in svg_tag_role.find_all('path'):
            d_code = path_tag_role.get('d', '').lower().strip()
            opacity = path_tag_role.get('opacity')
            # BOT/TOP Sonderfall:
            if d_code == "m19 3-4 4h7v8l-4 4v3z":
                if opacity == "0.2":
                    role = "BOT"
                else:
                    role = "TOP"
                break
            # Jungle
            elif "m5.14 2c1.58" in d_code:
                role = "JUNGLE"
                break
            # Mid
            elif "m15 3-4 4h7v4l-4 4v3z" in d_code:
                role = "MID"
                break
            # Utility
            elif "m12.833 10.833" in d_code or "14.5 17.53" in d_code:
                role = "UTILITY"
                break

    name_a = cols[1].find("a")
    name = name_a.text.strip() if name_a else cols[1].text.strip()
    winrate = cols[4].text.strip() if len(cols) > 4 else ""
    pickrate = cols[5].text.strip() if len(cols) > 5 else ""
    champ_data_tier.append({
        'champion': name,
        'role': role,
        'tier': tier,
        'winrate': winrate,
        'pickrate': pickrate
    })
for c in champ_data_tier:
    print(c)
# Out:
# {'champion': 'Trundle', 'role': 'JUNGLE', 'tier': '1', 'winrate': '53.27%', 'pickrate': '3.58%'}
# {'champion': 'Sett', 'role': 'TOP', 'tier': '1', 'winrate': '52.69%', 'pickrate': '9.72%'}
# {'champion': 'Milio', 'role': 'UTILITY', 'tier': '1', 'winrate': '52.64%', 'pickrate': '5.75%'}
# {'champion': 'Warwick', 'role': 'JUNGLE', 'tier': '1', 'winrate': '52.45%', 'pickrate': '7.26%'}
# {'champion': 'Yorick', 'role': 'TOP', 'tier': '1', 'winrate': '52.4%', 'pickrate': '6.25%'}
# {'champion': 'Mordekaiser', 'role': 'TOP', 'tier': '1', 'winrate': '52.37%', 'pickrate': '7.07%'}
# {'champion': 'Kayle', 'role': 'TOP', 'tier': '1', 'winrate': '52.29%', 'pickrate': '4.66%'}
# {'champion': 'Volibear', 'role': 'JUNGLE', 'tier': '1', 'winrate': '52.24%', 'pickrate': '4.96%'}
# {'champion': 'Nami', 'role': 'UTILITY', 'tier': '1', 'winrate': '52.15%', 'pickrate': '9.14%'}
# {'champion': 'Nocturne', 'role': 'JUNGLE', 'tier': '1', 'winrate': '52.06%', 'pickrate': '8.99%'}
# {'champion': 'Malzahar', 'role': 'MID', 'tier': '1', 'winrate': '52.01%', 'pickrate': '6.95%'}
# {'champion': 'Braum', 'role': 'UTILITY', 'tier': '1', 'winrate': '51.87%', 'pickrate': '6.01%'}
# {'champion': 'Xerath', 'role': 'MID', 'tier': '1', 'winrate': '51.73%', 'pickrate': '3.68%'}
# {'champion': 'Diana', 'role': 'MID', 'tier': '1', 'winrate': '51.62%', 'pickrate': '4.86%'}
# {'champion': 'Galio', 'role': 'MID', 'tier': '1', 'winrate': '51.47%', 'pickrate': '4.37%'}
# {'champion': 'Jinx', 'role': 'BOT', 'tier': '1', 'winrate': '51.46%', 'pickrate': '13.5%'}
# {'champion': 'Veigar', 'role': 'MID', 'tier': '1', 'winrate': '51.4%', 'pickrate': '4.96%'}
# {'champion': 'Morgana', 'role': 'UTILITY', 'tier': '1', 'winrate': '51.33%', 'pickrate': '7.43%'}
# {'champion': 'Miss Fortune', 'role': 'BOT', 'tier': '1', 'winrate': '51.25%', 'pickrate': '12.95%'}
# {'champion': 'Lux', 'role': 'MID', 'tier': '1', 'winrate': '51.13%', 'pickrate': '5.24%'}
# {'champion': 'Leona', 'role': 'UTILITY', 'tier': '1', 'winrate': '51.09%', 'pickrate': '7.3%'}
# {'champion': 'Dr. Mundo', 'role': 'TOP', 'tier': '1', 'winrate': '50.86%', 'pickrate': '9.03%'}
# {'champion': 'Yasuo', 'role': 'MID', 'tier': '1', 'winrate': '50.85%', 'pickrate': '10.09%'}
# {'champion': 'Lulu', 'role': 'UTILITY', 'tier': '1', 'winrate': '50.76%', 'pickrate': '8.82%'}
# {'champion': 'Twisted Fate', 'role': 'MID', 'tier': '1', 'winrate': '50.75%', 'pickrate': '7.53%'}
# {'champion': 'Thresh', 'role': 'UTILITY', 'tier': '1', 'winrate': '50.32%', 'pickrate': '9.82%'}
# {'champion': 'Lux', 'role': 'UTILITY', 'tier': '1', 'winrate': '49.99%', 'pickrate': '12.02%'}
# {'champion': 'Nilah', 'role': 'BOT', 'tier': '2', 'winrate': '53.85%', 'pickrate': '2.09%'}
# {'champion': 'Kayle', 'role': 'MID', 'tier': '2', 'winrate': '52.63%', 'pickrate': '1.42%'}
# {'champion': 'Naafiri', 'role': 'MID', 'tier': '2', 'winrate': '52.57%', 'pickrate': '1.12%'}
# {'champion': 'Sona', 'role': 'UTILITY', 'tier': '2', 'winrate': '52.49%', 'pickrate': '2.84%'}
# {'champion': 'Malphite', 'role': 'MID', 'tier': '2', 'winrate': '52.28%', 'pickrate': '1.19%'}
# {'champion': 'Jax', 'role': 'JUNGLE', 'tier': '2', 'winrate': '52.23%', 'pickrate': '2.26%'}
# {'champion': 'Briar', 'role': 'JUNGLE', 'tier': '2', 'winrate': '52.19%', 'pickrate': '4.08%'}
# {'champion': 'Sivir', 'role': 'BOT', 'tier': '2', 'winrate': '52.17%', 'pickrate': '5.92%'}
# {'champion': 'Warwick', 'role': 'TOP', 'tier': '2', 'winrate': '52.11%', 'pickrate': '2.19%'}
# {'champion': 'Urgot', 'role': 'TOP', 'tier': '2', 'winrate': '51.98%', 'pickrate': '2.93%'}
# {'champion': 'Jarvan IV.', 'role': 'JUNGLE', 'tier': '2', 'winrate': '51.59%', 'pickrate': '4.83%'}
# {'champion': 'Soraka', 'role': 'UTILITY', 'tier': '2', 'winrate': '51.59%', 'pickrate': '4.39%'}
# {'champion': 'Amumu', 'role': 'JUNGLE', 'tier': '2', 'winrate': '51.57%', 'pickrate': '4.39%'}
# {'champion': "Cho'Gath", 'role': 'TOP', 'tier': '2', 'winrate': '51.47%', 'pickrate': '3.76%'}
# {'champion': 'Malphite', 'role': 'TOP', 'tier': '2', 'winrate': '51.47%', 'pickrate': '5.25%'}
# {'champion': 'Nasus', 'role': 'TOP', 'tier': '2', 'winrate': '51.39%', 'pickrate': '4.31%'}
# {'champion': 'Teemo', 'role': 'TOP', 'tier': '2', 'winrate': '51.36%', 'pickrate': '5.23%'}
# {'champion': 'Smolder', 'role': 'BOT', 'tier': '2', 'winrate': '51.33%', 'pickrate': '8.28%'}
# {'champion': 'Wukong', 'role': 'JUNGLE', 'tier': '2', 'winrate': '51.32%', 'pickrate': '3.09%'}
# {'champion': 'Vex', 'role': 'MID', 'tier': '2', 'winrate': '51.3%', 'pickrate': '3.96%'}
# {'champion': 'Ekko', 'role': 'MID', 'tier': '2', 'winrate': '51.29%', 'pickrate': '3.46%'}
# {'champion': 'Zyra', 'role': 'UTILITY', 'tier': '2', 'winrate': '51.14%', 'pickrate': '4%'}
# {'champion': 'Ornn', 'role': 'TOP', 'tier': '2', 'winrate': '51.14%', 'pickrate': '3%'}
# {'champion': 'Vayne', 'role': 'BOT', 'tier': '2', 'winrate': '51.04%', 'pickrate': '8.66%'}
# {'champion': 'Vladimir', 'role': 'MID', 'tier': '2', 'winrate': '51.02%', 'pickrate': '4%'}
# {'champion': 'Fizz', 'role': 'MID', 'tier': '2', 'winrate': '50.81%', 'pickrate': '4.19%'}
# {'champion': 'Diana', 'role': 'JUNGLE', 'tier': '2', 'winrate': '50.65%', 'pickrate': '6.82%'}
# {'champion': 'Trundle', 'role': 'TOP', 'tier': '2', 'winrate': '50.61%', 'pickrate': '3.24%'}
# {'champion': 'Xin Zhao', 'role': 'JUNGLE', 'tier': '2', 'winrate': '50.59%', 'pickrate': '5.81%'}
# {'champion': 'Senna', 'role': 'BOT', 'tier': '2', 'winrate': '50.51%', 'pickrate': '8.08%'}
# {'champion': 'Master Yi', 'role': 'JUNGLE', 'tier': '2', 'winrate': '50.48%', 'pickrate': '7.06%'}
# {'champion': 'Garen', 'role': 'TOP', 'tier': '2', 'winrate': '50.47%', 'pickrate': '5.53%'}
# {'champion': 'Sion', 'role': 'TOP', 'tier': '2', 'winrate': '50.45%', 'pickrate': '4.69%'}
# {'champion': 'Ekko', 'role': 'JUNGLE', 'tier': '2', 'winrate': '50.4%', 'pickrate': '5.41%'}
# {'champion': 'Kayn', 'role': 'JUNGLE', 'tier': '2', 'winrate': '50.35%', 'pickrate': '9.74%'}
# {'champion': 'Syndra', 'role': 'MID', 'tier': '2', 'winrate': '50.32%', 'pickrate': '3.82%'}
# {'champion': 'Shen', 'role': 'TOP', 'tier': '2', 'winrate': '50.29%', 'pickrate': '5.12%'}
# {'champion': 'Jhin', 'role': 'BOT', 'tier': '2', 'winrate': '50.26%', 'pickrate': '15.26%'}
# {'champion': 'Jax', 'role': 'TOP', 'tier': '2', 'winrate': '50.14%', 'pickrate': '5.79%'}
# {'champion': 'Renekton', 'role': 'TOP', 'tier': '2', 'winrate': '50.13%', 'pickrate': '5.4%'}
# {'champion': 'Pantheon', 'role': 'JUNGLE', 'tier': '2', 'winrate': '50.05%', 'pickrate': '5.95%'}
# {'champion': "Kha'Zix", 'role': 'JUNGLE', 'tier': '2', 'winrate': '50.03%', 'pickrate': '5.9%'}
# {'champion': 'Viego', 'role': 'JUNGLE', 'tier': '2', 'winrate': '49.93%', 'pickrate': '11.8%'}
# {'champion': 'Akali', 'role': 'MID', 'tier': '2', 'winrate': '49.87%', 'pickrate': '7.34%'}
# {'champion': 'Viktor', 'role': 'MID', 'tier': '2', 'winrate': '49.77%', 'pickrate': '4.81%'}
# {'champion': 'Lucian', 'role': 'BOT', 'tier': '2', 'winrate': '49.66%', 'pickrate': '12.43%'}
# {'champion': 'LeBlanc', 'role': 'MID', 'tier': '2', 'winrate': '49.61%', 'pickrate': '5.42%'}
# {'champion': 'Lee Sin', 'role': 'JUNGLE', 'tier': '2', 'winrate': '49.57%', 'pickrate': '12.07%'}
# {'champion': 'Caitlyn', 'role': 'BOT', 'tier': '2', 'winrate': '49.57%', 'pickrate': '15.43%'}
# {'champion': 'Sylas', 'role': 'MID', 'tier': '2', 'winrate': '49.55%', 'pickrate': '8.21%'}
# {'champion': 'Nautilus', 'role': 'UTILITY', 'tier': '2', 'winrate': '49.38%', 'pickrate': '9.34%'}
# {'champion': 'Shaco', 'role': 'JUNGLE', 'tier': '2', 'winrate': '49.18%', 'pickrate': '6.69%'}
# {'champion': 'Aatrox', 'role': 'TOP', 'tier': '2', 'winrate': '49.06%', 'pickrate': '7.74%'}
# {'champion': 'Ahri', 'role': 'MID', 'tier': '2', 'winrate': '49.01%', 'pickrate': '8.97%'}
# {'champion': 'Darius', 'role': 'TOP', 'tier': '2', 'winrate': '48.65%', 'pickrate': '6.82%'}
# {'champion': 'Zed', 'role': 'MID', 'tier': '2', 'winrate': '48.51%', 'pickrate': '7.17%'}
# {'champion': "Kog'Maw", 'role': 'BOT', 'tier': '3', 'winrate': '52.89%', 'pickrate': '1.62%'}
# {'champion': 'Yorick', 'role': 'JUNGLE', 'tier': '3', 'winrate': '52.66%', 'pickrate': '0.53%'}
# {'champion': 'Taric', 'role': 'UTILITY', 'tier': '3', 'winrate': '52.58%', 'pickrate': '1.22%'}
# {'champion': 'Mordekaiser', 'role': 'JUNGLE', 'tier': '3', 'winrate': '52.57%', 'pickrate': '0.68%'}
# {'champion': 'Quinn', 'role': 'MID', 'tier': '3', 'winrate': '52.49%', 'pickrate': '0.69%'}
# {'champion': 'Teemo', 'role': 'UTILITY', 'tier': '3', 'winrate': '52.26%', 'pickrate': '1.29%'}
# {'champion': 'Yasuo', 'role': 'BOT', 'tier': '3', 'winrate': '52.24%', 'pickrate': '1.04%'}
# {'champion': 'Heimerdinger', 'role': 'MID', 'tier': '3', 'winrate': '52.24%', 'pickrate': '0.74%'}
# {'champion': 'Swain', 'role': 'MID', 'tier': '3', 'winrate': '51.64%', 'pickrate': '1.01%'}
# {'champion': 'Pantheon', 'role': 'MID', 'tier': '3', 'winrate': '51.61%', 'pickrate': '1.03%'}
# {'champion': 'Dr. Mundo', 'role': 'JUNGLE', 'tier': '3', 'winrate': '51.59%', 'pickrate': '1.49%'}
# {'champion': 'Janna', 'role': 'UTILITY', 'tier': '3', 'winrate': '51.56%', 'pickrate': '2.48%'}
# {'champion': 'Zilean', 'role': 'UTILITY', 'tier': '3', 'winrate': '51.46%', 'pickrate': '2.13%'}
# {'champion': 'Singed', 'role': 'TOP', 'tier': '3', 'winrate': '51.22%', 'pickrate': '1.54%'}
# {'champion': 'Quinn', 'role': 'TOP', 'tier': '3', 'winrate': '51.18%', 'pickrate': '1.83%'}
# {'champion': 'Maokai', 'role': 'UTILITY', 'tier': '3', 'winrate': '51.14%', 'pickrate': '2%'}
# {'champion': "Vel'Koz", 'role': 'UTILITY', 'tier': '3', 'winrate': '51.11%', 'pickrate': '3.01%'}
# {'champion': 'Heimerdinger', 'role': 'TOP', 'tier': '3', 'winrate': '51.03%', 'pickrate': '1.7%'}
# {'champion': 'Aurelion Sol', 'role': 'MID', 'tier': '3', 'winrate': '50.97%', 'pickrate': '2.23%'}
# {'champion': 'Rell', 'role': 'UTILITY', 'tier': '3', 'winrate': '50.94%', 'pickrate': '3.86%'}
# {'champion': 'Bard', 'role': 'UTILITY', 'tier': '3', 'winrate': '50.9%', 'pickrate': '2.99%'}
# {'champion': 'Poppy', 'role': 'UTILITY', 'tier': '3', 'winrate': '50.87%', 'pickrate': '2.23%'}
# {'champion': 'Anivia', 'role': 'MID', 'tier': '3', 'winrate': '50.86%', 'pickrate': '1.49%'}
# {'champion': 'Twitch', 'role': 'BOT', 'tier': '3', 'winrate': '50.82%', 'pickrate': '4%'}
# {'champion': 'Shaco', 'role': 'UTILITY', 'tier': '3', 'winrate': '50.78%', 'pickrate': '2.32%'}
# {'champion': 'Shyvana', 'role': 'JUNGLE', 'tier': '3', 'winrate': '50.75%', 'pickrate': '1.91%'}
# {'champion': 'Annie', 'role': 'MID', 'tier': '3', 'winrate': '50.73%', 'pickrate': '2.36%'}
# {'champion': 'Lissandra', 'role': 'MID', 'tier': '3', 'winrate': '50.62%', 'pickrate': '2.62%'}
# {'champion': 'Brand', 'role': 'UTILITY', 'tier': '3', 'winrate': '50.61%', 'pickrate': '3.18%'}
# {'champion': 'Zeri', 'role': 'BOT', 'tier': '3', 'winrate': '50.6%', 'pickrate': '5.06%'}
# {'champion': 'Samira', 'role': 'BOT', 'tier': '3', 'winrate': '50.58%', 'pickrate': '6.43%'}
# {'champion': 'Xerath', 'role': 'UTILITY', 'tier': '3', 'winrate': '50.56%', 'pickrate': '4.12%'}
# {'champion': 'Tristana', 'role': 'BOT', 'tier': '3', 'winrate': '50.32%', 'pickrate': '8.14%'}
# {'champion': 'Xayah', 'role': 'BOT', 'tier': '3', 'winrate': '50.29%', 'pickrate': '4.51%'}
# {'champion': 'Aphelios', 'role': 'BOT', 'tier': '3', 'winrate': '50.23%', 'pickrate': '5.88%'}
# {'champion': 'Illaoi', 'role': 'TOP', 'tier': '3', 'winrate': '50.2%', 'pickrate': '2.98%'}
# {'champion': 'Fiora', 'role': 'TOP', 'tier': '3', 'winrate': '50.19%', 'pickrate': '3.44%'}
# {'champion': 'Pantheon', 'role': 'TOP', 'tier': '3', 'winrate': '50.07%', 'pickrate': '2.08%'}
# {'champion': 'Alistar', 'role': 'UTILITY', 'tier': '3', 'winrate': '50.02%', 'pickrate': '4.39%'}
# {'champion': 'Hwei', 'role': 'MID', 'tier': '3', 'winrate': '49.95%', 'pickrate': '3.59%'}
# {'champion': 'Lillia', 'role': 'JUNGLE', 'tier': '3', 'winrate': '49.93%', 'pickrate': '3.89%'}
# {'champion': 'Nunu & Willump', 'role': 'JUNGLE', 'tier': '3', 'winrate': '49.93%', 'pickrate': '2.62%'}
# {'champion': 'Pantheon', 'role': 'UTILITY', 'tier': '3', 'winrate': '49.9%', 'pickrate': '3.78%'}
# {'champion': 'Swain', 'role': 'UTILITY', 'tier': '3', 'winrate': '49.85%', 'pickrate': '3.67%'}
# {'champion': 'Naafiri', 'role': 'JUNGLE', 'tier': '3', 'winrate': '49.83%', 'pickrate': '3.85%'}
# {'champion': 'Volibear', 'role': 'TOP', 'tier': '3', 'winrate': '49.81%', 'pickrate': '3.3%'}
# {'champion': 'Aurora', 'role': 'MID', 'tier': '3', 'winrate': '49.76%', 'pickrate': '3.07%'}
# {'champion': 'Rakan', 'role': 'UTILITY', 'tier': '3', 'winrate': '49.76%', 'pickrate': '3.51%'}
# {'champion': 'Karma', 'role': 'UTILITY', 'tier': '3', 'winrate': '49.69%', 'pickrate': '5.78%'}
# {'champion': 'Irelia', 'role': 'TOP', 'tier': '3', 'winrate': '49.66%', 'pickrate': '3.39%'}
# {'champion': 'Ashe', 'role': 'BOT', 'tier': '3', 'winrate': '49.65%', 'pickrate': '9.21%'}
# {'champion': 'Riven', 'role': 'TOP', 'tier': '3', 'winrate': '49.58%', 'pickrate': '3.29%'}
# {'champion': 'Tahm Kench', 'role': 'UTILITY', 'tier': '3', 'winrate': '49.57%', 'pickrate': '3.08%'}
# {'champion': 'Graves', 'role': 'JUNGLE', 'tier': '3', 'winrate': '49.52%', 'pickrate': '4.8%'}
# {'champion': 'Blitzcrank', 'role': 'UTILITY', 'tier': '3', 'winrate': '49.49%', 'pickrate': '5.48%'}
# {'champion': 'Zoe', 'role': 'MID', 'tier': '3', 'winrate': '49.44%', 'pickrate': '3.17%'}
# {'champion': 'Orianna', 'role': 'MID', 'tier': '3', 'winrate': '49.36%', 'pickrate': '3.59%'}
# {'champion': 'Vi', 'role': 'JUNGLE', 'tier': '3', 'winrate': '49.35%', 'pickrate': '5.32%'}
# {'champion': 'Katarina', 'role': 'MID', 'tier': '3', 'winrate': '49.23%', 'pickrate': '5.34%'}
# {'champion': 'Yasuo', 'role': 'TOP', 'tier': '3', 'winrate': '49.23%', 'pickrate': '3.04%'}
# {'champion': 'Seraphine', 'role': 'UTILITY', 'tier': '3', 'winrate': '49.16%', 'pickrate': '4.67%'}
# {'champion': 'Yuumi', 'role': 'UTILITY', 'tier': '3', 'winrate': '49.15%', 'pickrate': '5.87%'}
# {'champion': 'Pyke', 'role': 'UTILITY', 'tier': '3', 'winrate': '48.72%', 'pickrate': '5.81%'}
# {'champion': "Kai'Sa", 'role': 'BOT', 'tier': '3', 'winrate': '48.51%', 'pickrate': '16.18%'}
# {'champion': 'Mel', 'role': 'MID', 'tier': '3', 'winrate': '48.36%', 'pickrate': '5.9%'}
# {'champion': 'Yone', 'role': 'MID', 'tier': '3', 'winrate': '48.23%', 'pickrate': '6.8%'}
# {'champion': 'Ezreal', 'role': 'BOT', 'tier': '3', 'winrate': '47.59%', 'pickrate': '13.69%'}
# {'champion': 'Yone', 'role': 'TOP', 'tier': '3', 'winrate': '47.56%', 'pickrate': '4.83%'}
# {'champion': 'Swain', 'role': 'BOT', 'tier': '4', 'winrate': '53.35%', 'pickrate': '0.54%'}
# {'champion': 'Malzahar', 'role': 'TOP', 'tier': '4', 'winrate': '52.19%', 'pickrate': '0.65%'}
# {'champion': 'Morgana', 'role': 'MID', 'tier': '4', 'winrate': '51.83%', 'pickrate': '0.64%'}
# {'champion': 'Veigar', 'role': 'BOT', 'tier': '4', 'winrate': '51.81%', 'pickrate': '0.52%'}
# {'champion': 'Fiddlesticks', 'role': 'UTILITY', 'tier': '4', 'winrate': '51.63%', 'pickrate': '0.8%'}
# {'champion': 'Kennen', 'role': 'MID', 'tier': '4', 'winrate': '51.58%', 'pickrate': '0.85%'}
# {'champion': 'Zac', 'role': 'TOP', 'tier': '4', 'winrate': '51.48%', 'pickrate': '0.64%'}
# {'champion': "Cho'Gath", 'role': 'MID', 'tier': '4', 'winrate': '51.37%', 'pickrate': '0.71%'}
# {'champion': 'Wukong', 'role': 'TOP', 'tier': '4', 'winrate': '51.27%', 'pickrate': '0.84%'}
# {'champion': "Vel'Koz", 'role': 'MID', 'tier': '4', 'winrate': '51%', 'pickrate': '1.1%'}
# {'champion': 'Teemo', 'role': 'JUNGLE', 'tier': '4', 'winrate': '50.92%', 'pickrate': '1.14%'}
# {'champion': 'Olaf', 'role': 'TOP', 'tier': '4', 'winrate': '50.8%', 'pickrate': '1.52%'}
# {'champion': 'Shen', 'role': 'UTILITY', 'tier': '4', 'winrate': '50.71%', 'pickrate': '1.29%'}
# {'champion': 'LeBlanc', 'role': 'UTILITY', 'tier': '4', 'winrate': '50.69%', 'pickrate': '0.79%'}
# {'champion': 'Elise', 'role': 'UTILITY', 'tier': '4', 'winrate': '50.54%', 'pickrate': '1.17%'}
# {'champion': 'Poppy', 'role': 'JUNGLE', 'tier': '4', 'winrate': '50.47%', 'pickrate': '1.03%'}
# {'champion': 'Galio', 'role': 'UTILITY', 'tier': '4', 'winrate': '50.44%', 'pickrate': '0.85%'}
# {'champion': 'Poppy', 'role': 'TOP', 'tier': '4', 'winrate': '50.4%', 'pickrate': '0.94%'}
# {'champion': 'Brand', 'role': 'MID', 'tier': '4', 'winrate': '50.39%', 'pickrate': '1.01%'}
# {'champion': 'Kled', 'role': 'TOP', 'tier': '4', 'winrate': '50.33%', 'pickrate': '1.17%'}
# {'champion': 'Ziggs', 'role': 'BOT', 'tier': '4', 'winrate': '50.24%', 'pickrate': '1.08%'}
# {'champion': 'Ivern', 'role': 'JUNGLE', 'tier': '4', 'winrate': '50.16%', 'pickrate': '1.12%'}
# {'champion': 'Elise', 'role': 'JUNGLE', 'tier': '4', 'winrate': '50.07%', 'pickrate': '1.95%'}
# {'champion': 'Kassadin', 'role': 'MID', 'tier': '4', 'winrate': '50.02%', 'pickrate': '1.74%'}
# {'champion': 'Kennen', 'role': 'TOP', 'tier': '4', 'winrate': '49.86%', 'pickrate': '1.71%'}
# {'champion': 'Rammus', 'role': 'JUNGLE', 'tier': '4', 'winrate': '49.78%', 'pickrate': '2.52%'}
# {'champion': 'Akshan', 'role': 'MID', 'tier': '4', 'winrate': '49.78%', 'pickrate': '2.06%'}
# {'champion': 'Fiddlesticks', 'role': 'JUNGLE', 'tier': '4', 'winrate': '49.7%', 'pickrate': '2.18%'}
# {'champion': 'Cassiopeia', 'role': 'MID', 'tier': '4', 'winrate': '49.62%', 'pickrate': '1.18%'}
# {'champion': 'Akali', 'role': 'TOP', 'tier': '4', 'winrate': '49.61%', 'pickrate': '1.28%'}
# {'champion': 'Ryze', 'role': 'MID', 'tier': '4', 'winrate': '49.56%', 'pickrate': '2.71%'}
# {'champion': 'Evelynn', 'role': 'JUNGLE', 'tier': '4', 'winrate': '49.55%', 'pickrate': '2.78%'}
# {'champion': 'Tahm Kench', 'role': 'TOP', 'tier': '4', 'winrate': '49.53%', 'pickrate': '1.17%'}
# {'champion': 'Renata Glasc', 'role': 'UTILITY', 'tier': '4', 'winrate': '49.53%', 'pickrate': '1.15%'}
# {'champion': 'Vladimir', 'role': 'TOP', 'tier': '4', 'winrate': '49.5%', 'pickrate': '2.21%'}
# {'champion': "Bel'Veth", 'role': 'JUNGLE', 'tier': '4', 'winrate': '49.32%', 'pickrate': '1.65%'}
# {'champion': 'Mel', 'role': 'BOT', 'tier': '4', 'winrate': '49.28%', 'pickrate': '1.15%'}
# {'champion': 'Camille', 'role': 'TOP', 'tier': '4', 'winrate': '49.26%', 'pickrate': '2.17%'}
# {'champion': 'Zac', 'role': 'JUNGLE', 'tier': '4', 'winrate': '49.23%', 'pickrate': '2.88%'}
# {'champion': 'Tryndamere', 'role': 'TOP', 'tier': '4', 'winrate': '49.22%', 'pickrate': '2.52%'}
# {'champion': 'Udyr', 'role': 'JUNGLE', 'tier': '4', 'winrate': '49.15%', 'pickrate': '2.48%'}
# {'champion': 'Gragas', 'role': 'TOP', 'tier': '4', 'winrate': '49.15%', 'pickrate': '2.06%'}
# {'champion': 'Irelia', 'role': 'MID', 'tier': '4', 'winrate': '49.12%', 'pickrate': '2.72%'}
# {'champion': 'Talon', 'role': 'JUNGLE', 'tier': '4', 'winrate': '49.11%', 'pickrate': '2.83%'}
# {'champion': 'Sylas', 'role': 'UTILITY', 'tier': '4', 'winrate': '49.06%', 'pickrate': '1.04%'}
# {'champion': 'Sejuani', 'role': 'JUNGLE', 'tier': '4', 'winrate': '49.02%', 'pickrate': '2.44%'}
# {'champion': 'Draven', 'role': 'BOT', 'tier': '4', 'winrate': '49.02%', 'pickrate': '3.2%'}
# {'champion': 'Talon', 'role': 'MID', 'tier': '4', 'winrate': '48.77%', 'pickrate': '1.9%'}
# {'champion': 'Corki', 'role': 'BOT', 'tier': '4', 'winrate': '48.63%', 'pickrate': '1.14%'}
# {'champion': 'Kindred', 'role': 'JUNGLE', 'tier': '4', 'winrate': '48.59%', 'pickrate': '2.83%'}
# {'champion': 'Gangplank', 'role': 'TOP', 'tier': '4', 'winrate': '48.53%', 'pickrate': '2.92%'}
# {'champion': 'Hecarim', 'role': 'JUNGLE', 'tier': '4', 'winrate': '48.47%', 'pickrate': '3.16%'}
# {'champion': 'Neeko', 'role': 'UTILITY', 'tier': '4', 'winrate': '48.44%', 'pickrate': '2.9%'}
# {'champion': 'Gnar', 'role': 'TOP', 'tier': '4', 'winrate': '48.36%', 'pickrate': '2.57%'}
# {'champion': 'Jayce', 'role': 'TOP', 'tier': '4', 'winrate': '48.08%', 'pickrate': '3.34%'}
# {'champion': 'Vayne', 'role': 'TOP', 'tier': '4', 'winrate': '48.07%', 'pickrate': '1.95%'}
# {'champion': 'Ambessa', 'role': 'TOP', 'tier': '4', 'winrate': '47.9%', 'pickrate': '3.07%'}
# {'champion': 'Gwen', 'role': 'TOP', 'tier': '4', 'winrate': '47.85%', 'pickrate': '2.93%'}
# {'champion': 'Senna', 'role': 'UTILITY', 'tier': '4', 'winrate': '47.75%', 'pickrate': '4.8%'}
# {'champion': 'Zed', 'role': 'JUNGLE', 'tier': '4', 'winrate': '47.3%', 'pickrate': '4.53%'}
# {'champion': 'Varus', 'role': 'BOT', 'tier': '4', 'winrate': '47.04%', 'pickrate': '5.43%'}
# {'champion': 'Mel', 'role': 'UTILITY', 'tier': '4', 'winrate': '46.84%', 'pickrate': '4.49%'}
# {'champion': 'Ryze', 'role': 'TOP', 'tier': '5', 'winrate': '49.94%', 'pickrate': '0.83%'}
# {'champion': 'Nasus', 'role': 'JUNGLE', 'tier': '5', 'winrate': '49.58%', 'pickrate': '0.57%'}
# {'champion': 'Neeko', 'role': 'MID', 'tier': '5', 'winrate': '49.52%', 'pickrate': '0.75%'}
# {'champion': 'Zoe', 'role': 'UTILITY', 'tier': '5', 'winrate': '49.52%', 'pickrate': '0.65%'}
# {'champion': 'Darius', 'role': 'JUNGLE', 'tier': '5', 'winrate': '49.48%', 'pickrate': '0.61%'}
# {'champion': 'Zyra', 'role': 'JUNGLE', 'tier': '5', 'winrate': '49.47%', 'pickrate': '0.52%'}
# {'champion': "Rek'Sai", 'role': 'JUNGLE', 'tier': '5', 'winrate': '49.22%', 'pickrate': '0.77%'}
# {'champion': 'Aurora', 'role': 'TOP', 'tier': '5', 'winrate': '49.03%', 'pickrate': '0.55%'}
# {'champion': 'Varus', 'role': 'TOP', 'tier': '5', 'winrate': '48.62%', 'pickrate': '0.95%'}
# {'champion': 'Gragas', 'role': 'JUNGLE', 'tier': '5', 'winrate': '48.57%', 'pickrate': '0.84%'}
# {'champion': 'Ziggs', 'role': 'MID', 'tier': '5', 'winrate': '48.56%', 'pickrate': '0.78%'}
# {'champion': 'Karthus', 'role': 'JUNGLE', 'tier': '5', 'winrate': '48.32%', 'pickrate': '1.41%'}
# {'champion': 'Jayce', 'role': 'MID', 'tier': '5', 'winrate': '48.24%', 'pickrate': '0.65%'}
# {'champion': 'Sylas', 'role': 'TOP', 'tier': '5', 'winrate': '48.17%', 'pickrate': '1.35%'}
# {'champion': 'Hwei', 'role': 'UTILITY', 'tier': '5', 'winrate': '48.09%', 'pickrate': '0.66%'}
# {'champion': 'Malphite', 'role': 'UTILITY', 'tier': '5', 'winrate': '48.05%', 'pickrate': '1.34%'}
# {'champion': 'Taliyah', 'role': 'MID', 'tier': '5', 'winrate': '47.98%', 'pickrate': '1.58%'}
# {'champion': 'Qiyana', 'role': 'MID', 'tier': '5', 'winrate': '47.98%', 'pickrate': '1.88%'}
# {'champion': 'Gwen', 'role': 'JUNGLE', 'tier': '5', 'winrate': '47.85%', 'pickrate': '1.48%'}
# {'champion': 'Veigar', 'role': 'UTILITY', 'tier': '5', 'winrate': '47.52%', 'pickrate': '0.71%'}
# {'champion': 'Tristana', 'role': 'MID', 'tier': '5', 'winrate': '47.24%', 'pickrate': '0.67%'}
# {'champion': 'Varus', 'role': 'MID', 'tier': '5', 'winrate': '47.16%', 'pickrate': '0.5%'}
# {'champion': 'Smolder', 'role': 'MID', 'tier': '5', 'winrate': '46.7%', 'pickrate': '1.27%'}
# {'champion': 'Smolder', 'role': 'TOP', 'tier': '5', 'winrate': '46.63%', 'pickrate': '0.91%'}
# {'champion': "K'Sante", 'role': 'TOP', 'tier': '5', 'winrate': '46.48%', 'pickrate': '2.85%'}
# {'champion': 'Nidalee', 'role': 'JUNGLE', 'tier': '5', 'winrate': '46.4%', 'pickrate': '2.31%'}
# {'champion': 'Ashe', 'role': 'UTILITY', 'tier': '5', 'winrate': '46.07%', 'pickrate': '1.22%'}
# {'champion': 'Rengar', 'role': 'JUNGLE', 'tier': '5', 'winrate': '45.91%', 'pickrate': '2.26%'}
# {'champion': 'Azir', 'role': 'MID', 'tier': '5', 'winrate': '45.79%', 'pickrate': '2.37%'}
# {'champion': 'Rumble', 'role': 'TOP', 'tier': '5', 'winrate': '45.52%', 'pickrate': '1.37%'}
# {'champion': 'Corki', 'role': 'MID', 'tier': '5', 'winrate': '45.25%', 'pickrate': '0.52%'}
# {'champion': 'Kalista', 'role': 'BOT', 'tier': '5', 'winrate': '45.04%', 'pickrate': '1.2%'}
# {'champion': 'Skarner', 'role': 'JUNGLE', 'tier': '5', 'winrate': '43.4%', 'pickrate': '0.72%'}
# {'champion': 'Udyr', 'role': 'TOP', 'tier': '5', 'winrate': '41.64%', 'pickrate': '0.9%'}

# %%
#12. Off-Meta Champs -- Continuation
#If champ is tier 4 or 5 and pickrate is <1% then it is called off meta
#If champ + role combo is not in the list --> OffMeta too

meta_df = pd.DataFrame(champ_data_tier)

meta_df['pickrate_float'] = meta_df['pickrate'].str.replace('%', '').str.replace(',', '.').astype(float)

valid_combos = set(zip(meta_df['champion'], meta_df['role']))

def is_offmeta(row):
    champ = row['championName']
    role = row['teamPosition']
    meta_row = meta_df[(meta_df['champion'] == champ) & (meta_df['role'] == role)]
    if (champ, role) not in valid_combos:
        return True
    if not meta_row.empty:
        tier = meta_row.iloc[0]['tier']
        pickrate = meta_row.iloc[0]['pickrate_float']
        if (tier in ['4', '5']) and (pickrate < 1):
            return True
    return False

df_ranked['offmeta'] = df_ranked.apply(is_offmeta, axis=1)
display(df_ranked[["offmeta","puuid"]])
# Out:
#     offmeta                                              puuid
# 0      True  VecACGBYGaYN4rYoAdHr3nox4uAZERedMRHLuR8lqj9Z0P...
# 1      True  -WbLudFHyoIYrQJ6XV-5MtWisSVjjweLp8S19KcZXWh3uy...
# 2      True  vYQLI-rTA_2HuEUjwW3CzaD3J6ozUP-hXU0ogVPeruCNmh...
# 3      True  LKEJUSbX118NCvq71N5d2Lt2VIowd9fc0JKSEC_jSJkwA_...
# 4      True  D0eNXuIl7MQsskZFlosVNWJqV1jZ3zyR5nLk3sCEgIUcAT...
# ..      ...                                                ...
# 65     True  dSZRDHIK7sETNR2q_uodXNnJHMdu1uOvc3Lua4yqO-9P6B...
# 66     True  9KJqaSylw0NdkCxIBGyVSa2Nz9fAm1jUAP-vzadxoRg64x...
# 67     True  n4Ez80e-i6GgYeUeYkwDu32uJBPjhY6VwiB1WeY2X7SQrB...
# 68     True  3SfUU280VeZwGsmCJhmU7wFYdA6A6m38IvKPPebWD96GSY...
# 69     True  2rgIXCcnaYUzP-86OXVh0LQg0moZpWzlAzfCJUrk36_Krf...
#
# [70 rows x 2 columns]

# %%
#13. Anteil der Spiele mit über 20 Kills

kills_threshold = 20

games_with_over_kills = df_ranked.groupby('puuid')['kills'].apply(lambda x: (x > kills_threshold).mean()).reset_index()
games_with_over_kills.rename(columns={'kills': f'rate_games_over_{kills_threshold}kills'}, inplace=True)

df_ranked = df_ranked.merge(games_with_over_kills, on='puuid', how='left')

print(df_ranked[['puuid', f'rate_games_over_{kills_threshold}kills']].head())
# Out:
#                                                puuid  rate_games_over_20kills
# 0  VecACGBYGaYN4rYoAdHr3nox4uAZERedMRHLuR8lqj9Z0P...                      0.0
# 1  -WbLudFHyoIYrQJ6XV-5MtWisSVjjweLp8S19KcZXWh3uy...                      0.0
# 2  vYQLI-rTA_2HuEUjwW3CzaD3J6ozUP-hXU0ogVPeruCNmh...                      0.0
# 3  LKEJUSbX118NCvq71N5d2Lt2VIowd9fc0JKSEC_jSJkwA_...                      0.0
# 4  D0eNXuIl7MQsskZFlosVNWJqV1jZ3zyR5nLk3sCEgIUcAT...                      0.0

# %%
#17 Durchschnittliche Anzahl an "Skillshots landed" und dodged
#Dictionary für jedes Rank wie viel Skillshots landed --> Yes/No

avg_skillshots_per_rank = df.groupby('tier')['skillshotsHit'].mean().reset_index()
avg_skillshots_per_rank.rename(columns={'skillshotsHit': 'avg_skillshots_hit'}, inplace=True)

avg_skillshots_dodged_per_rank = df.groupby('tier')['skillshotsDodged'].mean().reset_index()
avg_skillshots_dodged_per_rank.rename(columns={'skillshotsDodged': 'avg_skillshots_dodged'}, inplace=True)

player_skillshots = df.groupby(['puuid', 'tier'])['skillshotsHit'].mean().reset_index()
player_skillshots.rename(columns={'skillshotsHit': 'player_skillshots'}, inplace=True)

player_skillshots_dodged = df.groupby(['puuid', 'tier'])['skillshotsDodged'].mean().reset_index()
player_skillshots_dodged.rename(columns={'skillshotsDodged': 'player_dodged'}, inplace=True)

avg_combined_skillshots = avg_skillshots_per_rank.merge(avg_skillshots_dodged_per_rank, on='tier', how='left')

compare_skillshots = player_skillshots.merge(
    avg_skillshots_per_rank, on=['tier'], how='left'
    ).merge(
        player_skillshots_dodged, on=['puuid', 'tier'], how='left'
    ).merge(
        avg_skillshots_dodged_per_rank, on=['tier'], how='left'
    )

compare_skillshots['skillshots_above_rank'] = np.where(
    compare_skillshots['player_skillshots'] > compare_skillshots['avg_skillshots_hit'], 1, 0
)

compare_skillshots['dodged_above_rank'] = np.where(
    compare_skillshots['player_dodged'] > compare_skillshots['avg_skillshots_dodged'], 1, 0
)

df_ranked = df_ranked.merge(compare_skillshots[['puuid',
                            'tier',
                            'player_skillshots',
                            'avg_skillshots_hit',
                            'skillshots_above_rank',
                            'player_dodged',
                            'avg_skillshots_dodged',
                            'dodged_above_rank'
                        ]], on=['puuid', 'tier'],
                        how='left'
                    )

print(df_ranked[[
    'puuid',
    'tier',
    'player_skillshots',
    'avg_skillshots_hit',
    'skillshots_above_rank',
    'player_dodged',
    'avg_skillshots_dodged',
    'dodged_above_rank'
]].head())

#print(avg_skillshots_per_rank)
#print(player_skillshots)
#print(avg_skillshots_dodged_per_rank)
#print(avg_combined_skillshots)
# Out:
#                                                puuid    tier  \
# 0  VecACGBYGaYN4rYoAdHr3nox4uAZERedMRHLuR8lqj9Z0P...  SILVER
# 1  -WbLudFHyoIYrQJ6XV-5MtWisSVjjweLp8S19KcZXWh3uy...  BRONZE
# 2  vYQLI-rTA_2HuEUjwW3CzaD3J6ozUP-hXU0ogVPeruCNmh...  BRONZE
# 3  LKEJUSbX118NCvq71N5d2Lt2VIowd9fc0JKSEC_jSJkwA_...  BRONZE
# 4  D0eNXuIl7MQsskZFlosVNWJqV1jZ3zyR5nLk3sCEgIUcAT...  BRONZE
#
#    player_skillshots  avg_skillshots_hit  skillshots_above_rank  \
# 0               24.0               8.000                      1
# 1               20.0              23.375                      0
# 2                0.0              23.375                      0
# 3                0.0              23.375                      0
# 4                6.0              23.375                      0
#
#    player_dodged  avg_skillshots_dodged  dodged_above_rank
# 0           61.0                 35.000                  1
# 1           85.0                 51.625                  1
# 2           15.0                 51.625                  0
# 3           85.0                 51.625                  1
# 4           34.0                 51.625                  0

# %%
#18 Durchschnittliche Objective Steals pro Spiel
#Dictionary für jeden Rank wie viel Steals typisch sind. Wenn mehr --> Yes/No

avg_EpicMonsterSteals_per_rank = df.groupby('tier')['epicMonsterSteals'].mean().reset_index()
avg_EpicMonsterSteals_per_rank.rename(columns={'epicMonsterSteals': 'avg_epicMonsterSteals'}, inplace=True)

avg_EpicMonsterStolenWOsmite_per_rank = df.groupby('tier')['epicMonsterStolenWithoutSmite'].mean().reset_index()
avg_EpicMonsterStolenWOsmite_per_rank.rename(columns={'epicMonsterStolenWithoutSmite': 'avg_epicMonsterStolenWithoutSmite'}, inplace=True)

player_EpicMonsterSteals = df.groupby(['puuid', 'tier'])['epicMonsterSteals'].mean().reset_index()
player_EpicMonsterSteals.rename(columns={'epicMonsterSteals': 'player_epicMonsterSteals'}, inplace=True)

player_EpicMonsterStealsWOsmite = df.groupby(['puuid', 'tier'])['epicMonsterStolenWithoutSmite'].mean().reset_index()
player_EpicMonsterStealsWOsmite.rename(columns={'epicMonsterStolenWithoutSmite': 'player_epicMonsterStealsWOsmite'}, inplace=True)

compare_objectives = player_EpicMonsterSteals.merge(
    avg_EpicMonsterSteals_per_rank, on='tier', how='left'
).merge(
    player_EpicMonsterStealsWOsmite, on=['puuid', 'tier'], how='left'
).merge(
    avg_EpicMonsterStolenWOsmite_per_rank, on='tier', how='left'
)

compare_objectives['epicMonsterSteals_above_rank'] = np.where(
    compare_objectives['player_epicMonsterSteals'] > compare_objectives['avg_epicMonsterSteals'], 1, 0
)
compare_objectives['epicMonsterStealsWOsmite_above_rank'] = np.where(
    compare_objectives['player_epicMonsterStealsWOsmite'] > compare_objectives['avg_epicMonsterStolenWithoutSmite'], 1, 0
)

df_ranked = df_ranked.merge(compare_objectives[['puuid',
                            'tier',
                            'player_epicMonsterSteals',
                            'avg_epicMonsterSteals',
                            'player_epicMonsterStealsWOsmite',
                            'avg_epicMonsterStolenWithoutSmite',
                            'epicMonsterSteals_above_rank',
                            'epicMonsterStealsWOsmite_above_rank'
                        ]],
                        on=['puuid', 'tier'], 
                        how='left'
                    )

#print(avg_EpicMonsterSteals_per_rank)
#print(avg_EpicMonsterStolenWOsmite_per_rank)

# %%
# 21 Erst Prüfen ob "eligibleForProgression" ist auf "True"
print(df['eligibleForProgression'])
# Out:
# 26     True
# 27     True
# 28     True
# 31     True
# 33     True
#        ...
# 193    True
# 194    True
# 195    True
# 196    True
# 197    True
# Name: eligibleForProgression, Length: 70, dtype: bool

# %%
# Aufräumaktion
df_ranked = df_ranked.loc[:, ~df_ranked.columns.str.startswith('SWARM_')]
df_ranked = df_ranked.loc[:, ~df_ranked.columns.str.startswith('challenge_SWARM_')]
df_ranked = df_ranked.drop(columns=['championSkinId', 'perks_styles','summonerName','legendaryItemUsed','challenge_legendaryItemUsed', 'rank', 'tier', 'individualPosition','role'], errors='ignore')

# %%
# Bool'sche Werte in numerische umwandeln
df_ranked_bool = df_ranked.select_dtypes(include=['bool'])

df_ranked[df_ranked_bool.columns] = df_ranked_bool.map(lambda x: 1 if x else 0)

# %%
for x in ['hotStreak', 'veteran', 'freshBlood']:
    df_ranked[x] = df_ranked[x].map({'True': 1, 'False': 0})

df_ranked['first_legendary_id'] = df_ranked['first_legendary_id'].astype('int64')


df_ranked['lane'] = df_ranked['lane'].replace('NONE', 'FILL')

lanes = pd.get_dummies(df_ranked['lane'], prefix='queued_lane', dtype=int)

df_ranked = pd.concat([df_ranked, lanes], axis=1)


played_lane = pd.get_dummies(df_ranked['teamPosition'], prefix='played_lane', dtype=int)

df_ranked = pd.concat([df_ranked, played_lane], axis=1)


df_ranked = df_ranked.drop(['lane'], axis=1, errors='ignore')
df_ranked = df_ranked.drop(['teamPosition'], axis=1, errors='ignore')


df_ranked['timestamp'] = df_ranked['timestamp'].astype('int64')
df_ranked = df_ranked.rename(columns={'timestamp': 'gameCreationTimestamp'})

# %%
champions = {
    'ALISTAR': 1,
    'ANNIE': 2,
    'ASHE': 3,
    'FIDDLESTICKS': 4,
    'JAX': 5,
    'KAYLE': 6,
    'MASTER YI': 7,
    'MORGANA': 8,
    'NUNUWILLUMP': 9,
    'RYZE': 10,
    'SION': 11,
    'SIVIR': 12,
    'SORAKA': 13,
    'TEEMO': 14,
    'TRISTANA': 15,
    'TWISTEDFATE': 16,
    'WARWICK': 17,
    'SINGED': 18,
    'ZILEAN': 19,
    'EVELYNN': 20,
    'TRYNDAMERE': 21,
    'TWITCH': 22,
    'KARTHUS': 23,
    'AMUMU': 24,
    'CHOGATH': 25,
    'ANIVIA': 26,
    'RAMMUS': 27,
    'VEIGAR': 28,
    'KASSADIN': 29,
    'GANGPLANK': 30,
    'TARIC': 31,
    'BLITZCRANK': 32,
    'DRMUNDO': 33,
    'JANNA': 34,
    'MALPHITE': 35,
    'CORKI': 36,
    'KATARINA': 37,
    'NASUS': 38,
    'HEIMERDINGER': 39,
    'SHACO': 40,
    'UDYR': 41,
    'NIDALEE': 42,
    'POPPY': 43,
    'GRAGAS': 44,
    'PANTHEON': 45,
    'MORDEKAISER': 46,
    'EZREAL': 47,
    'SHEN': 48,
    'KENNEN': 49,
    'GAREN': 50,
    'AKALI': 51,
    'MALZAHAR': 52,
    'OLAF': 53,
    'KOGMAW': 54,
    'XINZHAO': 55,
    'VLADIMIR': 56,
    'GALIO': 57,
    'URGOT': 58,
    'MISSFORTUNE': 59,
    'SONA': 60,
    'SWAIN': 61,
    'LUX': 62,
    'LEBLANC': 63,
    'IRELIA': 64,
    'TRUNDLE': 65,
    'CASSIOPEIA': 66,
    'CAITLYN': 67,
    'RENEKTON': 68,
    'KARMA': 69,
    'MAOKAI': 70,
    'JARVANIV': 71,
    'NOCTURNE': 72,
    'LEESIN': 73,
    'BRAND': 74,
    'RUMBLE': 75,
    'VAYNE': 76,
    'ORIANNA': 77,
    'YORICK': 78,
    'LEONA': 79,
    'WUKONG': 80,
    'SKARNER': 81,
    'TALON': 82,
    'RIVEN': 83,
    'XERATH': 84,
    'GRAVES': 85,
    'SHYVANA': 86,
    'FIZZ': 87,
    'VOLIBEAR': 88,
    'AHRI': 89,
    'VIKTOR': 90,
    'SEJUANI': 91,
    'ZIGGS': 92,
    'NAUTILUS': 93,
    'FIORA': 94,
    'LULU': 95,
    'HECARIM': 96,
    'VARUS': 97,
    'DARIUS': 98,
    'DRAVEN': 99,
    'JAYCE': 100,
    'ZYRA': 101,
    'DIANA': 102,
    'RENGAR': 103,
    'SYNDRA': 104,
    'KHAZIX': 105,
    'ELISE': 106,
    'ZED': 107,
    'NAMI': 108,
    'VI': 109,
    'THRESH': 110,
    'QUINN': 111,
    'ZAC': 112,
    'LISSANDRA': 113,
    'AATROX': 114,
    'LUCIAN': 115,
    'JINX': 116,
    'YASUO': 117,
    'VELKOZ': 118,
    'BRAUM': 119,
    'GNAR': 120,
    'AZIR': 121,
    'KALISTA': 122,
    'REKSAI': 123,
    'BARD': 124,
    'EKKO': 125,
    'TAHMKENCH': 126,
    'KINDRED': 127,
    'ILLAOI': 128,
    'JHIN': 129,
    'AURELIONSOL': 130,
    'TALIYAH': 131,
    'KLED': 132,
    'IVERN': 133,
    'CAMILLE': 134,
    'RAKAN': 135,
    'XAYAH': 136,
    'KAYN': 137,
    'ORNN': 138,
    'ZOE': 139,
    'KAISA': 140,
    'PYKE': 141,
    'NEEKO': 142,
    'SYLAS': 143,
    'YUUMI': 144,
    'QIYANA': 145,
    'SENNA': 146,
    'APHELIOS': 147,
    'SETT': 148,
    'LILLIA': 149,
    'YONE': 150,
    'SAMIRA': 151,
    'SERAPHINE': 152,
    'RELL': 153,
    'VIEGO': 154,
    'GWEN': 155,
    'AKSHAN': 156,
    'VEX': 157,
    'ZERI': 158,
    'RENATAGLASC': 159,
    'BELVETH': 160,
    'NILAH': 161,
    'KSANTE': 162,
    'MILIO': 163,
    'NAAFIRI': 164,
    'BRIAR': 165,
    'HWEI': 166,
    'SMOLDER': 167,
    'AURORA': 168,
    'AMBESSA': 169,
    'MEL': 170
}

df_ranked['championName'] = df_ranked['championName'].map(champions)

# %%
df_ranked_obj = df_ranked.select_dtypes(include=['object'])
df_ranked_obj
# Out:
#    gameMode      gameType                                              puuid  \
# 0   CLASSIC  MATCHED_GAME  VecACGBYGaYN4rYoAdHr3nox4uAZERedMRHLuR8lqj9Z0P...
# 1   CLASSIC  MATCHED_GAME  -WbLudFHyoIYrQJ6XV-5MtWisSVjjweLp8S19KcZXWh3uy...
# 2   CLASSIC  MATCHED_GAME  vYQLI-rTA_2HuEUjwW3CzaD3J6ozUP-hXU0ogVPeruCNmh...
# 3   CLASSIC  MATCHED_GAME  LKEJUSbX118NCvq71N5d2Lt2VIowd9fc0JKSEC_jSJkwA_...
# 4   CLASSIC  MATCHED_GAME  D0eNXuIl7MQsskZFlosVNWJqV1jZ3zyR5nLk3sCEgIUcAT...
# ..      ...           ...                                                ...
# 65  CLASSIC  MATCHED_GAME  dSZRDHIK7sETNR2q_uodXNnJHMdu1uOvc3Lua4yqO-9P6B...
# 66  CLASSIC  MATCHED_GAME  9KJqaSylw0NdkCxIBGyVSa2Nz9fAm1jUAP-vzadxoRg64x...
# 67  CLASSIC  MATCHED_GAME  n4Ez80e-i6GgYeUeYkwDu32uJBPjhY6VwiB1WeY2X7SQrB...
# 68  CLASSIC  MATCHED_GAME  3SfUU280VeZwGsmCJhmU7wFYdA6A6m38IvKPPebWD96GSY...
# 69  CLASSIC  MATCHED_GAME  2rgIXCcnaYUzP-86OXVh0LQg0moZpWzlAzfCJUrk36_Krf...
#
#     riotIdGameName riotIdTagline  \
# 0        12fuasboi           Kek
# 1    Ultraviolence          CCNC
# 2          Ramenyx           ATZ
# 3        Kranakrak           EUW
# 4   Quin mit vogel          0202
# ..             ...           ...
# 65     CoupDeGrâce          1385
# 66         Marslex           EUW
# 67           Hamso           EUW
# 68      Moopsiekin           EUW
# 69      Bard Bward           EUW
#
#                                            summonerId smurf_category
# 0    8kG_wMW7-0rMFHkGZDdRLF-FF0pY8T9H0AleXEyGRqr2QqJa         normal
# 1   FDvACnkaMdEZSZ9yzfe3iwfHvhuhrqLYtJmm0SiI2yFwpa...         normal
# 2   Fd5467ifSa_AzO55vObpYN6dv_TJpllYEJZzLcQsbrzlv_...         normal
# 3    W4XlN3rFEMBVYFeRdSkKU786CqXMomawbwDUCL3XytJW7wEs         normal
# 4   7_FL2KS2-2lhMwEAVF9YguT99eh-WoWI8eNIupsetj6phI...         normal
# ..                                                ...            ...
# 65   _WQuSQY_L5SmIu6plERBuEXElbNSW3wrt-h7tHz8fdNnAtG2         normal
# 66    QH2Fy_dc3YxvBM9RaholGcsNEIEy8CrnHSW4ELr-U_PZy4Q         normal
# 67    yP-HDeZj18qqVGM_Zj2vslssvZLjje4Dwjckf4ifRAuURGk         normal
# 68    sgoeLSbRC6vgzFxI1cP4CXiPq8n9DE5SRBIpQj6K4bGs5cQ         normal
# 69   Hl-mNLjTeF_afxgqd9RG3X2o_SueNZkrIypHriaMv9oykg4K         normal
#
# [70 rows x 7 columns]

# %%
#Imputation

df_ranked = df_ranked.fillna(
    df_ranked
        .select_dtypes(
            include=['float64']
            )
            .mean()
            .fillna(0)
    )

df_ranked = df_ranked.fillna(
    df_ranked
        .select_dtypes(
            include=['int64']
            )
            .mode()
            .iloc[0]
            .fillna(0)
            )

# %%
df_ranked.dtypes.value_counts()
# Out:
# int64      343
# float64    120
# object       7
# Name: count, dtype: int64

# %%
with open('/work/features_columns_df_ranked.json', 'w', encoding='utf-8') as f:
    json.dump(list(df_ranked.columns), f, ensure_ascii=False, indent=2)

# %%
df_ranked.select_dtypes(include=['float64', 'int64']).columns
# Out:
# Index(['gameCreationTimestamp', 'gameId', 'LP', 'wins', 'losses',
#        'PlayerScore0', 'PlayerScore1', 'PlayerScore10', 'PlayerScore11',
#        'PlayerScore2',
#        ...
#        'epicMonsterStealsWOsmite_above_rank', 'queued_lane_BOTTOM',
#        'queued_lane_JUNGLE', 'queued_lane_MIDDLE', 'queued_lane_TOP',
#        'played_lane_BOTTOM', 'played_lane_JUNGLE', 'played_lane_MIDDLE',
#        'played_lane_TOP', 'played_lane_UTILITY'],
#       dtype='object', length=463)

# %%
df_ranked['smurf_flag'].value_counts()
# Out:
# smurf_flag
# 0    70
# Name: count, dtype: int64

# %% [markdown]
# 0    964
# 1      4 with level 50 and winrate 70

# %%
test = df_ranked[df_ranked['smurf_flag']==1]
test[['riotIdGameName','riotIdTagline']]
# Out:
# Empty DataFrame
# Columns: [riotIdGameName, riotIdTagline]
# Index: []

# %%
test2 = df_ranked[df_ranked['riotIdGameName'] == "Regen"]
test2['championName']
# Out:
# Series([], Name: championName, dtype: int64)

# %%
df_ranked.to_csv('/work/df.eneemr', index=False)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5ba84711-b236-4487-8349-fb1f4283f4bd' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
