# %% [markdown]
# ARN = arn:aws:s3:::coleneemr
# AWS_REGION = Europa (Frankfurt) eu-central-1

# %% [markdown]
# # First Time Test

# %%
# !python.exe -m pip install --upgrade pip
# !pip install bs4
# Out:
# Requirement already satisfied: pip in c:\users\ensei\documents\github\research_cheatdetection_with_ml\.venv-fr\lib\site-packages (25.2)
# Requirement already satisfied: bs4 in c:\users\ensei\documents\github\research_cheatdetection_with_ml\.venv-fr\lib\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\ensei\documents\github\research_cheatdetection_with_ml\.venv-fr\lib\site-packages (from bs4) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ensei\documents\github\research_cheatdetection_with_ml\.venv-fr\lib\site-packages (from beautifulsoup4->bs4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\ensei\documents\github\research_cheatdetection_with_ml\.venv-fr\lib\site-packages (from beautifulsoup4->bs4) (4.14.1)

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
import requests
from bs4 import BeautifulSoup
import re

# %%
script_dir = os.getcwd()
file_path = os.path.join(script_dir, "..", "JSONS", "all_matches.json")
#file_path = "/work/all_matches.json" --> for DeepNote
all_rows = []

# %%
all_rows = []

with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

for team_name, matches in data.items():
    for match in matches:
        try:
            info = match.get("info", {})
            game_id = info.get('gameId')
            game_mode = info.get("gameMode")
            game_type = info.get("gameType")
            timestamp = info.get("gameCreation")
            participants = info.get("participants", [])

            challenges = [participant.get("challenges", {}) for participant in participants]

            for player, challenge in zip(participants, challenges):
                row = {
                    "timestamp": timestamp,
                    "gameId": game_id,
                    "gameMode": game_mode,
                    "gameType": game_type,
                    "tier": player.get("tier"),
                    "rank": player.get("rank"),
                    "LP": player.get("leaguePoints"),
                    "wins": player.get("wins"),
                    "losses": player.get("losses"),
                }
                row.update(player)
                row.update(challenge)
                all_rows.append(row)

        except KeyError as e:
            print(f"Error {e} in {file_path}")
        except Exception as e:
            print(f"Error {e}")

df = pd.DataFrame(all_rows)
df["timestamp"] = pd.to_datetime(df["timestamp"], unit='ms')

# Normalize challenges
if 'challenges' in df.columns:
    ch_df = pd.json_normalize(df['challenges']).add_prefix('challenge_')
    df = pd.concat([df.drop(columns=['challenges']), ch_df], axis=1)

# Normalize missions
if 'missions' in df.columns:
    missions_df = pd.json_normalize(df['missions']).add_prefix('mission_')
    df = pd.concat([df.drop(columns=['missions']), missions_df], axis=1)

# Normalize perks
if 'perks' in df.columns:
    perks_df = pd.json_normalize(df['perks']).add_prefix('perks_')
    df = pd.concat([df.drop(columns=['perks']), perks_df], axis=1)

df = df[df['gameMode'] == 'CLASSIC']
df = df[df['tier'].isin(['IRON', 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'EMERALD', 'DIAMOND'])]

print(df.tail())
# Out:
#                     timestamp      gameId gameMode      gameType      tier  \
# 22657 2025-07-30 22:33:18.459  7477856837  CLASSIC  MATCHED_GAME  PLATINUM
# 22659 2025-07-30 22:33:18.459  7477856837  CLASSIC  MATCHED_GAME    SILVER
# 22661 2025-07-30 22:33:18.459  7477856837  CLASSIC  MATCHED_GAME    SILVER
# 22662 2025-07-30 22:33:18.459  7477856837  CLASSIC  MATCHED_GAME  PLATINUM
# 22663 2025-07-30 22:33:18.459  7477856837  CLASSIC  MATCHED_GAME    BRONZE
#
#       rank  LP   wins  losses  PlayerScore0  ...  mission_playerScore6  \
# 22657  III  42    5.0     4.0           0.0  ...                   0.0
# 22659    I  99    6.0     3.0           0.0  ...                   0.0
# 22661   IV  80   87.0    75.0           0.0  ...                   0.0
# 22662   II  41  161.0   142.0           0.0  ...                   0.0
# 22663   II   2   26.0    11.0           0.0  ...                   0.0
#
#        mission_playerScore7  mission_playerScore8  mission_playerScore9  \
# 22657                   0.0                   0.0                     0
# 22659                   0.0                   0.0                     0
# 22661                   0.0                   0.0                     0
# 22662                   0.0                   0.0                     0
# 22663                   0.0                   0.0                     0
#
#        mission_playerScore10  mission_playerScore11  \
# 22657                      0                      0
# 22659                      0                      0
# 22661                      0                      0
# 22662                      0                      0
# 22663                      0                      0
#
#                                             perks_styles  \
# 22657  [{'description': 'primaryStyle', 'selections':...
# 22659  [{'description': 'primaryStyle', 'selections':...
# 22661  [{'description': 'primaryStyle', 'selections':...
# 22662  [{'description': 'primaryStyle', 'selections':...
# 22663  [{'description': 'primaryStyle', 'selections':...
#
#        perks_statPerks.defense  perks_statPerks.flex  perks_statPerks.offense
# 22657                     5001                  5008                     5005
# 22659                     5001                  5008                     5005
# 22661                     5001                  5008                     5005
# 22662                     5001                  5008                     5005
# 22663                     5001                  5008                     5007
#
# [5 rows x 453 columns]

# %%
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

for team_name, matches in data.items():
    for match in matches:
        try:
            info = match.get("info", {})
            game_id = info.get('gameId')
            game_mode = info.get("gameMode")
            game_type = info.get("gameType")
            timestamp = info.get("gameCreation")
            participants = info.get("participants", [])
            challenges = [participant.get("challenges", {}) for participant in participants]

            for player, challenge in zip(participants, challenges):
                row = {
                    "timestamp": timestamp,
                    "gameId": game_id,
                    "gameMode": game_mode,
                    "gameType": game_type,
                    "tier": player.get("tier"),
                    "rank": player.get("rank"),
                    "LP": player.get("leaguePoints"),
                    "wins": player.get("wins"),
                    "losses": player.get("losses"),
                }
                row.update(player)
                row.update(challenge)
                all_rows.append(row)

        except KeyError as e:
            print(f"Error {e} in {file_path}")
        except Exception as e:
            print(f"Error {e}")

df = pd.DataFrame(all_rows)

df["timestamp"] = pd.to_datetime(df["timestamp"], unit='ms')

# Open up dictionarys in the list and create columns:

ch_df = pd.json_normalize(df['challenges']).add_prefix('challenge_')

df = pd.concat([
    df.drop(columns=['challenges']), 
    ch_df
], axis=1)

missions_df = pd.json_normalize(df['missions']).add_prefix('mission_')

df = pd.concat(
    [df.drop(columns=['missions']), missions_df],
    axis=1
)

perks_df = pd.json_normalize(df['perks']).add_prefix('perks_')

df = pd.concat(
    [df.drop(columns=['perks']), perks_df],
    axis=1
)

df = df[df['gameMode'] == 'CLASSIC']
df = df[df['tier'].isin(['IRON', 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'EMERALD', 'DIAMOND'])]

df.tail()
# Out:
#                     timestamp      gameId gameMode      gameType      tier  \
# 45331 2025-07-30 22:33:18.459  7477856837  CLASSIC  MATCHED_GAME  PLATINUM
# 45333 2025-07-30 22:33:18.459  7477856837  CLASSIC  MATCHED_GAME    SILVER
# 45335 2025-07-30 22:33:18.459  7477856837  CLASSIC  MATCHED_GAME    SILVER
# 45336 2025-07-30 22:33:18.459  7477856837  CLASSIC  MATCHED_GAME  PLATINUM
# 45337 2025-07-30 22:33:18.459  7477856837  CLASSIC  MATCHED_GAME    BRONZE
#
#       rank  LP   wins  losses  PlayerScore0  ...  mission_playerScore6  \
# 45331  III  42    5.0     4.0           0.0  ...                   0.0
# 45333    I  99    6.0     3.0           0.0  ...                   0.0
# 45335   IV  80   87.0    75.0           0.0  ...                   0.0
# 45336   II  41  161.0   142.0           0.0  ...                   0.0
# 45337   II   2   26.0    11.0           0.0  ...                   0.0
#
#        mission_playerScore7  mission_playerScore8  mission_playerScore9  \
# 45331                   0.0                   0.0                     0
# 45333                   0.0                   0.0                     0
# 45335                   0.0                   0.0                     0
# 45336                   0.0                   0.0                     0
# 45337                   0.0                   0.0                     0
#
#        mission_playerScore10  mission_playerScore11  \
# 45331                      0                      0
# 45333                      0                      0
# 45335                      0                      0
# 45336                      0                      0
# 45337                      0                      0
#
#                                             perks_styles  \
# 45331  [{'description': 'primaryStyle', 'selections':...
# 45333  [{'description': 'primaryStyle', 'selections':...
# 45335  [{'description': 'primaryStyle', 'selections':...
# 45336  [{'description': 'primaryStyle', 'selections':...
# 45337  [{'description': 'primaryStyle', 'selections':...
#
#        perks_statPerks.defense  perks_statPerks.flex  perks_statPerks.offense
# 45331                     5001                  5008                     5005
# 45333                     5001                  5008                     5005
# 45335                     5001                  5008                     5005
# 45336                     5001                  5008                     5005
# 45337                     5001                  5008                     5007
#
# [5 rows x 453 columns]

# %%
df['tier'].unique()
df['gameType'].unique()
# Out:
# array(['MATCHED_GAME', 'CUSTOM_GAME'], dtype=object)

# %%
with open('features_columns.json', 'w', encoding='utf-8') as f:
    json.dump(list(df.columns), f, ensure_ascii=False, indent=2)

# %%
print(df.isna().sum().sum())
# Out:
# 831628

# %%
# Dropping non-numeric columns to compute the correlation matrix
numeric_df = df.select_dtypes(include=['number'])

# Compute the correlation matrix for numerical columns
correlation_matrix = numeric_df.corr()

plt.figure(figsize=(15, 12))
sns.heatmap(correlation_matrix,
            annot=False,
            cmap="coolwarm",
            vmin=0,
            vmax=1,
            fmt=".3f",
            cbar=True
            )
plt.title("Correlationmatrix (Champion Stats)")
plt.tight_layout()
plt.show()

# %%
c_matrix = correlation_matrix.abs()
intervals = np.arange(0, 1.1, 0.1)
result = {round(i,1):[] for i in intervals}
result[1.1] = [] # NaN-Values

cols = c_matrix.columns
n = len(cols)

for i in range(n):
    for j in range(i+1, n):
        v = c_matrix.iloc[i, j]
        if np.isnan(v):
            result[1.1].append((cols[i], cols[j]))
        else:
            bucket = round(np.floor(v * 10) / 10, 1)
            if v == 1.0:
                bucket = 1.0
            result[bucket].append((cols[i], cols[j]))

list_result = {k: v for k, v in result.items()}

with open('features_wertung.json', 'w', encoding='utf-8') as f:
    json.dump(list_result, f, ensure_ascii=False, indent=2)

# %%
# somtin somthin
'''
Features
DamageShare = teamDamagePercentage
role = lane
visionPerMinute = visionScorePerMinute
kda
totaltimespentdead
firstbloodkill
turretplatestaken
takedownsfirstxminutes
firstblood
kill-share
dodgeSkillShotsSmallWindow
outnumberedkills
veteran / freshBlood
hotStreak
perfectgame = deathless

longestTimeSpentLiving
quickCleanse
skillshotdogded
skillshotsHit
wardTakedownsBefore20M
gameEndedInEarlySurrender
maxlevelleadlaneopponent
summonerlevel
maxcsadvantageonlaneopponent
visionscoreadvantageonlaneopponent

heuristische Features
+1 Game Length vs. Winrate --> viele Games mit kurzer Zeit (normale Low Elo sind 30-40 Min)
+2 Account Level --> niedriges Level mit stark guten Stats ++
+3 Rank Progression (von Iron zu Gold in unter <50 Spielen)
-4 Durchschnittliches Gold vor 10 Minutes (vllt goldPerMinute anschauen und hohe Zahlen als Threshold verwenden)
-5 Anteil der Spiele mit S-Rank (kann OTP sein) Annäherungsversuch mittels Heuristik möglich --> S-Rank Potenzial Funktion
+6 Wie viele Perfekte Games (keine Tode)
+7 durchschnittlicher CS-Lead zum Lane Opponent (maxCsAdvantageOnLaneOpponent) ++
+8 hohe Vision Control ++
+9 durchschnittliches Gold pro Minute bei Champ und Rolle
+10 Zeit bis first full Item
-11 Erster Level 6 bei 10+ Games im Durchschnitt
+12 Winrate mit Off-Meta Champions (https://lolalytics.com/lol/tierlist/) --> All tierlist websites are dynamic (difficult to scrape)
+13 Anteil der Spiele mit über 20 Kills
-14 Ragequits/AFK-Quote (Smurf AFKt nicht)
-15 Keine frühen Aufgaben (earlysurrender gibt es nicht)
-16 Durchschnittliche Tower Damage im Verhältnis zum Team -->nur damageDealtToBuildings
+17 Durchschnittliche Anzahl an "Skillshots landed" ++
+18 Durchschnittliche Objective Steals pro Spiel
-19 Elo-Boosting (Drastische Veränderung der Account-Performance)
-20 Champion Experience (Viele S-Ranks ohne Championmastery oder wenige Punkte) - champion-mastery-v4-api
+21 Erst Prüfen ob "eligibleForProgression" ist auf "True" !!!

Info
--> mind 10+ Games für Aussagekraft
--> immer Top 5% der Elo-Rangliste
--> Alle Thresholds müssen aktualisiert werden mit einem Machine Learning Algorithmus

'''
# Out:
# '\nFeatures\nDamageShare = teamDamagePercentage\nrole = lane\nvisionPerMinute = visionScorePerMinute\nkda\ntotaltimespentdead\nfirstbloodkill\nturretplatestaken\ntakedownsfirstxminutes\nfirstblood\nkill-share\ndodgeSkillShotsSmallWindow\noutnumberedkills\nveteran / freshBlood\nhotStreak\nperfectgame = deathless\n\nlongestTimeSpentLiving\nquickCleanse\nskillshotdogded\nskillshotsHit\nwardTakedownsBefore20M\ngameEndedInEarlySurrender\nmaxlevelleadlaneopponent\nsummonerlevel\nmaxcsadvantageonlaneopponent\nvisionscoreadvantageonlaneopponent\n\nheuristische Features\n+1 Game Length vs. Winrate --> viele Games mit kurzer Zeit (normale Low Elo sind 30-40 Min)\n+2 Account Level --> niedriges Level mit stark guten Stats ++\n+3 Rank Progression (von Iron zu Gold in unter <50 Spielen)\n-4 Durchschnittliches Gold vor 10 Minutes (vllt goldPerMinute anschauen und hohe Zahlen als Threshold verwenden)\n-5 Anteil der Spiele mit S-Rank (kann OTP sein) Annäherungsversuch mittels Heuristik möglich --> S-Rank Potenzial Funktion\n+6 Wie viele Perfekte Games (keine Tode)\n+7 durchschnittlicher CS-Lead zum Lane Opponent (maxCsAdvantageOnLaneOpponent) ++\n+8 hohe Vision Control ++\n+9 durchschnittliches Gold pro Minute bei Champ und Rolle\n+10 Zeit bis first full Item\n-11 Erster Level 6 bei 10+ Games im Durchschnitt\n+12 Winrate mit Off-Meta Champions (https://lolalytics.com/lol/tierlist/) --> All tierlist websites are dynamic (difficult to scrape)\n+13 Anteil der Spiele mit über 20 Kills\n-14 Ragequits/AFK-Quote (Smurf AFKt nicht)\n-15 Keine frühen Aufgaben (earlysurrender gibt es nicht)\n-16 Durchschnittliche Tower Damage im Verhältnis zum Team -->nur damageDealtToBuildings\n+17 Durchschnittliche Anzahl an "Skillshots landed" ++\n+18 Durchschnittliche Objective Steals pro Spiel\n-19 Elo-Boosting (Drastische Veränderung der Account-Performance)\n-20 Champion Experience (Viele S-Ranks ohne Championmastery oder wenige Punkte) - champion-mastery-v4-api\n+21 Erst Prüfen ob "eligibleForProgression" ist auf "True" !!!\n\nInfo\n--> mind 10+ Games für Aussagekraft\n--> immer Top 5% der Elo-Rangliste\n--> Alle Thresholds müssen aktualisiert werden mit einem Machine Learning Algorithmus\n\n'

# %%
# New Features
df["damagePerGold"] = df["totalDamageDealtToChampions"] / df["goldEarned"]
df["carryScore"] =  (df["kda"] * df["totalDamageDealtToChampions"] * df["goldEarned"]) /  (df["timePlayed"]/60)
df["efficiencyScore"] = df["kda"] * df["damagePerGold"] * df["visionScorePerMinute"]

tier_map = {
    "IRON": 1,
    "BRONZE": 2,
    "SILVER": 3,
    "GOLD": 4,
    "PLATINUM": 5,
    "EMERALD": 6,
    "DIAMOND": 7,
    "MASTER": 8,
    "GRANDMASTER": 9,
    "CHALLENGER": 10,
    "UNRANKED": 0
}

rank_map = {"IV": 1, "III": 2, "II": 3, "I": 4}

df["tier_num"] = df["tier"].map(tier_map)
df["rank_num"] = df["rank"].map(rank_map).fillna(0).astype(int)

df["tier_score"] = df["tier_num"] + df["rank_num"] + df["LP"]/100

df_ranked = df[df["tier_score"] > 0].copy() #Filter non ranked players

df_ranked["kda_tier"] = df_ranked["kda"] / df_ranked["tier_score"]

df_ranked["winrate"] = (df_ranked["wins"] / (df_ranked["losses"]+df_ranked["wins"])) *100

df_ranked = df_ranked[df_ranked["eligibleForProgression"] == True].copy()

print(df_ranked["winrate"])

# Creation: Winrate, KDA/rank, damagePerGold, carryScore, efficiencyScore
# Out:
# 16       49.038462
# 17       48.548549
# 18       47.289157
# 19       51.724138
# 20       43.274854
#            ...
# 45331    55.555556
# 45333    66.666667
# 45335    53.703704
# 45336    53.135314
# 45337    70.270270
# Name: winrate, Length: 28244, dtype: float64

# %% [markdown]
# # Implementation of heuristical features

# %%
#1. Game Length vs. Winrate

def compute_fast_winrate(df):
    shortgame_threshold = 25 * 60 # seconds

    won_games = df[df['win'] == True]
    short_wins = won_games[won_games['gameLength'] < shortgame_threshold]

    all_fast_games = df[df['gameLength'] < shortgame_threshold]

    total_games = len(df)
    fast_winrate = len(short_wins) / len(won_games) if len(won_games) > 0 else 0
    fast_game_rate = len(all_fast_games) / total_games if total_games > 0 else 0

    return pd.Series({'winrate': fast_winrate, 'fast_game_rate': fast_game_rate})

df_fast_stats = df.groupby('puuid').apply(compute_fast_winrate).reset_index()

df_ranked = df_ranked.merge(df_fast_stats[['puuid', 'fast_game_rate']], on='puuid', how='left')
# Out:
# C:\Users\EnSei\AppData\Local\Temp\ipykernel_11312\1713805003.py:17: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_fast_stats = df.groupby('puuid').apply(compute_fast_winrate).reset_index()

# %%
#2. Account Level checking on smurf and score
low_level_threshold = 70
high_kda_threshold = 4
high_winrate_threshold = 65
gold_earned_threshold = 400
totalDamageDealt_threshold = 300

account_stats = df_ranked.groupby('puuid').agg({
    'summonerLevel': 'first',
    'kda': 'mean',
    'kills': 'mean',
    'assists': 'mean',
    'deaths': 'mean',
    'goldPerMinute': 'mean',
    'totalDamageDealtToChampions': 'mean',
    'tier_num': 'first',
    'winrate' : 'mean'
}).reset_index()

account_stats['smurf_flag'] = (
    (account_stats['summonerLevel'] < low_level_threshold) &
    (
        #(account_stats['kda'] >= high_kda_threshold) &
        #(account_stats['kills'] >= 8) &
        #(account_stats['goldPerMinute'] >= gold_earned_threshold) &
        #(account_stats['totalDamageDealtToChampions'] >= totalDamageDealt_threshold) &
        (account_stats['winrate'] >= high_winrate_threshold) 
    )
)

account_stats['smurf_score'] = (
    (account_stats['summonerLevel'] < low_level_threshold).astype(int) +
    #(account_stats['kda'] >= high_kda_threshold).astype(int) +
    #(account_stats['kills'] >= 8).astype(int) +
    #(account_stats['goldPerMinute'] >= gold_earned_threshold).astype(int) +
    #(account_stats['totalDamageDealtToChampions'] >= totalDamageDealt_threshold).astype(int) +
    (account_stats['winrate'] >= high_winrate_threshold).astype(int)
)

account_stats['smurf_ratio'] = account_stats['smurf_score'] / account_stats['tier_num']
account_stats['smurf_ratio'] = account_stats['smurf_ratio'].fillna(0)

df_ranked = df_ranked.merge(account_stats[['puuid', 'smurf_flag', 'smurf_score', 'smurf_ratio']], on='puuid', how='left')

print(df_ranked[['puuid', 'summonerLevel', 'kda', 'winrate', 'kills', 'goldPerMinute', 'totalDamageDealtToChampions', 'smurf_flag', 'smurf_score', 'smurf_ratio']].head())
# Out:
#                                                puuid  summonerLevel       kda  \
# 0  NS6Iz_PJ1jLlCCDSZbhC-_tSB0XDiTQFp_M4cUgNCbR7gM...             66  2.333333
# 1  BNEeQVLI4LHlAOpNrf_1UGzcPx5LgiKXPfKKIWReTwdPxK...            328  6.000000
# 2  zJnf3VYJutq8lqOnD_iXDlhmETkk1dULIZTWft2r-fkWCC...            328  5.000000
# 3  HwKU5bDk89rnr5yqXQwopXSh0x0z2tQXCWv4ewx0NtC0-L...            161  4.250000
# 4  ck-5nJvjkpmGgyNJnH_A3nMv_A7EJ0uJ3fZkN3WbsMLX3K...            262  4.333333
#
#      winrate  kills  goldPerMinute  totalDamageDealtToChampions  smurf_flag  \
# 0  49.038462      2     319.533989                        12311       False
# 1  48.548549      7     398.448854                        15545       False
# 2  47.289157     13     515.775330                        34209       False
# 3  51.724138      8     406.333079                        16469       False
# 4  43.274854     10     410.158061                        25372       False
#
#    smurf_score  smurf_ratio
# 0            1          1.0
# 1            0          0.0
# 2            0          0.0
# 3            0          0.0
# 4            0          0.0

# %%
sns.boxplot(data=account_stats, x='smurf_flag', y='smurf_ratio')
plt.title('Smurf Rating with Smurf Flag')
# Out:
# Text(0.5, 1.0, 'Smurf Rating with Smurf Flag')

# %%
for t in [0.8, 1.0, 1.2, 1.5]:
    temp_flag = account_stats['smurf_ratio'] > t
    print(f"Threshold {t:.1f}:\n", pd.crosstab(account_stats['smurf_flag'], temp_flag, normalize='index'), "\n")

def label_smurf(row):
    if row['smurf_ratio'] >= 1.5:
        return 'definite_smurf'
    elif row['smurf_ratio'] >= 1.0:
        return 'likely_smurf'
    elif row['smurf_ratio'] >= 0.8:
        return 'possible_smurf'
    else:
        return 'normal'

account_stats['smurf_category'] = account_stats.apply(label_smurf, axis=1)
df_ranked = df_ranked.merge(account_stats[['puuid', 'smurf_category']], on='puuid', how='left')
# Out:
# Threshold 0.8:
#  smurf_ratio     False     True
# smurf_flag
# False        0.983985  0.016015
# True         0.790230  0.209770
#
# Threshold 1.0:
#  smurf_ratio     False     True
# smurf_flag
# False        1.000000  0.000000
# True         0.902299  0.097701
#
# Threshold 1.2:
#  smurf_ratio     False     True
# smurf_flag
# False        1.000000  0.000000
# True         0.902299  0.097701
#
# Threshold 1.5:
#  smurf_ratio     False     True
# smurf_flag
# False        1.000000  0.000000
# True         0.902299  0.097701

# %%
#3. Rank progression (Iron to Gold in under 50 Games)
df_sorted = df_ranked.sort_values(['puuid', 'timestamp'])

def check_schneller_rank_aufstieg(gruppe):
    if len(gruppe) < 2:
        return False
    lowest_tier = gruppe['tier_num'].min()
    highest_tier = gruppe['tier_num'].max()
    num_games = len(gruppe)
    is_schnell_aufgestiegen = (lowest_tier == 1) and (highest_tier >= 4) and (num_games <= 50)
    return is_schnell_aufgestiegen

rankprog_df = df_sorted.groupby('puuid').apply(lambda x: check_schneller_rank_aufstieg(x)).reset_index()
rankprog_df.columns = ['puuid', 'fast_rank_progression']

df_ranked = df_ranked.merge(rankprog_df, on='puuid', how='left')

print(df_ranked[df_ranked['fast_rank_progression']])
# Out:
# Empty DataFrame
# Columns: [timestamp, gameId, gameMode, gameType, tier, rank, LP, wins, losses, PlayerScore0, PlayerScore1, PlayerScore10, PlayerScore11, PlayerScore2, PlayerScore3, PlayerScore4, PlayerScore5, PlayerScore6, PlayerScore7, PlayerScore8, PlayerScore9, allInPings, assistMePings, assists, baronKills, basicPings, champExperience, champLevel, championId, championName, championTransform, commandPings, consumablesPurchased, damageDealtToBuildings, damageDealtToObjectives, damageDealtToTurrets, damageSelfMitigated, dangerPings, deaths, detectorWardsPlaced, doubleKills, dragonKills, eligibleForProgression, enemyMissingPings, enemyVisionPings, firstBloodAssist, firstBloodKill, firstTowerAssist, firstTowerKill, gameEndedInEarlySurrender, gameEndedInSurrender, getBackPings, goldEarned, goldSpent, holdPings, individualPosition, inhibitorKills, inhibitorTakedowns, inhibitorsLost, item0, item1, item2, item3, item4, item5, item6, itemsPurchased, killingSprees, kills, lane, largestCriticalStrike, largestKillingSpree, largestMultiKill, longestTimeSpentLiving, magicDamageDealt, magicDamageDealtToChampions, magicDamageTaken, needVisionPings, neutralMinionsKilled, nexusKills, nexusLost, nexusTakedowns, objectivesStolen, objectivesStolenAssists, onMyWayPings, participantId, pentaKills, physicalDamageDealt, physicalDamageDealtToChampions, physicalDamageTaken, placement, playerAugment1, playerAugment2, playerAugment3, playerAugment4, playerAugment5, playerAugment6, playerSubteamId, profileIcon, pushPings, ...]
# Index: []
#
# [0 rows x 467 columns]
# C:\Users\EnSei\AppData\Local\Temp\ipykernel_11312\2728413343.py:13: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   rankprog_df = df_sorted.groupby('puuid').apply(lambda x: check_schneller_rank_aufstieg(x)).reset_index()

# %%
#7 average CS-Lead to Lane Opponent only advantage

cs_lead_per_account = df.groupby('puuid')['maxCsAdvantageOnLaneOpponent'].mean().reset_index()
cs_lead_per_account.rename(columns={'maxCsAdvantageOnLaneOpponent': 'avg_cs_lead_lane'}, inplace=True)

df_ranked = df_ranked.merge(cs_lead_per_account, on='puuid', how='left')

print(df_ranked[['puuid', 'avg_cs_lead_lane']].head())
# Out:
#                                                puuid  avg_cs_lead_lane
# 0  NS6Iz_PJ1jLlCCDSZbhC-_tSB0XDiTQFp_M4cUgNCbR7gM...               4.0
# 1  BNEeQVLI4LHlAOpNrf_1UGzcPx5LgiKXPfKKIWReTwdPxK...               7.0
# 2  zJnf3VYJutq8lqOnD_iXDlhmETkk1dULIZTWft2r-fkWCC...              45.0
# 3  HwKU5bDk89rnr5yqXQwopXSh0x0z2tQXCWv4ewx0NtC0-L...               3.0
# 4  ck-5nJvjkpmGgyNJnH_A3nMv_A7EJ0uJ3fZkN3WbsMLX3K...              13.0

# %%
#8 high Vision Control Score

vision_score_thresholds = df.groupby('tier')['visionScore'].quantile(0.75).reset_index()
vision_score_thresholds.rename(columns={'visionScore': 'visionScore_threshold'}, inplace=True)

df_ranked = df_ranked.merge(vision_score_thresholds, on='tier', how='left')

df_ranked['high_vision_control'] = (
    (df_ranked['visionScore'] > df_ranked['visionScore_threshold']) &
    (df_ranked['visionScoreAdvantageLaneOpponent'] > 0.5)
)

print(df_ranked[['puuid', 'championName', 'tier', 'visionScore', 'visionScore_threshold', 'visionScoreAdvantageLaneOpponent', 'high_vision_control']].head())
# Out:
#                                                puuid championName    tier  \
# 0  NS6Iz_PJ1jLlCCDSZbhC-_tSB0XDiTQFp_M4cUgNCbR7gM...        Milio    IRON
# 1  BNEeQVLI4LHlAOpNrf_1UGzcPx5LgiKXPfKKIWReTwdPxK...     Volibear    IRON
# 2  zJnf3VYJutq8lqOnD_iXDlhmETkk1dULIZTWft2r-fkWCC...          Mel  BRONZE
# 3  HwKU5bDk89rnr5yqXQwopXSh0x0z2tQXCWv4ewx0NtC0-L...       Yunara  BRONZE
# 4  ck-5nJvjkpmGgyNJnH_A3nMv_A7EJ0uJ3fZkN3WbsMLX3K...          Lux    IRON
#
#    visionScore  visionScore_threshold  visionScoreAdvantageLaneOpponent  \
# 0           19                   29.0                          0.262607
# 1           24                   29.0                          0.386654
# 2           13                   28.0                        801.507874
# 3           15                   28.0                          0.314189
# 4           53                   29.0                          0.979100
#
#    high_vision_control
# 0                False
# 1                False
# 2                False
# 3                False
# 4                 True

# %%
#9 average Gold per Minute for Champ and Role
#--> Websitescraper for average Gameduration with comparison on average Gold/XP
#--> https://op.gg/de/lol/statistics/champions and https://www.leagueofgraphs.com/stats/game-durations

with open("champtier.html", encoding="utf-8") as f:
    html = f.read()

soup = BeautifulSoup(html, "html.parser")

champ_data = []

rows = soup.find_all('tr')

for row in rows:
    cols = row.find_all('td')
    if len(cols) < 9:
        continue
    name = cols[1].text.strip()
    cs = cols[7].text.strip().replace(',', '.')
    gold = cols[8].text.strip().replace(',', '.')
    champ_data.append({'championName': name, 'goldAvgInternet': gold, 'csAvgInternet': cs})

for c in champ_data:
    print(c)
# Out:
# {'championName': 'Yunara', 'goldAvgInternet': '11.180', 'csAvgInternet': '200.02'}
# {'championName': 'Lux', 'goldAvgInternet': '10.593', 'csAvgInternet': '99.08'}
# {'championName': "Kai'Sa", 'goldAvgInternet': '13.017', 'csAvgInternet': '200.45'}
# {'championName': 'Caitlyn', 'goldAvgInternet': '12.804', 'csAvgInternet': '193.67'}
# {'championName': 'Jhin', 'goldAvgInternet': '12.793', 'csAvgInternet': '187.98'}
# {'championName': 'Jinx', 'goldAvgInternet': '12.484', 'csAvgInternet': '197.46'}
# {'championName': 'Yasuo', 'goldAvgInternet': '12.307', 'csAvgInternet': '199.28'}
# {'championName': 'Pantheon', 'goldAvgInternet': '11.585', 'csAvgInternet': '130.16'}
# {'championName': 'Zed', 'goldAvgInternet': '12.604', 'csAvgInternet': '182.37'}
# {'championName': 'Viego', 'goldAvgInternet': '12.822', 'csAvgInternet': '180'}
# {'championName': 'Miss Fortune', 'goldAvgInternet': '12.918', 'csAvgInternet': '181.66'}
# {'championName': 'Trundle', 'goldAvgInternet': '12.346', 'csAvgInternet': '177.47'}
# {'championName': 'Lee Sin', 'goldAvgInternet': '11.986', 'csAvgInternet': '160.7'}
# {'championName': 'Yone', 'goldAvgInternet': '12.055', 'csAvgInternet': '195.9'}
# {'championName': 'Sylas', 'goldAvgInternet': '11.059', 'csAvgInternet': '142.45'}
# {'championName': 'Ezreal', 'goldAvgInternet': '12.103', 'csAvgInternet': '186.83'}
# {'championName': 'Mel', 'goldAvgInternet': '11.971', 'csAvgInternet': '141.81'}
# {'championName': 'Diana', 'goldAvgInternet': '12.771', 'csAvgInternet': '185.33'}
# {'championName': 'Lucian', 'goldAvgInternet': '12.674', 'csAvgInternet': '200.16'}
# {'championName': 'Warwick', 'goldAvgInternet': '12.444', 'csAvgInternet': '165.83'}
# {'championName': 'Thresh', 'goldAvgInternet': '8.547', 'csAvgInternet': '33.61'}
# {'championName': 'Jax', 'goldAvgInternet': '12.150', 'csAvgInternet': '176.8'}
# {'championName': 'Lulu', 'goldAvgInternet': '8.202', 'csAvgInternet': '29.14'}
# {'championName': 'Kayn', 'goldAvgInternet': '12.741', 'csAvgInternet': '181.09'}
# {'championName': 'Sett', 'goldAvgInternet': '12.208', 'csAvgInternet': '172.09'}
# {'championName': 'Nautilus', 'goldAvgInternet': '8.553', 'csAvgInternet': '34.72'}
# {'championName': 'Ashe', 'goldAvgInternet': '11.589', 'csAvgInternet': '167.19'}
# {'championName': 'Volibear', 'goldAvgInternet': '12.149', 'csAvgInternet': '178.02'}
# {'championName': 'Mordekaiser', 'goldAvgInternet': '12.069', 'csAvgInternet': '175.12'}
# {'championName': 'Vayne', 'goldAvgInternet': '12.583', 'csAvgInternet': '179.06'}
# {'championName': 'Ahri', 'goldAvgInternet': '11.489', 'csAvgInternet': '179.43'}
# {'championName': 'Malphite', 'goldAvgInternet': '11.107', 'csAvgInternet': '150.58'}
# {'championName': 'Akali', 'goldAvgInternet': '11.847', 'csAvgInternet': '164.1'}
# {'championName': 'Morgana', 'goldAvgInternet': '9.865', 'csAvgInternet': '66.08'}
# {'championName': 'Sivir', 'goldAvgInternet': '12.806', 'csAvgInternet': '225.45'}
# {'championName': 'Smolder', 'goldAvgInternet': '12.900', 'csAvgInternet': '214.47'}
# {'championName': 'Nami', 'goldAvgInternet': '8.398', 'csAvgInternet': '25.51'}
# {'championName': 'Shaco', 'goldAvgInternet': '12.027', 'csAvgInternet': '135.37'}
# {'championName': 'Nocturne', 'goldAvgInternet': '12.622', 'csAvgInternet': '184.61'}
# {'championName': 'Malzahar', 'goldAvgInternet': '12.692', 'csAvgInternet': '217.16'}
# {'championName': 'Teemo', 'goldAvgInternet': '11.990', 'csAvgInternet': '165.52'}
# {'championName': 'Darius', 'goldAvgInternet': '12.245', 'csAvgInternet': '182.84'}
# {'championName': 'Master Yi', 'goldAvgInternet': '13.002', 'csAvgInternet': '179.71'}
# {'championName': 'Ekko', 'goldAvgInternet': '12.757', 'csAvgInternet': '178.27'}
# {'championName': 'Senna', 'goldAvgInternet': '10.928', 'csAvgInternet': '105.12'}
# {'championName': 'Dr. Mundo', 'goldAvgInternet': '11.929', 'csAvgInternet': '189.67'}
# {'championName': 'Aatrox', 'goldAvgInternet': '11.436', 'csAvgInternet': '175.92'}
# {'championName': 'Xerath', 'goldAvgInternet': '11.131', 'csAvgInternet': '121.78'}
# {'championName': 'Irelia', 'goldAvgInternet': '13.241', 'csAvgInternet': '216.51'}
# {'championName': 'Leona', 'goldAvgInternet': '8.580', 'csAvgInternet': '31.58'}
# {'championName': 'Tristana', 'goldAvgInternet': '12.989', 'csAvgInternet': '184.13'}
# {'championName': 'Veigar', 'goldAvgInternet': '12.399', 'csAvgInternet': '174.13'}
# {'championName': 'Garen', 'goldAvgInternet': '12.890', 'csAvgInternet': '198.76'}
# {'championName': 'Jarvan IV.', 'goldAvgInternet': '12.036', 'csAvgInternet': '162.95'}
# {'championName': 'Karma', 'goldAvgInternet': '8.792', 'csAvgInternet': '48.9'}
# {'championName': 'Pyke', 'goldAvgInternet': '10.128', 'csAvgInternet': '35.91'}
# {'championName': 'Milio', 'goldAvgInternet': '8.125', 'csAvgInternet': '28.08'}
# {'championName': 'Aphelios', 'goldAvgInternet': '12.653', 'csAvgInternet': '192.88'}
# {'championName': 'Xin Zhao', 'goldAvgInternet': '11.789', 'csAvgInternet': '166.55'}
# {'championName': 'Renekton', 'goldAvgInternet': '12.097', 'csAvgInternet': '193.26'}
# {'championName': 'Varus', 'goldAvgInternet': '12.260', 'csAvgInternet': '185'}
# {'championName': 'Galio', 'goldAvgInternet': '10.515', 'csAvgInternet': '150.93'}
# {'championName': 'Katarina', 'goldAvgInternet': '12.593', 'csAvgInternet': '163.05'}
# {'championName': 'Blitzcrank', 'goldAvgInternet': '8.384', 'csAvgInternet': '29.4'}
# {'championName': 'Vladimir', 'goldAvgInternet': '11.978', 'csAvgInternet': '192.29'}
# {'championName': 'Yuumi', 'goldAvgInternet': '7.964', 'csAvgInternet': '14.89'}
# {'championName': 'Swain', 'goldAvgInternet': '10.361', 'csAvgInternet': '94.59'}
# {'championName': 'LeBlanc', 'goldAvgInternet': '11.557', 'csAvgInternet': '148.78'}
# {'championName': 'Yorick', 'goldAvgInternet': '12.551', 'csAvgInternet': '201.89'}
# {'championName': 'Braum', 'goldAvgInternet': '8.255', 'csAvgInternet': '27.36'}
# {'championName': 'Viktor', 'goldAvgInternet': '11.772', 'csAvgInternet': '195.33'}
# {'championName': "Kha'Zix", 'goldAvgInternet': '13.118', 'csAvgInternet': '177.29'}
# {'championName': 'Briar', 'goldAvgInternet': '13.018', 'csAvgInternet': '172.27'}
# {'championName': 'Nasus', 'goldAvgInternet': '12.105', 'csAvgInternet': '182.55'}
# {'championName': 'Aurora', 'goldAvgInternet': '11.659', 'csAvgInternet': '182.39'}
# {'championName': 'Twitch', 'goldAvgInternet': '12.943', 'csAvgInternet': '162.21'}
# {'championName': 'Sion', 'goldAvgInternet': '12.286', 'csAvgInternet': '192.57'}
# {'championName': 'Samira', 'goldAvgInternet': '13.522', 'csAvgInternet': '183.25'}
# {'championName': 'Seraphine', 'goldAvgInternet': '9.308', 'csAvgInternet': '54.8'}
# {'championName': "Cho'Gath", 'goldAvgInternet': '11.876', 'csAvgInternet': '171.05'}
# {'championName': 'Orianna', 'goldAvgInternet': '11.579', 'csAvgInternet': '191.18'}
# {'championName': 'Fizz', 'goldAvgInternet': '12.766', 'csAvgInternet': '164.22'}
# {'championName': 'Twisted Fate', 'goldAvgInternet': '12.334', 'csAvgInternet': '176.24'}
# {'championName': 'Wukong', 'goldAvgInternet': '12.082', 'csAvgInternet': '169.18'}
# {'championName': 'Hwei', 'goldAvgInternet': '11.530', 'csAvgInternet': '175.29'}
# {'championName': 'Shen', 'goldAvgInternet': '10.489', 'csAvgInternet': '133.97'}
# {'championName': 'Brand', 'goldAvgInternet': '10.711', 'csAvgInternet': '93.78'}
# {'championName': 'Zyra', 'goldAvgInternet': '10.085', 'csAvgInternet': '79.6'}
# {'championName': 'Amumu', 'goldAvgInternet': '11.344', 'csAvgInternet': '153.06'}
# {'championName': 'Vi', 'goldAvgInternet': '11.839', 'csAvgInternet': '168.17'}
# {'championName': 'Kayle', 'goldAvgInternet': '12.750', 'csAvgInternet': '211.01'}
# {'championName': 'Alistar', 'goldAvgInternet': '8.165', 'csAvgInternet': '30.74'}
# {'championName': 'Tahm Kench', 'goldAvgInternet': '9.824', 'csAvgInternet': '70.61'}
# {'championName': 'Gwen', 'goldAvgInternet': '12.319', 'csAvgInternet': '189.46'}
# {'championName': 'Graves', 'goldAvgInternet': '13.699', 'csAvgInternet': '202.54'}
# {'championName': 'Soraka', 'goldAvgInternet': '7.992', 'csAvgInternet': '27.45'}
# {'championName': 'Xayah', 'goldAvgInternet': '12.587', 'csAvgInternet': '205.15'}
# {'championName': 'Syndra', 'goldAvgInternet': '12.548', 'csAvgInternet': '193.49'}
# {'championName': 'Poppy', 'goldAvgInternet': '10.091', 'csAvgInternet': '96.3'}
# {'championName': 'Fiora', 'goldAvgInternet': '12.388', 'csAvgInternet': '192.14'}
# {'championName': "Vel'Koz", 'goldAvgInternet': '10.716', 'csAvgInternet': '95.98'}
# {'championName': 'Talon', 'goldAvgInternet': '12.797', 'csAvgInternet': '189.42'}
# {'championName': 'Ambessa', 'goldAvgInternet': '11.383', 'csAvgInternet': '177.6'}
# {'championName': 'Neeko', 'goldAvgInternet': '9.856', 'csAvgInternet': '79.68'}
# {'championName': 'Rakan', 'goldAvgInternet': '8.172', 'csAvgInternet': '31.36'}
# {'championName': 'Vex', 'goldAvgInternet': '11.711', 'csAvgInternet': '171.84'}
# {'championName': 'Naafiri', 'goldAvgInternet': '12.644', 'csAvgInternet': '179.25'}
# {'championName': 'Jayce', 'goldAvgInternet': '12.174', 'csAvgInternet': '196.51'}
# {'championName': 'Ryze', 'goldAvgInternet': '12.162', 'csAvgInternet': '209.31'}
# {'championName': 'Gragas', 'goldAvgInternet': '11.031', 'csAvgInternet': '161.33'}
# {'championName': 'Rell', 'goldAvgInternet': '8.570', 'csAvgInternet': '28.97'}
# {'championName': 'Azir', 'goldAvgInternet': '11.998', 'csAvgInternet': '202.25'}
# {'championName': 'Zac', 'goldAvgInternet': '11.139', 'csAvgInternet': '150.08'}
# {'championName': 'Ziggs', 'goldAvgInternet': '12.333', 'csAvgInternet': '188.83'}
# {'championName': 'Lillia', 'goldAvgInternet': '12.412', 'csAvgInternet': '185.31'}
# {'championName': 'Fiddlesticks', 'goldAvgInternet': '11.517', 'csAvgInternet': '145.23'}
# {'championName': 'Ornn', 'goldAvgInternet': '10.934', 'csAvgInternet': '170.35'}
# {'championName': 'Gangplank', 'goldAvgInternet': '13.668', 'csAvgInternet': '205.99'}
# {'championName': 'Nidalee', 'goldAvgInternet': '11.765', 'csAvgInternet': '155.28'}
# {'championName': 'Tryndamere', 'goldAvgInternet': '13.142', 'csAvgInternet': '210.95'}
# {'championName': 'Zoe', 'goldAvgInternet': '11.187', 'csAvgInternet': '145.63'}
# {'championName': 'Bard', 'goldAvgInternet': '9.093', 'csAvgInternet': '33.17'}
# {'championName': "K'Sante", 'goldAvgInternet': '10.904', 'csAvgInternet': '175.94'}
# {'championName': 'Urgot', 'goldAvgInternet': '12.827', 'csAvgInternet': '190.62'}
# {'championName': 'Riven', 'goldAvgInternet': '11.973', 'csAvgInternet': '181.42'}
# {'championName': 'Annie', 'goldAvgInternet': '11.325', 'csAvgInternet': '153.34'}
# {'championName': 'Illaoi', 'goldAvgInternet': '12.064', 'csAvgInternet': '189.33'}
# {'championName': 'Quinn', 'goldAvgInternet': '12.957', 'csAvgInternet': '172.2'}
# {'championName': 'Draven', 'goldAvgInternet': '13.484', 'csAvgInternet': '190.24'}
# {'championName': 'Zeri', 'goldAvgInternet': '13.219', 'csAvgInternet': '215.81'}
# {'championName': 'Sona', 'goldAvgInternet': '8.616', 'csAvgInternet': '29.53'}
# {'championName': 'Kindred', 'goldAvgInternet': '12.860', 'csAvgInternet': '178.11'}
# {'championName': 'Heimerdinger', 'goldAvgInternet': '11.778', 'csAvgInternet': '172.85'}
# {'championName': 'Hecarim', 'goldAvgInternet': '12.513', 'csAvgInternet': '194.15'}
# {'championName': 'Sejuani', 'goldAvgInternet': '11.269', 'csAvgInternet': '160.2'}
# {'championName': 'Maokai', 'goldAvgInternet': '9.384', 'csAvgInternet': '75.14'}
# {'championName': 'Evelynn', 'goldAvgInternet': '12.430', 'csAvgInternet': '158.83'}
# {'championName': 'Lissandra', 'goldAvgInternet': '11.582', 'csAvgInternet': '179.94'}
# {'championName': 'Janna', 'goldAvgInternet': '8.291', 'csAvgInternet': '28.37'}
# {'championName': 'Nunu & Willump', 'goldAvgInternet': '11.292', 'csAvgInternet': '152.34'}
# {'championName': 'Kennen', 'goldAvgInternet': '11.636', 'csAvgInternet': '170.62'}
# {'championName': 'Aurelion Sol', 'goldAvgInternet': '12.704', 'csAvgInternet': '192.83'}
# {'championName': 'Rengar', 'goldAvgInternet': '12.740', 'csAvgInternet': '180.43'}
# {'championName': 'Udyr', 'goldAvgInternet': '12.094', 'csAvgInternet': '186.15'}
# {'championName': 'Gnar', 'goldAvgInternet': '11.729', 'csAvgInternet': '180.77'}
# {'championName': 'Elise', 'goldAvgInternet': '11.596', 'csAvgInternet': '129.14'}
# {'championName': 'Camille', 'goldAvgInternet': '11.719', 'csAvgInternet': '163.66'}
# {'championName': 'Kled', 'goldAvgInternet': '12.138', 'csAvgInternet': '171.49'}
# {'championName': 'Qiyana', 'goldAvgInternet': '12.255', 'csAvgInternet': '168.5'}
# {'championName': 'Zilean', 'goldAvgInternet': '9.012', 'csAvgInternet': '61.25'}
# {'championName': 'Akshan', 'goldAvgInternet': '13.104', 'csAvgInternet': '176.89'}
# {'championName': 'Taliyah', 'goldAvgInternet': '11.716', 'csAvgInternet': '187.14'}
# {'championName': 'Rammus', 'goldAvgInternet': '11.173', 'csAvgInternet': '152.13'}
# {'championName': "Kog'Maw", 'goldAvgInternet': '12.957', 'csAvgInternet': '184.78'}
# {'championName': 'Corki', 'goldAvgInternet': '12.540', 'csAvgInternet': '205.25'}
# {'championName': 'Anivia', 'goldAvgInternet': '11.379', 'csAvgInternet': '170.72'}
# {'championName': 'Singed', 'goldAvgInternet': '12.453', 'csAvgInternet': '216.55'}
# {'championName': 'Nilah', 'goldAvgInternet': '13.319', 'csAvgInternet': '190.27'}
# {'championName': "Bel'Veth", 'goldAvgInternet': '12.493', 'csAvgInternet': '183.56'}
# {'championName': 'Kassadin', 'goldAvgInternet': '12.228', 'csAvgInternet': '178.55'}
# {'championName': 'Karthus', 'goldAvgInternet': '13.526', 'csAvgInternet': '203.06'}
# {'championName': 'Shyvana', 'goldAvgInternet': '12.723', 'csAvgInternet': '208.88'}
# {'championName': 'Olaf', 'goldAvgInternet': '12.472', 'csAvgInternet': '184.64'}
# {'championName': 'Rumble', 'goldAvgInternet': '11.485', 'csAvgInternet': '176.51'}
# {'championName': 'Cassiopeia', 'goldAvgInternet': '11.782', 'csAvgInternet': '185.78'}
# {'championName': 'Ivern', 'goldAvgInternet': '10.478', 'csAvgInternet': '135.61'}
# {'championName': 'Renata Glasc', 'goldAvgInternet': '8.529', 'csAvgInternet': '33.39'}
# {'championName': 'Taric', 'goldAvgInternet': '8.546', 'csAvgInternet': '41.52'}
# {'championName': "Rek'Sai", 'goldAvgInternet': '11.831', 'csAvgInternet': '157.63'}
# {'championName': 'Kalista', 'goldAvgInternet': '12.617', 'csAvgInternet': '181.06'}
# {'championName': 'Skarner', 'goldAvgInternet': '10.497', 'csAvgInternet': '143.27'}
# {'championName': '', 'goldAvgInternet': 'NaN', 'csAvgInternet': 'NaN'}

# %%
#9 average Gold per Minute for Champ and Role -- Continuation
def clean_name(name):
    if pd.isna(name):
        return ""
    return re.sub(r'[^A-Za-z0-9]', '', name).upper()

champion_gold_df = pd.DataFrame(champ_data)

#Unify championName
champion_gold_df['championName'] = champion_gold_df['championName'].apply(clean_name)
df_ranked['championName']      = df_ranked['championName'].apply(clean_name)
df_ranked['tier']              = df_ranked['tier'].str.strip().str.upper()

champion_gold_df['goldAvgInternet'] = (
    champion_gold_df['goldAvgInternet']
    .str.replace('.', '', regex=False)
    .str.replace(',', '.', regex=False)
    .astype(float)
)

#Average gametime per rank
def compute_time(x: float) -> float:
    m = int(x)
    s = int((x - m) * 100)
    return (m*60 + s) / 60.0

Ranked_Solo_Duo = {
    tier: compute_time(val)
    for tier, val in {
        'IRON':   30.36, 'BRONZE': 30.44, 'SILVER': 30.33,
        'GOLD':   30.05, 'PLATINUM':29.32, 'EMERALD':28.54,
        'DIAMOND':28.02, 'MASTER':26.58, 'GRANDMASTER':26.36,
        'CHALLENGER':26.11
    }.items()
}

df_ranked = df_ranked.merge(
    champion_gold_df[['championName','goldAvgInternet']],
    on='championName',
    how='left'
)

df_ranked['avgGameTime'] = df_ranked['tier'].map(Ranked_Solo_Duo)

df_ranked['internetGoldPerMinute'] = (
    df_ranked['goldAvgInternet'] / df_ranked['avgGameTime']
)

df_ranked['gpmDelta'] = df_ranked['goldPerMinute'] - df_ranked['internetGoldPerMinute']

display(df_ranked[['puuid','championName','tier',
                   'goldAvgInternet','avgGameTime',
                   'internetGoldPerMinute','goldPerMinute','gpmDelta']].head(10))
# Out:
#                                                puuid championName    tier  \
# 0  NS6Iz_PJ1jLlCCDSZbhC-_tSB0XDiTQFp_M4cUgNCbR7gM...        MILIO    IRON
# 1  BNEeQVLI4LHlAOpNrf_1UGzcPx5LgiKXPfKKIWReTwdPxK...     VOLIBEAR    IRON
# 2  zJnf3VYJutq8lqOnD_iXDlhmETkk1dULIZTWft2r-fkWCC...          MEL  BRONZE
# 3  HwKU5bDk89rnr5yqXQwopXSh0x0z2tQXCWv4ewx0NtC0-L...       YUNARA  BRONZE
# 4  ck-5nJvjkpmGgyNJnH_A3nMv_A7EJ0uJ3fZkN3WbsMLX3K...          LUX    IRON
# 5  o191uU3FbQtcsvE8yyt2t3BTLS8OSGcP2kTd_k4CyORRrD...         ORNN    IRON
# 6  wTyVkOGGuLbbKT67eA6ODpv4sZhNiQ_HxmHsskv0EQPokf...        VIEGO    IRON
# 7  iEOB7U0XtKLdQBsUyIZJo9VSvlzTmARr5qgt5Xj5-Aox-2...  MISSFORTUNE    IRON
# 8  66aOL25UEOjXIL69Aw6IgTd4zKy92ErHKw1yYnxpL6afY_...   CASSIOPEIA    IRON
# 9  BHE9669t6XKq-5nDU4_yfciEDEvHgcPtOC5aTgft-lhAd3...         PYKE  BRONZE
#
#    goldAvgInternet  avgGameTime  internetGoldPerMinute  goldPerMinute  \
# 0           8125.0    30.583333             265.667575     319.533989
# 1          12149.0    30.583333             397.242507     398.448854
# 2          11971.0    30.733333             389.511931     515.775330
# 3          11180.0    30.733333             363.774403     406.333079
# 4          10593.0    30.583333             346.365123     410.158061
# 5          10934.0    30.583333             357.514986     315.566766
# 6          12822.0    30.583333             419.247956     324.173926
# 7          12918.0    30.583333             422.386921     475.738465
# 8          11782.0    30.583333             385.242507     366.274107
# 9          10128.0    30.733333             329.544469     258.730841
#
#      gpmDelta
# 0   53.866414
# 1    1.206347
# 2  126.263400
# 3   42.558676
# 4   63.792939
# 5  -41.948221
# 6  -95.074030
# 7   53.351544
# 8  -18.968400
# 9  -70.813628

# %%
#10. Time to first full Item

# There is no possible metric for first full Item
# However we could estimate the first item time by applying the goldPerMinute feature on the first bought item cost

url = 'https://wiki.leagueoflegends.com/en-us/List_of_items'
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")

# Search for legendary items and their URLs

item_names = []
item_links = []
legendary_items = []

for dt in soup.find_all('dt'):
    if "Legendary items" in dt.text:
        legendary_div = dt.find_next('div', class_='tlist')
        if legendary_div:
            for item in legendary_div.find_all('li'):
                icon_div = item.find('div', class_='item-icon')
                if icon_div:
                    name = icon_div.get('data-item', '')
                    a_tag = item.find('a', href=True)
                    link = 'https://wiki.leagueoflegends.com' + a_tag['href'] if a_tag else ''
                    item_names.append(name)
                    item_links.append(link)
        break

# Visit every URL and find out what the item cost and ID is

for i in range(len(item_links)):
    url = item_links[i]
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")

    infobox = soup.find('div', class_='infobox-section-cell')

    cost = ''
    item_id = ''
    if infobox:
        rows = infobox.find_all('div', class_='infobox-data-row')
        for row in rows:
            label = row.find('div', class_='infobox-data-label')
            value = row.find('div', class_='infobox-data-value')
            if not label or not value:
                continue
            # Extract item costs
            if 'Cost' in label.text:
                gold_span = value.find('span', style=lambda x: x and 'color:#E2BA3D' in x)
                if gold_span:
                    cost_text = gold_span.find_all('span')[-1].text.strip()
                    cost = cost_text
            # Extract item ID
            if label.text.strip() == 'ID':
                item_id = value.text.strip()
    legendary_items.append({'name': item_names[i], 'cost': cost, 'id': item_id})

print(legendary_items)
# Out:
# [{'name': 'Abyssal Mask', 'cost': '2650', 'id': '8020'}, {'name': "Archangel's Staff", 'cost': '2900', 'id': '3003'}, {'name': 'Ardent Censer', 'cost': '2200', 'id': '3504'}, {'name': 'Axiom Arc', 'cost': '3000', 'id': '6696'}, {'name': "Banshee's Veil", 'cost': '3000', 'id': '3102'}, {'name': 'Black Cleaver', 'cost': '3000', 'id': '3071'}, {'name': 'Blackfire Torch', 'cost': '2800', 'id': '2503'}, {'name': 'Blade of the Ruined King', 'cost': '3200', 'id': '3153'}, {'name': "Bloodletter's Curse", 'cost': '2900', 'id': '8010'}, {'name': 'Bloodsong', 'cost': '400', 'id': '3877'}, {'name': 'Bloodthirster', 'cost': '3400', 'id': '3072'}, {'name': 'Bounty of Worlds', 'cost': '400', 'id': '3867'}, {'name': 'Celestial Opposition', 'cost': '400', 'id': '3869'}, {'name': 'Chempunk Chainsword', 'cost': '3100', 'id': '6609'}, {'name': 'Cosmic Drive', 'cost': '3000', 'id': '4629'}, {'name': 'Cryptbloom', 'cost': '3000', 'id': '3137'}, {'name': 'Dawncore', 'cost': '2500', 'id': '6621'}, {'name': "Dead Man's Plate", 'cost': '2900', 'id': '3742'}, {'name': "Death's Dance", 'cost': '3300', 'id': '6333'}, {'name': 'Dream Maker', 'cost': '400', 'id': '3870'}, {'name': 'Echoes of Helia', 'cost': '2200', 'id': '6620'}, {'name': 'Eclipse', 'cost': '2900', 'id': '6692'}, {'name': 'Edge of Night', 'cost': '3000', 'id': '3814'}, {'name': 'Essence Reaver', 'cost': '2900', 'id': '3508'}, {'name': 'Experimental Hexplate', 'cost': '3000', 'id': '3073'}, {'name': 'Fimbulwinter', 'cost': '2400', 'id': '3121'}, {'name': 'Force of Nature', 'cost': '2800', 'id': '4401'}, {'name': 'Frozen Heart', 'cost': '2500', 'id': '3110'}, {'name': 'Guardian Angel', 'cost': '3200', 'id': '3026'}, {'name': "Guinsoo's Rageblade", 'cost': '3000', 'id': '3124'}, {'name': 'Heartsteel', 'cost': '3000', 'id': '3084'}, {'name': 'Hextech Rocketbelt', 'cost': '2650', 'id': '3152'}, {'name': 'Hollow Radiance', 'cost': '2800', 'id': '6664'}, {'name': 'Horizon Focus', 'cost': '2800', 'id': '4628'}, {'name': 'Hubris', 'cost': '3000', 'id': '6697'}, {'name': 'Hullbreaker', 'cost': '3000', 'id': '3181'}, {'name': 'Iceborn Gauntlet', 'cost': '2900', 'id': '6662'}, {'name': 'Immortal Shieldbow', 'cost': '3000', 'id': '6673'}, {'name': 'Imperial Mandate', 'cost': '2250', 'id': '4005'}, {'name': 'Infinity Edge', 'cost': '3450', 'id': '3031'}, {'name': "Jak'Sho, The Protean", 'cost': '3200', 'id': '6665'}, {'name': 'Kaenic Rookern', 'cost': '2900', 'id': '2504'}, {'name': "Knight's Vow", 'cost': '2300', 'id': '3109'}, {'name': 'Kraken Slayer', 'cost': '3000', 'id': '6672'}, {'name': "Liandry's Torment", 'cost': '3000', 'id': '6653'}, {'name': 'Lich Bane', 'cost': '2900', 'id': '3100'}, {'name': 'Locket of the Iron Solari', 'cost': '2200', 'id': '3190'}, {'name': "Lord Dominik's Regards", 'cost': '3100', 'id': '3036'}, {'name': "Luden's Companion", 'cost': '2750', 'id': '6655'}, {'name': 'Malignance', 'cost': '2700', 'id': '3118'}, {'name': 'Manamune', 'cost': '2900', 'id': '3004'}, {'name': 'Maw of Malmortius', 'cost': '3100', 'id': '3156'}, {'name': "Mejai's Soulstealer", 'cost': '1500', 'id': '3041'}, {'name': 'Mercurial Scimitar', 'cost': '3200', 'id': '3139'}, {'name': "Mikael's Blessing", 'cost': '2300', 'id': '3222'}, {'name': 'Moonstone Renewer', 'cost': '2200', 'id': '6617'}, {'name': 'Morellonomicon', 'cost': '2850', 'id': '3165'}, {'name': 'Mortal Reminder', 'cost': '3300', 'id': '3033'}, {'name': 'Muramana', 'cost': '2900', 'id': '3042'}, {'name': "Nashor's Tooth", 'cost': '2900', 'id': '3115'}, {'name': 'Navori Flickerblade', 'cost': '2650', 'id': '6675'}, {'name': 'Opportunity', 'cost': '2700', 'id': '6701'}, {'name': "Overlord's Bloodmail", 'cost': '3300', 'id': '2501'}, {'name': 'Phantom Dancer', 'cost': '2650', 'id': '3046'}, {'name': 'Profane Hydra', 'cost': '3200', 'id': '6698'}, {'name': "Rabadon's Deathcap", 'cost': '3500', 'id': '3089'}, {'name': "Randuin's Omen", 'cost': '2700', 'id': '3143'}, {'name': 'Rapid Firecannon', 'cost': '2650', 'id': '3094'}, {'name': 'Ravenous  ...

# %%
#10. Time to first full Item - Continuation

# if item_id in items, then we take the first entry and take the costs and look how much gold per minute he has

id_to_cost = {str(item['id']): int(item['cost']) for item in legendary_items if 'id' in item and 'cost' in item}
print(id_to_cost)

legendary_ids = set(id_to_cost.keys())

def first_legendary_stats(row):
    items = [str(row[f'item{i}']) for i in range(7) if f'item{i}' in row]
    for item in items:
        if item in legendary_ids:
            cost = id_to_cost[item]
            if cost >= 500:  # Filter out evolved support items, because they cost 400G and count as legendary
                gpm = row['goldPerMinute']
                minutes_needed = round(cost / gpm, 2) if gpm > 0 else None
                return pd.Series({
                    'first_legendary_id': item,
                    'first_legendary_cost': cost,
                    'first_legendary_minutes': minutes_needed
                })
    return pd.Series({'first_legendary_id': None, 'first_legendary_cost': None, 'first_legendary_minutes': None})

# Apply on DataFrame:
df_ranked = df_ranked.join(df_ranked.apply(first_legendary_stats, axis=1))
df_ranked['first_legendary_id'] = df_ranked['first_legendary_id'].fillna(0)

print(df_ranked[['puuid','first_legendary_id', 'first_legendary_cost', 'first_legendary_minutes']].head(20))
# Out:
# {'8020': 2650, '3003': 2900, '3504': 2200, '6696': 3000, '3102': 3000, '3071': 3000, '2503': 2800, '3153': 3200, '8010': 2900, '3877': 400, '3072': 3400, '3867': 400, '3869': 400, '6609': 3100, '4629': 3000, '3137': 3000, '6621': 2500, '3742': 2900, '6333': 3300, '3870': 400, '6620': 2200, '6692': 2900, '3814': 3000, '3508': 2900, '3073': 3000, '3121': 2400, '4401': 2800, '3110': 2500, '3026': 3200, '3124': 3000, '3084': 3000, '3152': 2650, '6664': 2800, '4628': 2800, '6697': 3000, '3181': 3000, '6662': 2900, '6673': 3000, '4005': 2250, '3031': 3450, '6665': 3200, '2504': 2900, '3109': 2300, '6672': 3000, '6653': 3000, '3100': 2900, '3190': 2200, '3036': 3100, '6655': 2750, '3118': 2700, '3004': 2900, '3156': 3100, '3041': 1500, '3139': 3200, '3222': 2300, '6617': 2200, '3165': 2850, '3033': 3300, '3042': 2900, '3115': 2900, '6675': 2650, '6701': 2700, '2501': 3300, '3046': 2650, '6698': 3200, '3089': 3500, '3143': 2700, '3094': 2650, '3074': 3300, '3107': 2300, '4633': 3100, '6657': 2600, '3085': 2650, '3116': 2600, '3040': 2900, '6695': 2500, '6694': 3000, '4645': 3200, '2065': 2200, '3876': 400, '3161': 3100, '224004': 2800, '3065': 2700, '6616': 2250, '3087': 2700, '3053': 3200, '4646': 2800, '6631': 3300, '6610': 3100, '3068': 2700, '3302': 3000, '6676': 3000, '3075': 2450, '3748': 3300, '3002': 2400, '3078': 3333, '3179': 2500, '2502': 2800, '4643': 2300, '3135': 3000, '6699': 3000, '3083': 3100, '3119': 2400, '3091': 2800, '3142': 2800, '3032': 3000, '3871': 400, '3050': 2200, '3157': 3250}
#                                                 puuid first_legendary_id  \
# 0   NS6Iz_PJ1jLlCCDSZbhC-_tSB0XDiTQFp_M4cUgNCbR7gM...               6653
# 1   BNEeQVLI4LHlAOpNrf_1UGzcPx5LgiKXPfKKIWReTwdPxK...               4629
# 2   zJnf3VYJutq8lqOnD_iXDlhmETkk1dULIZTWft2r-fkWCC...               2503
# 3   HwKU5bDk89rnr5yqXQwopXSh0x0z2tQXCWv4ewx0NtC0-L...               3032
# 4   ck-5nJvjkpmGgyNJnH_A3nMv_A7EJ0uJ3fZkN3WbsMLX3K...               6655
# 5   o191uU3FbQtcsvE8yyt2t3BTLS8OSGcP2kTd_k4CyORRrD...               3084
# 6   wTyVkOGGuLbbKT67eA6ODpv4sZhNiQ_HxmHsskv0EQPokf...               3078
# 7   iEOB7U0XtKLdQBsUyIZJo9VSvlzTmARr5qgt5Xj5-Aox-2...               2503
# 8   66aOL25UEOjXIL69Aw6IgTd4zKy92ErHKw1yYnxpL6afY_...               3040
# 9   BHE9669t6XKq-5nDU4_yfciEDEvHgcPtOC5aTgft-lhAd3...               3179
# 10  VecACGBYGaYN4rYoAdHr3nox4uAZERedMRHLuR8lqj9Z0P...               6673
# 11  -WbLudFHyoIYrQJ6XV-5MtWisSVjjweLp8S19KcZXWh3uy...               3100
# 12  vYQLI-rTA_2HuEUjwW3CzaD3J6ozUP-hXU0ogVPeruCNmh...               2503
# 13  LKEJUSbX118NCvq71N5d2Lt2VIowd9fc0JKSEC_jSJkwA_...               3078
# 14  D0eNXuIl7MQsskZFlosVNWJqV1jZ3zyR5nLk3sCEgIUcAT...               3115
# 15  BOIe8vqhUfX27L0ES02Lp9xTRAUmQ8Xo-ng8xI0Dud0WB1...               3089
# 16  fgUmO3_kqZR3_nqvigkrL520DlCQZE5sG3TU2Df6bCL77G...               3157
# 17  X0QMYETs5b_hLPUQXH04wKXc1YCxHQvN-Ug2C7AjkUUqir...               6333
# 18  ytrGkn0K2g55uOg5Y07ki0BeFJGbSAvLJLhG7gfqTb7h7L...               4646
# 19  MoE3lvLHqwAw4XzcBuh5na8rskmd9rpMZzfw9mUKEqdIJG...               3089
#
#     first_legendary_cost  first_legendary_minutes
# 0                 3000.0                     9.39
# 1                 3000.0                     7.53
# 2                 2800.0                     5.43
# 3                 3000.0                     7.38
# 4                 2750.0                     6.70
# 5                 3000.0                     9.51
# 6                 3333.0                    10.28
# 7                 2800.0                     5.89
# 8                 2900.0                     7.92
# 9                 2500.0                     9.66
# 10                3000.0                     7.50
# 11                2900.0                     7.10
# 12                2800.0                     7.07
# 13                3333.0                     8.98
# 14                2900.0                     6.00
# 15                3500.0                     6.27
# 16                3250.0                     7.83
# 17                3300.0                     6.73
# 18                2800.0                     5.85
# 19                3500.0                     8.42

# %%
#12. Off-Meta Champs 

with open("champ-stats.html", encoding="utf-8") as f:
    html = f.read()

soup = BeautifulSoup(html, "html.parser")

color_to_tier = {
    "#0093ff": "1",
    "#00bba3": "2",
    "#ffb900": "3",
    "#9aa4af": "4",
    "#a88a67": "5"
}

champ_data_tier = []

rows = soup.find_all('tr')

for row in rows:
    cols = row.find_all('td')
    if len(cols) < 8:
        continue
    tier = None
    svg_tag_tier = cols[2].find('svg')
    if svg_tag_tier:
        path_tag_tier = svg_tag_tier.find('path')
        if path_tag_tier and path_tag_tier.has_attr('fill'):
            color = path_tag_tier['fill'].lower()
            tier = color_to_tier.get(color)

    role = None
    svg_tag_role = cols[3].find('svg')
    if svg_tag_role:
        for path_tag_role in svg_tag_role.find_all('path'):
            d_code = path_tag_role.get('d', '').lower().strip()
            opacity = path_tag_role.get('opacity')
            # BOT/TOP Special case:
            if d_code == "m19 3-4 4h7v8l-4 4v3z":
                if opacity == "0.2":
                    role = "BOT"
                else:
                    role = "TOP"
                break
            # Jungle
            elif "m5.14 2c1.58" in d_code:
                role = "JUNGLE"
                break
            # Mid
            elif "m15 3-4 4h7v4l-4 4v3z" in d_code:
                role = "MID"
                break
            # Utility
            elif "m12.833 10.833" in d_code or "14.5 17.53" in d_code:
                role = "UTILITY"
                break

    name_a = cols[1].find("a")
    name = name_a.text.strip() if name_a else cols[1].text.strip()
    winrate = cols[4].text.strip() if len(cols) > 4 else ""
    pickrate = cols[5].text.strip() if len(cols) > 5 else ""
    champ_data_tier.append({
        'champion': name,
        'role': role,
        'tier': tier,
        'winrate': winrate,
        'pickrate': pickrate
    })
for c in champ_data_tier:
    print(c)
# Out:
# {'champion': 'Trundle', 'role': 'JUNGLE', 'tier': None, 'winrate': '53.35%', 'pickrate': '9.35%'}
# {'champion': 'Volibear', 'role': 'JUNGLE', 'tier': '1', 'winrate': '52.74%', 'pickrate': '6.23%'}
# {'champion': 'Briar', 'role': 'JUNGLE', 'tier': '1', 'winrate': '52.69%', 'pickrate': '5.04%'}
# {'champion': 'Milio', 'role': 'UTILITY', 'tier': '1', 'winrate': '52.63%', 'pickrate': '6.41%'}
# {'champion': 'Warwick', 'role': 'JUNGLE', 'tier': '1', 'winrate': '52.45%', 'pickrate': '7.56%'}
# {'champion': 'Nami', 'role': 'UTILITY', 'tier': '1', 'winrate': '52.22%', 'pickrate': '8.76%'}
# {'champion': 'Mordekaiser', 'role': 'TOP', 'tier': '1', 'winrate': '52.14%', 'pickrate': '8.61%'}
# {'champion': 'Sett', 'role': 'TOP', 'tier': '1', 'winrate': '52.06%', 'pickrate': '9.1%'}
# {'champion': 'Malzahar', 'role': 'MID', 'tier': '1', 'winrate': '52.03%', 'pickrate': '7.51%'}
# {'champion': 'Sivir', 'role': 'BOT', 'tier': '1', 'winrate': '51.83%', 'pickrate': '9.71%'}
# {'champion': 'Xerath', 'role': 'MID', 'tier': '1', 'winrate': '51.8%', 'pickrate': '3.75%'}
# {'champion': 'Diana', 'role': 'MID', 'tier': '1', 'winrate': '51.57%', 'pickrate': '4.89%'}
# {'champion': 'Nocturne', 'role': 'JUNGLE', 'tier': '1', 'winrate': '51.55%', 'pickrate': '8.43%'}
# {'champion': 'Veigar', 'role': 'MID', 'tier': '1', 'winrate': '51.49%', 'pickrate': '5.42%'}
# {'champion': 'Lux', 'role': 'MID', 'tier': '1', 'winrate': '51.34%', 'pickrate': '4.75%'}
# {'champion': 'Fizz', 'role': 'MID', 'tier': '1', 'winrate': '51.31%', 'pickrate': '4.6%'}
# {'champion': 'Leona', 'role': 'UTILITY', 'tier': '1', 'winrate': '51.21%', 'pickrate': '7.46%'}
# {'champion': 'Jinx', 'role': 'BOT', 'tier': '1', 'winrate': '51.2%', 'pickrate': '14.31%'}
# {'champion': 'Morgana', 'role': 'UTILITY', 'tier': '1', 'winrate': '51.07%', 'pickrate': '7.5%'}
# {'champion': 'Galio', 'role': 'MID', 'tier': '1', 'winrate': '51.06%', 'pickrate': '5.04%'}
# {'champion': 'Lulu', 'role': 'UTILITY', 'tier': '1', 'winrate': '50.85%', 'pickrate': '10.09%'}
# {'champion': 'Akali', 'role': 'MID', 'tier': '1', 'winrate': '50.23%', 'pickrate': '7.69%'}
# {'champion': 'Viego', 'role': 'JUNGLE', 'tier': '1', 'winrate': '50.16%', 'pickrate': '13.45%'}
# {'champion': 'Yasuo', 'role': 'MID', 'tier': '1', 'winrate': '49.95%', 'pickrate': '9.62%'}
# {'champion': 'Swain', 'role': 'MID', 'tier': '2', 'winrate': '52.86%', 'pickrate': '1.1%'}
# {'champion': 'Naafiri', 'role': 'MID', 'tier': '2', 'winrate': '52.46%', 'pickrate': '1.12%'}
# {'champion': 'Warwick', 'role': 'TOP', 'tier': '2', 'winrate': '52.36%', 'pickrate': '2.95%'}
# {'champion': 'Sona', 'role': 'UTILITY', 'tier': '2', 'winrate': '52.24%', 'pickrate': '3.63%'}
# {'champion': 'Smolder', 'role': 'BOT', 'tier': '2', 'winrate': '51.89%', 'pickrate': '7.29%'}
# {'champion': 'Soraka', 'role': 'UTILITY', 'tier': '2', 'winrate': '51.82%', 'pickrate': '4.49%'}
# {'champion': 'Vayne', 'role': 'BOT', 'tier': '2', 'winrate': '51.8%', 'pickrate': '7.59%'}
# {'champion': 'Jax', 'role': 'JUNGLE', 'tier': '2', 'winrate': '51.71%', 'pickrate': '2.69%'}
# {'champion': 'Yorick', 'role': 'TOP', 'tier': '2', 'winrate': '51.65%', 'pickrate': '4.85%'}
# {'champion': 'Malphite', 'role': 'TOP', 'tier': '2', 'winrate': '51.61%', 'pickrate': '6.01%'}
# {'champion': 'Amumu', 'role': 'JUNGLE', 'tier': '2', 'winrate': '51.4%', 'pickrate': '4.13%'}
# {'champion': 'Jarvan IV.', 'role': 'JUNGLE', 'tier': '2', 'winrate': '51.33%', 'pickrate': '6.33%'}
# {'champion': 'Zyra', 'role': 'UTILITY', 'tier': '2', 'winrate': '51.31%', 'pickrate': '3.92%'}
# {'champion': 'Ekko', 'role': 'MID', 'tier': '2', 'winrate': '51.22%', 'pickrate': '3.28%'}
# {'champion': 'Wukong', 'role': 'JUNGLE', 'tier': '2', 'winrate': '51.17%', 'pickrate': '4.27%'}
# {'champion': 'Teemo', 'role': 'TOP', 'tier': '2', 'winrate': '51.16%', 'pickrate': '5.64%'}
# {'champion': 'Vex', 'role': 'MID', 'tier': '2', 'winrate': '50.96%', 'pickrate': '4.04%'}
# {'champion': 'Dr. Mundo', 'role': 'TOP', 'tier': '2', 'winrate': '50.91%', 'pickrate': '6.34%'}
# {'champion': 'Garen', 'role': 'TOP', 'tier': '2', 'winrate': '50.9%', 'pickrate': '6.15%'}
# {'champion': 'Ekko', 'role': 'JUNGLE', 'tier': '2', 'winrate': '50.84%', 'pickrate': '4.65%'}
# {'champion': 'Miss Fortune', 'role': 'BOT', 'tier': '2', 'winrate': '50.79%', 'pickrate': '11.29%'}
# {'champion': 'Xin Zhao', 'role': 'JUNGLE', 'tier': '2', 'winrate': '50.71%', 'pickrate': '6.08%'}
# {'champion': 'Irelia', 'role': 'MID', 'tier': '2', 'winrate': '50.63%', 'pickrate': '3.22%'}
# {'champion': 'Braum', 'role': 'UTILITY', 'tier': '2', 'winrate': '50.58%', 'pickrate': '4.8%'}
# {'champion': 'Master Yi', 'role': 'JUNGLE', 'tier': '2', 'winrate': '50.52%', 'pickrate': '7.25%'}
# {'champion': 'Diana', 'role': 'JUNGLE', 'tier': '2', 'winrate': '50.33%', 'pickrate': '5.56%'}
# {'champion': 'Thresh', 'role': 'UTILITY', 'tier': '2', 'winrate': '50.12%', 'pickrate': '10.55%'}
# {'champion': 'Viktor', 'role': 'MID', 'tier': '2', 'winrate': '50.04%', 'pickrate': '5.15%'}
# {'champion': 'LeBlanc', 'role': 'MID', 'tier': '2', 'winrate': '49.98%', 'pickrate': '4.79%'}
# {'champion': 'Lux', 'role': 'UTILITY', 'tier': '2', 'winrate': '49.97%', 'pickrate': '11.26%'}
# {'champion': "Kha'Zix", 'role': 'JUNGLE', 'tier': '2', 'winrate': '49.92%', 'pickrate': '5.39%'}
# {'champion': 'Jhin', 'role': 'BOT', 'tier': '2', 'winrate': '49.86%', 'pickrate': '15.44%'}
# {'champion': 'Kayn', 'role': 'JUNGLE', 'tier': '2', 'winrate': '49.82%', 'pickrate': '8.84%'}
# {'champion': "Kai'Sa", 'role': 'BOT', 'tier': '2', 'winrate': '49.64%', 'pickrate': '16.54%'}
# {'champion': 'Caitlyn', 'role': 'BOT', 'tier': '2', 'winrate': '49.6%', 'pickrate': '14.89%'}
# {'champion': 'Sylas', 'role': 'MID', 'tier': '2', 'winrate': '49.45%', 'pickrate': '8.79%'}
# {'champion': 'Nautilus', 'role': 'UTILITY', 'tier': '2', 'winrate': '49.3%', 'pickrate': '9.52%'}
# {'champion': 'Ahri', 'role': 'MID', 'tier': '2', 'winrate': '49.26%', 'pickrate': '10.74%'}
# {'champion': 'Shaco', 'role': 'JUNGLE', 'tier': '2', 'winrate': '49.25%', 'pickrate': '5.93%'}
# {'champion': 'Lee Sin', 'role': 'JUNGLE', 'tier': '2', 'winrate': '48.22%', 'pickrate': '10.46%'}
# {'champion': 'Kayle', 'role': 'MID', 'tier': '3', 'winrate': '52.77%', 'pickrate': '0.84%'}
# {'champion': 'Nilah', 'role': 'BOT', 'tier': '3', 'winrate': '52.67%', 'pickrate': '1.99%'}
# {'champion': "Kog'Maw", 'role': 'BOT', 'tier': '3', 'winrate': '52.52%', 'pickrate': '2.11%'}
# {'champion': 'Taric', 'role': 'UTILITY', 'tier': '3', 'winrate': '52.34%', 'pickrate': '1.21%'}
# {'champion': 'Heimerdinger', 'role': 'MID', 'tier': '3', 'winrate': '52.33%', 'pickrate': '0.62%'}
# {'champion': 'Teemo', 'role': 'UTILITY', 'tier': '3', 'winrate': '52.2%', 'pickrate': '1.36%'}
# {'champion': 'Kennen', 'role': 'MID', 'tier': '3', 'winrate': '52.11%', 'pickrate': '0.56%'}
# {'champion': 'Urgot', 'role': 'TOP', 'tier': '3', 'winrate': '51.79%', 'pickrate': '3.07%'}
# {'champion': 'Rammus', 'role': 'JUNGLE', 'tier': '3', 'winrate': '51.77%', 'pickrate': '2.01%'}
# {'champion': 'Malphite', 'role': 'MID', 'tier': '3', 'winrate': '51.76%', 'pickrate': '1.22%'}
# {'champion': 'Morgana', 'role': 'MID', 'tier': '3', 'winrate': '51.63%', 'pickrate': '0.66%'}
# {'champion': 'Kayle', 'role': 'TOP', 'tier': '3', 'winrate': '51.57%', 'pickrate': '3.59%'}
# {'champion': 'Janna', 'role': 'UTILITY', 'tier': '3', 'winrate': '51.43%', 'pickrate': '2.56%'}
# {'champion': "Vel'Koz", 'role': 'UTILITY', 'tier': '3', 'winrate': '51.42%', 'pickrate': '2.82%'}
# {'champion': "Vel'Koz", 'role': 'MID', 'tier': '3', 'winrate': '51.35%', 'pickrate': '1.11%'}
# {'champion': 'Teemo', 'role': 'JUNGLE', 'tier': '3', 'winrate': '51.32%', 'pickrate': '1.13%'}
# {'champion': 'Pantheon', 'role': 'MID', 'tier': '3', 'winrate': '51.23%', 'pickrate': '0.95%'}
# {'champion': 'Ornn', 'role': 'TOP', 'tier': '3', 'winrate': '51.23%', 'pickrate': '3.24%'}
# {'champion': 'Anivia', 'role': 'MID', 'tier': '3', 'winrate': '51.21%', 'pickrate': '1.67%'}
# {'champion': 'Quinn', 'role': 'TOP', 'tier': '3', 'winrate': '51.11%', 'pickrate': '2.44%'}
# {'champion': 'Twitch', 'role': 'BOT', 'tier': '3', 'winrate': '51.06%', 'pickrate': '4.63%'}
# {'champion': 'Zilean', 'role': 'UTILITY', 'tier': '3', 'winrate': '51.06%', 'pickrate': '2.06%'}
# {'champion': 'Aurelion Sol', 'role': 'MID', 'tier': '3', 'winrate': '51.02%', 'pickrate': '2.14%'}
# {'champion': 'Nasus', 'role': 'TOP', 'tier': '3', 'winrate': '51%', 'pickrate': '4.15%'}
# {'champion': "Cho'Gath", 'role': 'TOP', 'tier': '3', 'winrate': '50.92%', 'pickrate': '3.78%'}
# {'champion': 'Maokai', 'role': 'UTILITY', 'tier': '3', 'winrate': '50.83%', 'pickrate': '1.99%'}
# {'champion': 'Poppy', 'role': 'UTILITY', 'tier': '3', 'winrate': '50.83%', 'pickrate': '2.28%'}
# {'champion': 'Annie', 'role': 'MID', 'tier': '3', 'winrate': '50.68%', 'pickrate': '2.51%'}
# {'champion': 'Rell', 'role': 'UTILITY', 'tier': '3', 'winrate': '50.63%', 'pickrate': '3.76%'}
# {'champion': 'Trundle', 'role': 'TOP', 'tier': '3', 'winrate': '50.61%', 'pickrate': '2.74%'}
# {'champion': 'Shen', 'role': 'TOP', 'tier': '3', 'winrate': '50.59%', 'pickrate': '3.53%'}
# {'champion': 'Lissandra', 'role': 'MID', 'tier': '3', 'winrate': '50.56%', 'pickrate': '2.36%'}
# {'champion': 'Ashe', 'role': 'BOT', 'tier': '3', 'winrate': '50.53%', 'pickrate': '8.79%'}
# {'champion': 'Samira', 'role': 'BOT', 'tier': '3', 'winrate': '50.5%', 'pickrate': '5.26%'}
# {'champion': 'Vladimir', 'role': 'MID', 'tier': '3', 'winrate': '50.46%', 'pickrate': '3.34%'}
# {'champion': 'Sion', 'role': 'TOP', 'tier': '3', 'winrate': '50.45%', 'pickrate': '3.96%'}
# {'champion': 'Irelia', 'role': 'TOP', 'tier': '3', 'winrate': '50.4%', 'pickrate': '4.08%'}
# {'champion': 'Bard', 'role': 'UTILITY', 'tier': '3', 'winrate': '50.4%', 'pickrate': '3.57%'}
# {'champion': 'Brand', 'role': 'UTILITY', 'tier': '3', 'winrate': '50.35%', 'pickrate': '3.13%'}
# {'champion': 'Xerath', 'role': 'UTILITY', 'tier': '3', 'winrate': '50.34%', 'pickrate': '3.94%'}
# {'champion': 'Ziggs', 'role': 'MID', 'tier': '3', 'winrate': '50.34%', 'pickrate': '1.36%'}
# {'champion': 'Hwei', 'role': 'MID', 'tier': '3', 'winrate': '50.32%', 'pickrate': '3.86%'}
# {'champion': 'Fiora', 'role': 'TOP', 'tier': '3', 'winrate': '50.3%', 'pickrate': '4.23%'}
# {'champion': 'Shaco', 'role': 'UTILITY', 'tier': '3', 'winrate': '50.26%', 'pickrate': '2.15%'}
# {'champion': 'Fiddlesticks', 'role': 'JUNGLE', 'tier': '3', 'winrate': '50.22%', 'pickrate': '2.47%'}
# {'champion': 'Syndra', 'role': 'MID', 'tier': '3', 'winrate': '50.1%', 'pickrate': '4.06%'}
# {'champion': 'Jax', 'role': 'TOP', 'tier': '3', 'winrate': '50.07%', 'pickrate': '6.94%'}
# {'champion': 'Lillia', 'role': 'JUNGLE', 'tier': '3', 'winrate': '50.01%', 'pickrate': '3.5%'}
# {'champion': 'Renekton', 'role': 'TOP', 'tier': '3', 'winrate': '50.01%', 'pickrate': '5.77%'}
# {'champion': 'Kassadin', 'role': 'MID', 'tier': '3', 'winrate': '49.99%', 'pickrate': '1.9%'}
# {'champion': 'Swain', 'role': 'UTILITY', 'tier': '3', 'winrate': '49.92%', 'pickrate': '3.74%'}
# {'champion': 'Ryze', 'role': 'MID', 'tier': '3', 'winrate': '49.82%', 'pickrate': '3.01%'}
# {'champion': 'Tristana', 'role': 'BOT', 'tier': '3', 'winrate': '49.8%', 'pickrate': '6.44%'}
# {'champion': 'Karma', 'role': 'UTILITY', 'tier': '3', 'winrate': '49.75%', 'pickrate': '5.97%'}
# {'champion': 'Twisted Fate', 'role': 'MID', 'tier': '3', 'winrate': '49.72%', 'pickrate': '4.85%'}
# {'champion': 'Talon', 'role': 'JUNGLE', 'tier': '3', 'winrate': '49.68%', 'pickrate': '2.61%'}
# {'champion': 'Aphelios', 'role': 'BOT', 'tier': '3', 'winrate': '49.63%', 'pickrate': '7.65%'}
# {'champion': 'Evelynn', 'role': 'JUNGLE', 'tier': '3', 'winrate': '49.61%', 'pickrate': '2.62%'}
# {'champion': 'Blitzcrank', 'role': 'UTILITY', 'tier': '3', 'winrate': '49.48%', 'pickrate': '5.8%'}
# {'champion': 'Lucian', 'role': 'BOT', 'tier': '3', 'winrate': '49.42%', 'pickrate': '9.96%'}
# {'champion': 'Zoe', 'role': 'MID', 'tier': '3', 'winrate': '49.35%', 'pickrate': '2.76%'}
# {'champion': 'Darius', 'role': 'TOP', 'tier': '3', 'winrate': '49.33%', 'pickrate': '7.65%'}
# {'champion': 'Katarina', 'role': 'MID', 'tier': '3', 'winrate': '49.27%', 'pickrate': '5.82%'}
# {'champion': 'Rakan', 'role': 'UTILITY', 'tier': '3', 'winrate': '49.22%', 'pickrate': '4.02%'}
# {'champion': 'Seraphine', 'role': 'UTILITY', 'tier': '3', 'winrate': '49.2%', 'pickrate': '4.89%'}
# {'champion': 'Aurora', 'role': 'MID', 'tier': '3', 'winrate': '49.17%', 'pickrate': '4.21%'}
# {'champion': 'Aatrox', 'role': 'TOP', 'tier': '3', 'winrate': '49.04%', 'pickrate': '7.61%'}
# {'champion': 'Pantheon', 'role': 'UTILITY', 'tier': '3', 'winrate': '48.99%', 'pickrate': '3.6%'}
# {'champion': 'Alistar', 'role': 'UTILITY', 'tier': '3', 'winrate': '48.98%', 'pickrate': '4.05%'}
# {'champion': 'Pyke', 'role': 'UTILITY', 'tier': '3', 'winrate': '48.97%', 'pickrate': '6.17%'}
# {'champion': 'Graves', 'role': 'JUNGLE', 'tier': '3', 'winrate': '48.94%', 'pickrate': '3.97%'}
# {'champion': 'Orianna', 'role': 'MID', 'tier': '3', 'winrate': '48.79%', 'pickrate': '5.19%'}
# {'champion': 'Yuumi', 'role': 'UTILITY', 'tier': '3', 'winrate': '48.79%', 'pickrate': '5.74%'}
# {'champion': 'Yunara', 'role': 'BOT', 'tier': '3', 'winrate': '48.57%', 'pickrate': '15.3%'}
# {'champion': 'Zed', 'role': 'MID', 'tier': '3', 'winrate': '48.5%', 'pickrate': '7.03%'}
# {'champion': 'Pantheon', 'role': 'JUNGLE', 'tier': '3', 'winrate': '48.45%', 'pickrate': '4.96%'}
# {'champion': 'Mel', 'role': 'MID', 'tier': '3', 'winrate': '48.45%', 'pickrate': '5.47%'}
# {'champion': 'Yone', 'role': 'MID', 'tier': '3', 'winrate': '48.04%', 'pickrate': '6.85%'}
# {'champion': 'Zed', 'role': 'JUNGLE', 'tier': '3', 'winrate': '47.29%', 'pickrate': '5.05%'}
# {'champion': 'Swain', 'role': 'BOT', 'tier': '4', 'winrate': '53.98%', 'pickrate': '0.64%'}
# {'champion': 'Ziggs', 'role': 'BOT', 'tier': '4', 'winrate': '52%', 'pickrate': '1.86%'}
# {'champion': 'Elise', 'role': 'UTILITY', 'tier': '4', 'winrate': '51.69%', 'pickrate': '0.64%'}
# {'champion': 'Amumu', 'role': 'UTILITY', 'tier': '4', 'winrate': '51.64%', 'pickrate': '0.51%'}
# {'champion': 'Singed', 'role': 'TOP', 'tier': '4', 'winrate': '51.54%', 'pickrate': '1.75%'}
# {'champion': 'Fiddlesticks', 'role': 'UTILITY', 'tier': '4', 'winrate': '51.29%', 'pickrate': '0.76%'}
# {'champion': 'Kled', 'role': 'TOP', 'tier': '4', 'winrate': '51.08%', 'pickrate': '2.18%'}
# {'champion': "Cho'Gath", 'role': 'MID', 'tier': '4', 'winrate': '51.06%', 'pickrate': '0.66%'}
# {'champion': 'Neeko', 'role': 'MID', 'tier': '4', 'winrate': '50.99%', 'pickrate': '0.76%'}
# {'champion': 'LeBlanc', 'role': 'UTILITY', 'tier': '4', 'winrate': '50.95%', 'pickrate': '0.71%'}
# {'champion': 'Heimerdinger', 'role': 'TOP', 'tier': '4', 'winrate': '50.87%', 'pickrate': '1.76%'}
# {'champion': 'Poppy', 'role': 'TOP', 'tier': '4', 'winrate': '50.87%', 'pickrate': '1%'}
# {'champion': 'Galio', 'role': 'UTILITY', 'tier': '4', 'winrate': '50.85%', 'pickrate': '0.88%'}
# {'champion': 'Dr. Mundo', 'role': 'JUNGLE', 'tier': '4', 'winrate': '50.67%', 'pickrate': '0.97%'}
# {'champion': 'Poppy', 'role': 'JUNGLE', 'tier': '4', 'winrate': '50.67%', 'pickrate': '0.9%'}
# {'champion': 'Brand', 'role': 'MID', 'tier': '4', 'winrate': '50.6%', 'pickrate': '0.91%'}
# {'champion': 'Ivern', 'role': 'JUNGLE', 'tier': '4', 'winrate': '50.51%', 'pickrate': '1.12%'}
# {'champion': 'Olaf', 'role': 'TOP', 'tier': '4', 'winrate': '50.46%', 'pickrate': '1.54%'}
# {'champion': 'Zeri', 'role': 'BOT', 'tier': '4', 'winrate': '50.45%', 'pickrate': '2.58%'}
# {'champion': 'Shen', 'role': 'UTILITY', 'tier': '4', 'winrate': '50.37%', 'pickrate': '0.98%'}
# {'champion': "Bel'Veth", 'role': 'JUNGLE', 'tier': '4', 'winrate': '50.2%', 'pickrate': '1.78%'}
# {'champion': 'Renata Glasc', 'role': 'UTILITY', 'tier': '4', 'winrate': '50.14%', 'pickrate': '1.2%'}
# {'champion': 'Vayne', 'role': 'TOP', 'tier': '4', 'winrate': '50.12%', 'pickrate': '1.71%'}
# {'champion': 'Mel', 'role': 'BOT', 'tier': '4', 'winrate': '50.11%', 'pickrate': '0.79%'}
# {'champion': 'Akali', 'role': 'TOP', 'tier': '4', 'winrate': '50.06%', 'pickrate': '1.46%'}
# {'champion': 'Senna', 'role': 'BOT', 'tier': '4', 'winrate': '50.01%', 'pickrate': '3.27%'}
# {'champion': 'Shyvana', 'role': 'JUNGLE', 'tier': '4', 'winrate': '49.91%', 'pickrate': '1.62%'}
# {'champion': 'Talon', 'role': 'MID', 'tier': '4', 'winrate': '49.8%', 'pickrate': '1.33%'}
# {'champion': 'Xayah', 'role': 'BOT', 'tier': '4', 'winrate': '49.74%', 'pickrate': '4.33%'}
# {'champion': 'Tryndamere', 'role': 'TOP', 'tier': '4', 'winrate': '49.72%', 'pickrate': '2.62%'}
# {'champion': 'Vladimir', 'role': 'TOP', 'tier': '4', 'winrate': '49.67%', 'pickrate': '2.35%'}
# {'champion': 'Illaoi', 'role': 'TOP', 'tier': '4', 'winrate': '49.64%', 'pickrate': '3.01%'}
# {'champion': 'Kennen', 'role': 'TOP', 'tier': '4', 'winrate': '49.58%', 'pickrate': '2.07%'}
# {'champion': 'Nunu & Willump', 'role': 'JUNGLE', 'tier': '4', 'winrate': '49.56%', 'pickrate': '2.4%'}
# {'champion': 'Volibear', 'role': 'TOP', 'tier': '4', 'winrate': '49.56%', 'pickrate': '3.55%'}
# {'champion': 'Naafiri', 'role': 'JUNGLE', 'tier': '4', 'winrate': '49.55%', 'pickrate': '2.4%'}
# {'champion': 'Elise', 'role': 'JUNGLE', 'tier': '4', 'winrate': '49.51%', 'pickrate': '1.8%'}
# {'champion': 'Akshan', 'role': 'MID', 'tier': '4', 'winrate': '49.41%', 'pickrate': '2.01%'}
# {'champion': 'Cassiopeia', 'role': 'MID', 'tier': '4', 'winrate': '49.41%', 'pickrate': '1.26%'}
# {'champion': 'Udyr', 'role': 'JUNGLE', 'tier': '4', 'winrate': '49.24%', 'pickrate': '2%'}
# {'champion': 'Pantheon', 'role': 'TOP', 'tier': '4', 'winrate': '49.23%', 'pickrate': '2.06%'}
# {'champion': 'Camille', 'role': 'TOP', 'tier': '4', 'winrate': '49.21%', 'pickrate': '2.18%'}
# {'champion': 'Gangplank', 'role': 'TOP', 'tier': '4', 'winrate': '49.11%', 'pickrate': '3.25%'}
# {'champion': 'Tahm Kench', 'role': 'UTILITY', 'tier': '4', 'winrate': '49.09%', 'pickrate': '2.99%'}
# {'champion': 'Zac', 'role': 'JUNGLE', 'tier': '4', 'winrate': '49.02%', 'pickrate': '2.7%'}
# {'champion': 'Neeko', 'role': 'UTILITY', 'tier': '4', 'winrate': '48.96%', 'pickrate': '3.32%'}
# {'champion': 'Kindred', 'role': 'JUNGLE', 'tier': '4', 'winrate': '48.89%', 'pickrate': '2.94%'}
# {'champion': 'Gragas', 'role': 'TOP', 'tier': '4', 'winrate': '48.87%', 'pickrate': '2.41%'}
# {'champion': 'Ambessa', 'role': 'TOP', 'tier': '4', 'winrate': '48.76%', 'pickrate': '3.56%'}
# {'champion': 'Yasuo', 'role': 'TOP', 'tier': '4', 'winrate': '48.7%', 'pickrate': '2.82%'}
# {'champion': 'Draven', 'role': 'BOT', 'tier': '4', 'winrate': '48.64%', 'pickrate': '3.05%'}
# {'champion': 'Sejuani', 'role': 'JUNGLE', 'tier': '4', 'winrate': '48.58%', 'pickrate': '2.34%'}
# {'champion': 'Taliyah', 'role': 'MID', 'tier': '4', 'winrate': '48.55%', 'pickrate': '1.92%'}
# {'champion': 'Hecarim', 'role': 'JUNGLE', 'tier': '4', 'winrate': '48.47%', 'pickrate': '2.96%'}
# {'champion': 'Riven', 'role': 'TOP', 'tier': '4', 'winrate': '48.43%', 'pickrate': '3.08%'}
# {'champion': 'Senna', 'role': 'UTILITY', 'tier': '4', 'winrate': '48.15%', 'pickrate': '4.15%'}
# {'champion': 'Yone', 'role': 'TOP', 'tier': '4', 'winrate': '48.02%', 'pickrate': '4.71%'}
# {'champion': 'Nidalee', 'role': 'JUNGLE', 'tier': '4', 'winrate': '47.99%', 'pickrate': '2.77%'}
# {'champion': 'Vi', 'role': 'JUNGLE', 'tier': '4', 'winrate': '47.91%', 'pickrate': '4.2%'}
# {'champion': 'Varus', 'role': 'BOT', 'tier': '4', 'winrate': '47.6%', 'pickrate': '5.13%'}
# {'champion': 'Azir', 'role': 'MID', 'tier': '4', 'winrate': '47.48%', 'pickrate': '3.77%'}
# {'champion': 'Ezreal', 'role': 'BOT', 'tier': '4', 'winrate': '47.21%', 'pickrate': '10.68%'}

# %%
#12. Off-Meta Champs -- Continuation
# If champ is tier 4 or 5 and pickrate is <1% then it is called off meta
# If champ + role combo is not in the list --> OffMeta too

meta_df = pd.DataFrame(champ_data_tier)

meta_df['pickrate_float'] = meta_df['pickrate'].str.replace('%', '').str.replace(',', '.').astype(float)

valid_combos = set(zip(meta_df['champion'], meta_df['role']))

def is_offmeta(row):
    champ = row['championName']
    role = row['teamPosition']
    meta_row = meta_df[(meta_df['champion'] == champ) & (meta_df['role'] == role)]
    if (champ, role) not in valid_combos:
        return True
    if not meta_row.empty:
        tier = meta_row.iloc[0]['tier']
        pickrate = meta_row.iloc[0]['pickrate_float']
        if (tier in ['4', '5']) and (pickrate < 1):
            return True
    return False

df_ranked['offmeta'] = df_ranked.apply(is_offmeta, axis=1)
display(df_ranked[["offmeta","puuid"]])
# Out:
#        offmeta                                              puuid
# 0         True  NS6Iz_PJ1jLlCCDSZbhC-_tSB0XDiTQFp_M4cUgNCbR7gM...
# 1         True  BNEeQVLI4LHlAOpNrf_1UGzcPx5LgiKXPfKKIWReTwdPxK...
# 2         True  zJnf3VYJutq8lqOnD_iXDlhmETkk1dULIZTWft2r-fkWCC...
# 3         True  HwKU5bDk89rnr5yqXQwopXSh0x0z2tQXCWv4ewx0NtC0-L...
# 4         True  ck-5nJvjkpmGgyNJnH_A3nMv_A7EJ0uJ3fZkN3WbsMLX3K...
# ...        ...                                                ...
# 28239     True  nXsh_YGl4JoiE6YwujkRUsssdIDm6igniY_GZtwybdBR38...
# 28240     True  sctQO-_g1p2Jd8-IYqKsCHBYbcMfZQMhwe30Ml9GiPpY30...
# 28241     True  k3QAhE5LhuNEsV4eEvmrDWliQrdfpPHcsEoJ_dEjuHIRuz...
# 28242     True  Ao9Z0pTWKx8FVv31_BIX1BenGN6XBLfcvkUUzGIeLC1Jh5...
# 28243     True  cYDCBEUxCvbgUvxQPpKxZ0O-wQS35jV-6tHXTAruGorV6-...
#
# [28244 rows x 2 columns]

# %%
#13. Games with over 20 Kills

kills_threshold = 20

games_with_over_kills = df_ranked.groupby('puuid')['kills'].apply(lambda x: (x > kills_threshold).mean()).reset_index()
games_with_over_kills.rename(columns={'kills': f'rate_games_over_{kills_threshold}kills'}, inplace=True)

df_ranked = df_ranked.merge(games_with_over_kills, on='puuid', how='left')

print(df_ranked[['puuid', f'rate_games_over_{kills_threshold}kills']].head())
# Out:
#                                                puuid  rate_games_over_20kills
# 0  NS6Iz_PJ1jLlCCDSZbhC-_tSB0XDiTQFp_M4cUgNCbR7gM...                      0.0
# 1  BNEeQVLI4LHlAOpNrf_1UGzcPx5LgiKXPfKKIWReTwdPxK...                      0.0
# 2  zJnf3VYJutq8lqOnD_iXDlhmETkk1dULIZTWft2r-fkWCC...                      0.0
# 3  HwKU5bDk89rnr5yqXQwopXSh0x0z2tQXCWv4ewx0NtC0-L...                      0.0
# 4  ck-5nJvjkpmGgyNJnH_A3nMv_A7EJ0uJ3fZkN3WbsMLX3K...                      0.0

# %%
#17 Average "Skillshots landed" und "-dodged"
# Dictionary for every rank with Skillshots landed --> Yes/No

avg_skillshots_per_rank = df.groupby('tier')['skillshotsHit'].mean().reset_index()
avg_skillshots_per_rank.rename(columns={'skillshotsHit': 'avg_skillshots_hit'}, inplace=True)

avg_skillshots_dodged_per_rank = df.groupby('tier')['skillshotsDodged'].mean().reset_index()
avg_skillshots_dodged_per_rank.rename(columns={'skillshotsDodged': 'avg_skillshots_dodged'}, inplace=True)

player_skillshots = df.groupby(['puuid', 'tier'])['skillshotsHit'].mean().reset_index()
player_skillshots.rename(columns={'skillshotsHit': 'player_skillshots'}, inplace=True)

player_skillshots_dodged = df.groupby(['puuid', 'tier'])['skillshotsDodged'].mean().reset_index()
player_skillshots_dodged.rename(columns={'skillshotsDodged': 'player_dodged'}, inplace=True)

avg_combined_skillshots = avg_skillshots_per_rank.merge(avg_skillshots_dodged_per_rank, on='tier', how='left')

compare_skillshots = player_skillshots.merge(
    avg_skillshots_per_rank, on=['tier'], how='left'
    ).merge(
        player_skillshots_dodged, on=['puuid', 'tier'], how='left'
    ).merge(
        avg_skillshots_dodged_per_rank, on=['tier'], how='left'
    )

compare_skillshots['skillshots_above_rank'] = np.where(
    compare_skillshots['player_skillshots'] > compare_skillshots['avg_skillshots_hit'], 1, 0
)

compare_skillshots['dodged_above_rank'] = np.where(
    compare_skillshots['player_dodged'] > compare_skillshots['avg_skillshots_dodged'], 1, 0
)

df_ranked = df_ranked.merge(compare_skillshots[['puuid',
                            'tier',
                            'player_skillshots',
                            'avg_skillshots_hit',
                            'skillshots_above_rank',
                            'player_dodged',
                            'avg_skillshots_dodged',
                            'dodged_above_rank'
                        ]], on=['puuid', 'tier'],
                        how='left'
                    )

print(df_ranked[[
    'puuid',
    'tier',
    'player_skillshots',
    'avg_skillshots_hit',
    'skillshots_above_rank',
    'player_dodged',
    'avg_skillshots_dodged',
    'dodged_above_rank'
]].head())
# Out:
#                                                puuid    tier  \
# 0  NS6Iz_PJ1jLlCCDSZbhC-_tSB0XDiTQFp_M4cUgNCbR7gM...    IRON
# 1  BNEeQVLI4LHlAOpNrf_1UGzcPx5LgiKXPfKKIWReTwdPxK...    IRON
# 2  zJnf3VYJutq8lqOnD_iXDlhmETkk1dULIZTWft2r-fkWCC...  BRONZE
# 3  HwKU5bDk89rnr5yqXQwopXSh0x0z2tQXCWv4ewx0NtC0-L...  BRONZE
# 4  ck-5nJvjkpmGgyNJnH_A3nMv_A7EJ0uJ3fZkN3WbsMLX3K...    IRON
#
#    player_skillshots  avg_skillshots_hit  skillshots_above_rank  \
# 0               28.0           29.185304                      0
# 1                0.0           29.185304                      0
# 2              322.0           29.193687                      1
# 3               17.0           29.193687                      0
# 4               35.0           29.185304                      1
#
#    player_dodged  avg_skillshots_dodged  dodged_above_rank
# 0           61.0              34.551118                  1
# 1           44.0              34.551118                  1
# 2          115.0              36.964849                  1
# 3           74.0              36.964849                  1
# 4           51.0              34.551118                  1

# %%
#18 Average objective steals per game
# Dictionary for every rank how many Steals is typical --> Yes/No

avg_EpicMonsterSteals_per_rank = df.groupby('tier')['epicMonsterSteals'].mean().reset_index()
avg_EpicMonsterSteals_per_rank.rename(columns={'epicMonsterSteals': 'avg_epicMonsterSteals'}, inplace=True)

avg_EpicMonsterStolenWOsmite_per_rank = df.groupby('tier')['epicMonsterStolenWithoutSmite'].mean().reset_index()
avg_EpicMonsterStolenWOsmite_per_rank.rename(columns={'epicMonsterStolenWithoutSmite': 'avg_epicMonsterStolenWithoutSmite'}, inplace=True)

player_EpicMonsterSteals = df.groupby(['puuid', 'tier'])['epicMonsterSteals'].mean().reset_index()
player_EpicMonsterSteals.rename(columns={'epicMonsterSteals': 'player_epicMonsterSteals'}, inplace=True)

player_EpicMonsterStealsWOsmite = df.groupby(['puuid', 'tier'])['epicMonsterStolenWithoutSmite'].mean().reset_index()
player_EpicMonsterStealsWOsmite.rename(columns={'epicMonsterStolenWithoutSmite': 'player_epicMonsterStealsWOsmite'}, inplace=True)

compare_objectives = player_EpicMonsterSteals.merge(
    avg_EpicMonsterSteals_per_rank, on='tier', how='left'
).merge(
    player_EpicMonsterStealsWOsmite, on=['puuid', 'tier'], how='left'
).merge(
    avg_EpicMonsterStolenWOsmite_per_rank, on='tier', how='left'
)

compare_objectives['epicMonsterSteals_above_rank'] = np.where(
    compare_objectives['player_epicMonsterSteals'] > compare_objectives['avg_epicMonsterSteals'], 1, 0
)
compare_objectives['epicMonsterStealsWOsmite_above_rank'] = np.where(
    compare_objectives['player_epicMonsterStealsWOsmite'] > compare_objectives['avg_epicMonsterStolenWithoutSmite'], 1, 0
)

df_ranked = df_ranked.merge(compare_objectives[['puuid',
                            'tier',
                            'player_epicMonsterSteals',
                            'avg_epicMonsterSteals',
                            'player_epicMonsterStealsWOsmite',
                            'avg_epicMonsterStolenWithoutSmite',
                            'epicMonsterSteals_above_rank',
                            'epicMonsterStealsWOsmite_above_rank'
                        ]],
                        on=['puuid', 'tier'], 
                        how='left'
                    )

# %%
# 21. "eligibleForProgression" is "True"?
print(df['eligibleForProgression'])
# Out:
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
#          ...
# 45331    True
# 45333    True
# 45335    True
# 45336    True
# 45337    True
# Name: eligibleForProgression, Length: 28548, dtype: bool

# %%
# Cleaning process
df_ranked = df_ranked.loc[:, ~df_ranked.columns.str.startswith('SWARM_')]
df_ranked = df_ranked.loc[:, ~df_ranked.columns.str.startswith('challenge_SWARM_')]
df_ranked = df_ranked.drop(columns=['championSkinId', 'perks_styles','summonerName','legendaryItemUsed','challenge_legendaryItemUsed', 'rank', 'tier', 'individualPosition','role'], errors='ignore')

# %%
# Bool values in numerical
df_ranked_bool = df_ranked.select_dtypes(include=['bool'])

df_ranked[df_ranked_bool.columns] = df_ranked_bool.map(lambda x: 1 if x else 0)

# %%
for x in ['hotStreak', 'veteran', 'freshBlood']:
    df_ranked[x] = df_ranked[x].map({'True': 1, 'False': 0})

df_ranked['first_legendary_id'] = df_ranked['first_legendary_id'].astype('int64')


df_ranked['lane'] = df_ranked['lane'].replace('NONE', 'FILL')

lanes = pd.get_dummies(df_ranked['lane'], prefix='queued_lane', dtype=int)

df_ranked = pd.concat([df_ranked, lanes], axis=1)


played_lane = pd.get_dummies(df_ranked['teamPosition'], prefix='played_lane', dtype=int)

df_ranked = pd.concat([df_ranked, played_lane], axis=1)


df_ranked = df_ranked.drop(['lane'], axis=1, errors='ignore')
df_ranked = df_ranked.drop(['teamPosition'], axis=1, errors='ignore')


df_ranked['timestamp'] = df_ranked['timestamp'].astype('int64')
df_ranked = df_ranked.rename(columns={'timestamp': 'gameCreationTimestamp'})

# %%
champions = {
    'ALISTAR': 1,
    'ANNIE': 2,
    'ASHE': 3,
    'FIDDLESTICKS': 4,
    'JAX': 5,
    'KAYLE': 6,
    'MASTER YI': 7,
    'MORGANA': 8,
    'NUNUWILLUMP': 9,
    'RYZE': 10,
    'SION': 11,
    'SIVIR': 12,
    'SORAKA': 13,
    'TEEMO': 14,
    'TRISTANA': 15,
    'TWISTEDFATE': 16,
    'WARWICK': 17,
    'SINGED': 18,
    'ZILEAN': 19,
    'EVELYNN': 20,
    'TRYNDAMERE': 21,
    'TWITCH': 22,
    'KARTHUS': 23,
    'AMUMU': 24,
    'CHOGATH': 25,
    'ANIVIA': 26,
    'RAMMUS': 27,
    'VEIGAR': 28,
    'KASSADIN': 29,
    'GANGPLANK': 30,
    'TARIC': 31,
    'BLITZCRANK': 32,
    'DRMUNDO': 33,
    'JANNA': 34,
    'MALPHITE': 35,
    'CORKI': 36,
    'KATARINA': 37,
    'NASUS': 38,
    'HEIMERDINGER': 39,
    'SHACO': 40,
    'UDYR': 41,
    'NIDALEE': 42,
    'POPPY': 43,
    'GRAGAS': 44,
    'PANTHEON': 45,
    'MORDEKAISER': 46,
    'EZREAL': 47,
    'SHEN': 48,
    'KENNEN': 49,
    'GAREN': 50,
    'AKALI': 51,
    'MALZAHAR': 52,
    'OLAF': 53,
    'KOGMAW': 54,
    'XINZHAO': 55,
    'VLADIMIR': 56,
    'GALIO': 57,
    'URGOT': 58,
    'MISSFORTUNE': 59,
    'SONA': 60,
    'SWAIN': 61,
    'LUX': 62,
    'LEBLANC': 63,
    'IRELIA': 64,
    'TRUNDLE': 65,
    'CASSIOPEIA': 66,
    'CAITLYN': 67,
    'RENEKTON': 68,
    'KARMA': 69,
    'MAOKAI': 70,
    'JARVANIV': 71,
    'NOCTURNE': 72,
    'LEESIN': 73,
    'BRAND': 74,
    'RUMBLE': 75,
    'VAYNE': 76,
    'ORIANNA': 77,
    'YORICK': 78,
    'LEONA': 79,
    'WUKONG': 80,
    'SKARNER': 81,
    'TALON': 82,
    'RIVEN': 83,
    'XERATH': 84,
    'GRAVES': 85,
    'SHYVANA': 86,
    'FIZZ': 87,
    'VOLIBEAR': 88,
    'AHRI': 89,
    'VIKTOR': 90,
    'SEJUANI': 91,
    'ZIGGS': 92,
    'NAUTILUS': 93,
    'FIORA': 94,
    'LULU': 95,
    'HECARIM': 96,
    'VARUS': 97,
    'DARIUS': 98,
    'DRAVEN': 99,
    'JAYCE': 100,
    'ZYRA': 101,
    'DIANA': 102,
    'RENGAR': 103,
    'SYNDRA': 104,
    'KHAZIX': 105,
    'ELISE': 106,
    'ZED': 107,
    'NAMI': 108,
    'VI': 109,
    'THRESH': 110,
    'QUINN': 111,
    'ZAC': 112,
    'LISSANDRA': 113,
    'AATROX': 114,
    'LUCIAN': 115,
    'JINX': 116,
    'YASUO': 117,
    'VELKOZ': 118,
    'BRAUM': 119,
    'GNAR': 120,
    'AZIR': 121,
    'KALISTA': 122,
    'REKSAI': 123,
    'BARD': 124,
    'EKKO': 125,
    'TAHMKENCH': 126,
    'KINDRED': 127,
    'ILLAOI': 128,
    'JHIN': 129,
    'AURELIONSOL': 130,
    'TALIYAH': 131,
    'KLED': 132,
    'IVERN': 133,
    'CAMILLE': 134,
    'RAKAN': 135,
    'XAYAH': 136,
    'KAYN': 137,
    'ORNN': 138,
    'ZOE': 139,
    'KAISA': 140,
    'PYKE': 141,
    'NEEKO': 142,
    'SYLAS': 143,
    'YUUMI': 144,
    'QIYANA': 145,
    'SENNA': 146,
    'APHELIOS': 147,
    'SETT': 148,
    'LILLIA': 149,
    'YONE': 150,
    'SAMIRA': 151,
    'SERAPHINE': 152,
    'RELL': 153,
    'VIEGO': 154,
    'GWEN': 155,
    'AKSHAN': 156,
    'VEX': 157,
    'ZERI': 158,
    'RENATAGLASC': 159,
    'BELVETH': 160,
    'NILAH': 161,
    'KSANTE': 162,
    'MILIO': 163,
    'NAAFIRI': 164,
    'BRIAR': 165,
    'HWEI': 166,
    'SMOLDER': 167,
    'AURORA': 168,
    'AMBESSA': 169,
    'MEL': 170
}

df_ranked['championName'] = df_ranked['championName'].map(champions)

# %%
df_ranked_obj = df_ranked.select_dtypes(include=['object'])
df_ranked_obj
# Out:
#       gameMode      gameType  \
# 0      CLASSIC  MATCHED_GAME
# 1      CLASSIC  MATCHED_GAME
# 2      CLASSIC  MATCHED_GAME
# 3      CLASSIC  MATCHED_GAME
# 4      CLASSIC  MATCHED_GAME
# ...        ...           ...
# 28239  CLASSIC  MATCHED_GAME
# 28240  CLASSIC  MATCHED_GAME
# 28241  CLASSIC  MATCHED_GAME
# 28242  CLASSIC  MATCHED_GAME
# 28243  CLASSIC  MATCHED_GAME
#
#                                                    puuid   riotIdGameName  \
# 0      NS6Iz_PJ1jLlCCDSZbhC-_tSB0XDiTQFp_M4cUgNCbR7gM...       DaviPolo30
# 1      BNEeQVLI4LHlAOpNrf_1UGzcPx5LgiKXPfKKIWReTwdPxK...           FM93LY
# 2      zJnf3VYJutq8lqOnD_iXDlhmETkk1dULIZTWft2r-fkWCC...  Feathers McGraw
# 3      HwKU5bDk89rnr5yqXQwopXSh0x0z2tQXCWv4ewx0NtC0-L...        Janjani03
# 4      ck-5nJvjkpmGgyNJnH_A3nMv_A7EJ0uJ3fZkN3WbsMLX3K...    Neliafasantos
# ...                                                  ...              ...
# 28239  nXsh_YGl4JoiE6YwujkRUsssdIDm6igniY_GZtwybdBR38...      chupipuerco
# 28240  sctQO-_g1p2Jd8-IYqKsCHBYbcMfZQMhwe30Ml9GiPpY30...       FatBoyZero
# 28241  k3QAhE5LhuNEsV4eEvmrDWliQrdfpPHcsEoJ_dEjuHIRuz...        ItzDARKiQ
# 28242  Ao9Z0pTWKx8FVv31_BIX1BenGN6XBLfcvkUUzGIeLC1Jh5...          mikitom
# 28243  cYDCBEUxCvbgUvxQPpKxZ0O-wQS35jV-6tHXTAruGorV6-...       CrossBonez
#
#       riotIdTagline                                         summonerId  \
# 0               EUW  bAk85gl9MyCFkwttrV18j_hCKY5-U9ZvnnGVlQH7-xNuLJ...
# 1               EUW  kSHAQCYrlG9jLMKyDpwCOXutMt81nDM2NiXZbnvMM9lbcR...
# 2              6858  XOuWqsdfz9RqnRun69zBfYANuk4OP4VSO5xlBoqhYA27Dq...
# 3               UwU  3hbNNYnD7QR3JDryiUhC1_aQfdQN-tJRb74ER46NESfFVq...
# 4              5456  NMdrKqDBltzhtkkbkbzVSsHEbNxe0rcxQ6duYKSL-6C-L4...
# ...             ...                                                ...
# 28239           ts3  R17u4k0gwtwSbZA1ko5yvcDuHhFPDkXWb6xhiwvWaszhWX...
# 28240           FBZ    o7YYPMxrT8UX2HW0BxJnPeENo_8txYGRPlYcXIwFp-SjlW4
# 28241           RBK  7YsZsIIqVqacApY9O8V1CX2nrl1jFh4BoYY9nLypUCPsD_...
# 28242          3411   H56KbdLdh9Eai_M9NakJgv39GsHr1PrbsfIrHNRQIcQkPn5x
# 28243         GAROU  1G-UIfFaVhb4wCzTbfCsIpnXIsLVz-i7Tq0rM-aQMPNZgk...
#
#       smurf_category
# 0       likely_smurf
# 1             normal
# 2             normal
# 3             normal
# 4             normal
# ...              ...
# 28239         normal
# 28240         normal
# 28241         normal
# 28242         normal
# 28243   likely_smurf
#
# [28244 rows x 7 columns]

# %%
# Imputation

df_ranked = df_ranked.fillna(
    df_ranked
        .select_dtypes(
            include=['float64']
            )
            .mean()
            .fillna(0)
    )

df_ranked = df_ranked.fillna(
    df_ranked
        .select_dtypes(
            include=['int64']
            )
            .mode()
            .iloc[0]
            .fillna(0)
            )

# %%
df_ranked.dtypes.value_counts()
# Out:
# float64    311
# int64      153
# object       7
# Name: count, dtype: int64

# %%
with open('features_columns_df_ranked.json', 'w', encoding='utf-8') as f:
    json.dump(list(df_ranked.columns), f, ensure_ascii=False, indent=2)

# %%
df_ranked.select_dtypes(include=['float64', 'int64']).columns
# Out:
# Index(['gameCreationTimestamp', 'gameId', 'LP', 'wins', 'losses',
#        'PlayerScore0', 'PlayerScore1', 'PlayerScore10', 'PlayerScore11',
#        'PlayerScore2',
#        ...
#        'queued_lane_BOTTOM', 'queued_lane_FILL', 'queued_lane_JUNGLE',
#        'queued_lane_MIDDLE', 'queued_lane_TOP', 'played_lane_BOTTOM',
#        'played_lane_JUNGLE', 'played_lane_MIDDLE', 'played_lane_TOP',
#        'played_lane_UTILITY'],
#       dtype='object', length=464)

# %%
df_ranked['smurf_flag'].value_counts()
# Out:
# smurf_flag
# 0    27532
# 1      712
# Name: count, dtype: int64

# %% [markdown]
# 0    964
# 1      4 with level 50 and winrate 70

# %%
test = df_ranked[df_ranked['smurf_flag']==1]
test[['riotIdGameName','riotIdTagline']]
# Out:
#          riotIdGameName riotIdTagline
# 129           Shiyelden          1801
# 176             Crawler          THIB
# 221          Tiaktonris          5733
# 265    zoe pink panties         hello
# 325          Erisghtrod          8092
# ...                 ...           ...
# 28191               893           1st
# 28198            Perrin           YEP
# 28206           Sky Bri           BBY
# 28220           agpvzzu           EUW
# 28243        CrossBonez         GAROU
#
# [712 rows x 2 columns]

# %%
test2 = df_ranked[df_ranked['riotIdGameName'] == "Regen"]
test2['championName']
# Out:
# Series([], Name: championName, dtype: float64)

# %%
df_ranked.to_csv('df.eneemr', index=False)
