# %%
from bs4 import BeautifulSoup
import glob
import os

# Only for DeepNote
path = "/work"  

#Find all files with .txt
files = sorted(glob.glob(os.path.join(path, "*.txt")))

players = []

for file in files:
    with open(file, "r", encoding="utf-8") as f:
        html_content = f.read()

    soup = BeautifulSoup(html_content, "html.parser")

    rows = soup.select("tr")

    for row in rows:
        name = row.select_one("span.whitespace-pre-wrap.text-gray-900")
        tag = row.select_one("span.text-gray-500.truncate")

        if name and tag:
            player_name = name.text.strip()
            player_tag = tag.text.strip()
            players.append(f"{player_name}{player_tag}")

#Drop Duplicates
players = list(set(players))

print(players)
print(f"{len(players)} Spieler gefunden")

with open("/work/alle_spieler.txt", "w", encoding="utf-8") as f:
    for p in players:
        f.write(p + "\n")
# Out:
# ['Wèt Zèd#EUW', 'KeriaMakhnovista#1849', '12fuasboi#Kek', 'Sombrilla#Autmn', 'Vanquisher#CIA', 'IndianMentale#66666', 'Dragodinde dorée#LV100', 'CoupDeGrâce#1385', 'DocSoraka#666', 'RNGesú#RPEAT', 'JACK#HNAG', 'leonesquik#EUW', 'NzErmurphy#6969', 'Simon Candsi#EUW', 'Ovny#EUW', 'Z Insec Z#EUW', 'Just a Sash#EUW', 'uWu animefreakxo#uwu', 'Queen of Top#QUEEN', 'AGRO5#EUWNA', '文智謙#444', 'why always me#1512', 'OmegaSchlumpf#EUW', 'SKAZARA#EUW', 'claptrap#4444', 'Yung Kaihua#EUW', 'Clecian#EUW', 'Crawler#THIB', 'Grillo23#LUX', 'Kalitko#EUW', 'Pearce#1202', 'Veigar#vei', 'BestShamponEU#EUW', 'Arabic Papi#EUW', 'Tiaktonris#5733', 'FlashEQNoBrain#VAPE', 'Britney Spears#1v9', 'gearsofwarjake#wwe2k', 'zoe pink panties#hello', 'gggggame#EUW', 'Alexander296#296', 'JustMat#EUW', 'DumbWaysToDie2#EUW', 'Kunyen#AMG', 'Malcora#EUW', 'Bored but shiny#EUW', 'AW Archi#MGSTR', 'Keyboard Mouse#EUW', 'Astaldox88#1000', 'D105#EUW', 'ShoeExploding#EUW', 'PoPo376#EUW', 'ASSI#2760', 'Hyst0s#EUW', 'Wil0111#Bombe', 'piper777#5073', 'Kuurwa Bober#John', 'EatMySh0rtS#EUW', 'Hungry as fk#EUW', 'AshleyFrenchley#4420', 'ELENA LA BUFAS#uwu', 'So Baka#EUW', 'chinoirrpz#EUW', 'Lvl 1 déjà skren#skark', 'Chton#EUW', 'epileptic panda#EUW', 'Ganja One#EUW', 'SkydiamondLife#Poppy', 'Emerald Ranger#EUW', 'Evil Engineer#EUW', 'Marvynn#99999', 'x64 Hero#EUW', 'Loser ACC#EUW', 'HOUDITEUR#EUW', 'Very Strong Snus#EUW', 'Gontran#1152', 'Julcesanney#0023', 'Onecaiantane#EUW', 'Lawahu#EUW', 'P0RRAXXL#2307', 'Leafyez#EUW', 'IVAN McGREGOR#EUW', 'Turmelija#EUW', 'Linusoss#7943', 'S4L Gorosh#EUW', 'eleventwelves#Leite', 'عنتر بن شداد#sword', 'Engelstrompete#EUW', 'netandchill#EUW', 'Fingolfin#ELF1', 'ILoveUIHateU#2031', 'ChaosKosuel#EUW', 'Lil Peep Enjoyer#lIlIl', 'TChipsOfLegends#EUW', 'inpace#0001', 'ArIscooo#EUW', 'RTN